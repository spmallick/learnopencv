# %% [markdown]
# ## Installation

# %%
# !pip install git+https://github.com/huggingface/transformers@v4.49.0-Gemma-3 -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done

# %%
# To use quantization
# !pip install bitsandbytes -qU
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 56.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.7 MB/s eta 0:00:00

# %%
# for fast weight downloads
# !pip install hf_transfer -qU
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 46.6 MB/s eta 0:00:00

# %%
import huggingface_hub
huggingface_hub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Gemma 3 - 4B, 12B, 27B

# %%
## FOR 4,12,27B model

from transformers import AutoProcessor, Gemma3ForConditionalGeneration
import torch

model_id = "google/gemma-3-4b-it"
# model_id = "google/gemma-3-12b-it" # cell outputs below for from this model in nf4 (but I've defaulted a smaller model above)
# model_id = "google/gemma-3-27b-it"

datatype = torch.bfloat16

# to use this, first run `!pip install bitsandbytes`
from transformers import BitsAndBytesConfig

# 4bit
quantization_config = BitsAndBytesConfig(
   load_in_4bit=True,
   bnb_4bit_quant_type="nf4",
   bnb_4bit_use_double_quant=True,
   bnb_4bit_compute_dtype=datatype
)

## 8bit
# quantization_config = BitsAndBytesConfig(
#    load_in_8bit=True,
# )

model = Gemma3ForConditionalGeneration.from_pretrained(
    model_id,
    torch_dtype=datatype,
    device_map="auto",
    quantization_config=quantization_config # comment this out if you don't want to use quantization.
).eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %%
processor = AutoProcessor.from_pretrained(model_id)
# Out:
# processor_config.json:   0%|          | 0.00/70.0 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]

# %%
instruction="""
Convert the equation images to LaTeX equations.
"""

messages = [
    {
        "role": "system",
        "content": [{"type": "text", "text": "You are a helpful assistant."}]
    },
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "/content/latex1.jpg"},
            {"type": "text", "text": instruction}
        ]
    }
]

inputs = processor.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True,
    return_dict=True, return_tensors="pt"
).to(model.device, dtype=torch.bfloat16)

input_len = inputs["input_ids"].shape[-1]

with torch.inference_mode():
    generation = model.generate(**inputs, max_new_tokens=512, do_sample=False)
    generation = generation[0][input_len:]

decoded = processor.decode(generation, skip_special_tokens=True)
print(decoded)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:634: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:651: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `64` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# Here's the LaTeX representation of the equation you provided:
#
# ```latex
# H' = \beta N \int \lambda d\lambda \{ \frac{1}{2B^2 N^2} \alpha_s^* \alpha_s + V(\lambda) \alpha_s^{*2} \}
# ```
#
# **Explanation of the LaTeX code:**
#
# *   `H'` :  Represents the integral of a quantity called H-prime.
# *   `\beta N`:  Represents a constant multiplied by N.
# *   `\int`:  Indicates the integral symbol.
# *   `\lambda`:  Represents a variable lambda.
# *   `d\lambda`:  Indicates the integration with respect to lambda.
# *   `\{ ... \}`:  Encloses a set of expressions within curly braces, indicating a summation or a group of terms.
# *   `\frac{1}{2B^2 N^2}`:  Represents a fraction.
# *   `\alpha_s^*`:  Represents a symbol alpha\_s with an asterisk, indicating a derivative.
# *   `\alpha_s`:  Represents a symbol alpha\_s.
# *   `V(\lambda)`:  Represents a function V of lambda.
# *   `\alpha_s^{*2}`: Represents a symbol alpha\_s with an asterisk squared.
#
# If you'd like to provide another equation, please do so, and I'll convert it to LaTeX as well.

# %%
instruction="""
Convert the equation images to LaTeX equations.
"""

messages = [
    {
        "role": "system",
        "content": [{"type": "text", "text": "You are a helpful assistant."}]
    },
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "/content/latex2.jpg"}, # Credit Simon Willison's blog for the choice here
            {"type": "text", "text": instruction}
        ]
    }
]

inputs = processor.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True,
    return_dict=True, return_tensors="pt"
).to(model.device, dtype=torch.bfloat16)

input_len = inputs["input_ids"].shape[-1]

with torch.inference_mode():
    generation = model.generate(**inputs, max_new_tokens=512, do_sample=False)
    generation = generation[0][input_len:]

decoded = processor.decode(generation, skip_special_tokens=True)
print(decoded)
# Out:
# Here's the LaTeX representation of the equation images:
#
# ```latex
# \left[B_{x_t, b_2, b_6}[x_t] \right) = nB_{x_t}, \quad \left[B_{x_t, b_2, b_6}[x_t] \right) = nB_{x_t}.
# ```
#
# **Explanation:**
#
# *   `\left[ ... \right)`:  This creates parentheses around the entire expression.
# *   `B_{x_t, b_2, b_6}[x_t]`:  This represents the notation for the function B.
# *   `n`:  This represents the constant 'n'.
# *   `B_{x_t}`:  This represents the function B with input $x_t$.
# *   `\quad`:  This is used to insert a large space between the two equations.
#
# If you'd like me to convert other equations or explain any part of this, just ask!

# %%
instruction="""
Convert the equation images to LaTeX equations.
"""

messages = [
    {
        "role": "system",
        "content": [{"type": "text", "text": "You are a helpful assistant."}]
    },
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "/content/latex3.jpg"}, # Credit Simon Willison's blog for the choice here
            {"type": "text", "text": instruction}
        ]
    }
]

inputs = processor.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True,
    return_dict=True, return_tensors="pt"
).to(model.device, dtype=torch.bfloat16)

input_len = inputs["input_ids"].shape[-1]

with torch.inference_mode():
    generation = model.generate(**inputs, max_new_tokens=512, do_sample=False)
    generation = generation[0][input_len:]

decoded = processor.decode(generation, skip_special_tokens=True)
print(decoded)
# Out:
# Here's the LaTeX representation of the equation:
#
# ```latex
# +\int \partial_i^n J^k(x) a_{\mu}(x) + \int \partial_i^n J^k(x) \phi(x),
# ```
#
# **Explanation:**
#
# *   `\int`:  Represents the integral symbol.
# *   `\partial_i^n`:  Represents the partial derivative of the i-th variable to the n-th power.
# *   `J^k(x)`: Represents a function J^k(x).
# *   `a_{\mu}(x)`: Represents a function a_{\mu}(x).
# *   `\phi(x)`: Represents a function $\phi(x)$.
#
# If you'd like me to convert other equations or provide further explanations, just let me know!

# %%
instruction="""
Convert the equation images to LaTeX equations.
"""

messages = [
    {
        "role": "system",
        "content": [{"type": "text", "text": "You are a helpful assistant."}]
    },
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "/content/latex4.jpg"}, # Credit Simon Willison's blog for the choice here
            {"type": "text", "text": instruction}
        ]
    }
]

inputs = processor.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True,
    return_dict=True, return_tensors="pt"
).to(model.device, dtype=torch.bfloat16)

input_len = inputs["input_ids"].shape[-1]

with torch.inference_mode():
    generation = model.generate(**inputs, max_new_tokens=512, do_sample=False)
    generation = generation[0][input_len:]

decoded = processor.decode(generation, skip_special_tokens=True)
print(decoded)
# Out:
# Here's the LaTeX representation of the equation:
#
# ```latex
# M = \frac{V_p \Omega \Omega_{d-1}}{16 \pi G} d^2 \left[d - 1 + (d-2) \sinh^2 \alpha \right]
# ```
#
# **Explanation of the LaTeX code:**
#
# *   `M =`:  Indicates the variable M is equal to...
# *   `\frac{...}{...}`:  Creates a fraction.
# *   `V_p`:  Represents a variable (as is).
# *   `\Omega`:  Represents a variable (as is).
# *   `\Omega_{d-1}`:  Represents a variable (as is).
# *   `16 \pi G`:  Represents a constant.
# *   `d^2`:  Represents the variable d squared.
# *   `[...]`:  Encloses a bracketed expression.
# *   `\left[ ... \right]`:  Creates a pair of parentheses for grouping.
# *   `d - 1`:  Represents the variable d minus 1.
# *   `+`:  The addition symbol.
# *   `(d-2)`:  Represents the variable d minus 2.
# *   `\sinh^2 \alpha`:  Represents the variable sinh squared alpha.
#
# If you'd like me to convert other equations or explain any part of this equation in more detail, just ask!

# %%
instruction="""
Convert the equation images to LaTeX equations.
"""

messages = [
    {
        "role": "system",
        "content": [{"type": "text", "text": "You are a helpful assistant."}]
    },
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "/content/latex5.jpg"}, # Credit Simon Willison's blog for the choice here
            {"type": "text", "text": instruction}
        ]
    }
]

inputs = processor.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True,
    return_dict=True, return_tensors="pt"
).to(model.device, dtype=torch.bfloat16)

input_len = inputs["input_ids"].shape[-1]

with torch.inference_mode():
    generation = model.generate(**inputs, max_new_tokens=512, do_sample=False)
    generation = generation[0][input_len:]

decoded = processor.decode(generation, skip_special_tokens=True)
print(decoded)
# Out:
# Here's the LaTeX representation of the equations you provided:
#
# ```latex
# \begin{aligned}
# \lambda_R &= \frac{1}{3!} \frac{d^4 V(\phi)}{d\phi^4} \Big|_{\phi=0} \\
# &= \frac{\lambda}{1 + 3X I_{2}(m^2) [m^2]}
# \end{aligned}
# ```
#
# **Explanation:**
#
# *   `\begin{aligned} ... \end{aligned}`:  This environment is used to align equations vertically.
# *   `\frac{numerator}{denominator}`:  This creates a fraction.
# *   `\frac{d^4 V(\phi)}{d\phi^4}`:  This represents the fourth derivative of the potential V(φ).
# *   `\Big|_{\phi=0}`:  This indicates the value is evaluated at φ = 0.
# *   `\lambda`:  This represents the parameter lambda.
# *   `X I_{2}(m^2) [m^2]`:  This represents the term with the function $X I_2(m^2)$ and the square of $m$.
# *   `[m^2]`: This denotes the square of the mass $m$.
#
# If you'd like me to convert other equations or explain any part of this, just ask!

# %%
instruction="""
Convert the equation images to LaTeX equations.
"""

messages = [
    {
        "role": "system",
        "content": [{"type": "text", "text": "You are a helpful assistant."}]
    },
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "/content/latex6.jpg"}, # Credit Simon Willison's blog for the choice here
            {"type": "text", "text": instruction}
        ]
    }
]

inputs = processor.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True,
    return_dict=True, return_tensors="pt"
).to(model.device, dtype=torch.bfloat16)

input_len = inputs["input_ids"].shape[-1]

with torch.inference_mode():
    generation = model.generate(**inputs, max_new_tokens=512, do_sample=False)
    generation = generation[0][input_len:]

decoded = processor.decode(generation, skip_special_tokens=True)
print(decoded)
# Out:
# Here's the LaTeX representation of the equation you provided:
#
# ```latex
# E_{ij}(j2) = \left( -1 \right)^n \prod_{k=1}^{n} c_{k} E^{n}(j_1, \dots, j_n) + \text{other terms}
# ```
#
# **Explanation of the LaTeX code:**
#
# *   `E_{ij}(j2)`:  This represents the notation for the equation.
# *   `\left( -1 \right)^n`:  This denotes the negative sign raised to the power of n.
# *   `\prod_{k=1}^{n}`:  This is the product symbol, indicating a product from k=1 to n.
# *   `c_{k}`:  This represents a coefficient.
# *   `E^{n}(j_1, \dots, j_n)`:  This represents a term with a power of n.
# *   `\text{other terms}`:  This indicates that there are other terms in the equation that are not explicitly shown.
#
# If you'd like to convert other equations or have any questions about LaTeX, feel free to ask!

# %%
instruction="""
Convert the equation images to LaTeX equations.
"""

messages = [
    {
        "role": "system",
        "content": [{"type": "text", "text": "You are a helpful assistant."}]
    },
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "/content/latex7_test.jpg"}, # Credit Simon Willison's blog for the choice here
            {"type": "text", "text": instruction}
        ]
    }
]

inputs = processor.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True,
    return_dict=True, return_tensors="pt"
).to(model.device, dtype=torch.bfloat16)

input_len = inputs["input_ids"].shape[-1]

with torch.inference_mode():
    generation = model.generate(**inputs, max_new_tokens=512, do_sample=False)
    generation = generation[0][input_len:]

decoded = processor.decode(generation, skip_special_tokens=True)
print(decoded)
# Out:
# Here's the LaTeX representation of the equation you provided:
#
# ```latex
# \frac{1}{\pi^4} \int_{-\infty}^{\infty} d\phi^n(x) + \frac{1}{\pi^4} \int_{-\infty}^{\infty} d\phi^n(x) \quad n \geq 2
# ```
#
# **Explanation:**
#
# *   `\frac{1}{\pi^4}`:  Represents the fraction with 1 over pi to the power of 4.
# *   `\int_{-\infty}^{\infty}`:  Represents the integral from negative infinity to positive infinity.
# *   `d\phi^n(x)`:  Represents the differential of the function $\phi^n(x)$.
# *   `+`:  Represents the addition sign.
# *   `\quad`:  Adds a horizontal space for readability.
# *   `n \geq 2`:  Represents the inequality "n is greater than or equal to 2".
#
# If you'd like to convert other equations or have any questions about LaTeX, feel free to ask!
