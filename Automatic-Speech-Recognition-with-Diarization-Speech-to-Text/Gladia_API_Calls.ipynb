# %%
import requests
import pprint

# %%
HEADERS = {"x-gladia-key": "YOUR GLADIA KEY HERE"}

# %% [markdown]
# ## Upload data

# %%
data_upload_url = "https://api.gladia.io/v2/upload"

file_path = "/path/to/test/audio"

# Open the file in binary mode and send it
with open(file_path, "rb") as f:
    files = {
             "audio": ("test_audio.mp3", f, "audio/mpeg")
            }
    response = requests.post(url=data_upload_url, headers=HEADERS, files=files)

# %%
print(pprint.pformat(response.json(),sort_dicts=False))
# Out:
# {'audio_url': 'https://api.gladia.io/file/11e766ea-6ba6-4f96-bd2b-82754e6858cc',
#  'audio_metadata': {'id': '11e766ea-6ba6-4f96-bd2b-82754e6858cc',
#                     'filename': 'test_audio.mp3',
#                     'extension': 'mp3',
#                     'size': 3515416,
#                     'audio_duration': 169.896,
#                     'number_of_channels': 2}}

# %%
audio_id = response.json()['items'][0]['file']['id']
audio_id  #Get the audio id of the test upload
# Out:
# '11e766ea-6ba6-4f96-bd2b-82754e6858cc'

# %% [markdown]
# ## Perform Transcription

# %%
transcribe_URL = "https://api.gladia.io/v2/transcription"

HEADERS_TRANSCRIBE = {
    "x-gladia-key": "SAME GALDIA API KEY HERE",
    "Content-Type": "application/json"}

data = {
    "audio_url": f"https://api.gladia.io/file/{audio_id}",
    "diarization": True,
    "diarization_config": {
      "number_of_speakers": 2,
      "min_speakers": 1,
      "max_speakers": 5
        },
    "translation": True,
    "translation_config": {
      "model": "base",
      "target_languages": ["en"]
        },
    "subtitles": True,
    "subtitles_config": {
      "formats": ["srt"]
        },
    "detect_language": True,
    "enable_code_switching": False
    }

# %%
response = requests.post(url=transcribe_URL, headers=HEADERS_TRANSCRIBE, json=data)

print(pprint.pformat(response.json(),sort_dicts=False))
# Out:
# {'id': 'e6a2da6a-30c1-44e2-9145-b3c395ace544',
#  'result_url': 'https://api.gladia.io/v2/transcription/e6a2da6a-30c1-44e2-9145-b3c395ace544'}

# %% [markdown]
# ## Get List of Transcriptions

# %%
get_transcription_url = "https://api.gladia.io/v2/transcription"

response = requests.get(url=get_transcription_url, headers=HEADERS)

data = response.json()
# print(response.json())

# %%
print(pprint.pformat(data,sort_dicts=False))
# Out:
# {'items': [{'id': 'e6a2da6a-30c1-44e2-9145-b3c395ace544',
#             'request_id': 'G-e6a2da6a',
#             'kind': 'pre-recorded',
#             'status': 'processing',
#             'created_at': '2024-05-15T07:42:08.794Z',
#             'file': {'id': '11e766ea-6ba6-4f96-bd2b-82754e6858cc',
#                      'filename': 'test_audio.mp3',
#                      'source': None,
#                      'audio_duration': 169.896,
#                      'number_of_channels': 2},
#             'request_params': {'audio_url': 'https://api.gladia.io/file/11e766ea-6ba6-4f96-bd2b-82754e6858cc',
#                                'diarization': True,
#                                'diarization_config': {'max_speakers': 5,
#                                                       'min_speakers': 1,
#                                                       'number_of_speakers': 2},
#                                'subtitles': True,
#                                'subtitles_config': {'formats': ['srt']},
#                                'translation': True,
#                                'translation_config': {'model': 'base',
#                                                       'target_languages': ['en']}}},
#            {'id': '0632e41b-ddb2-43af-81db-e619e224b4c0',
#             'request_id': 'G-0632e41b',
#             'kind': 'pre-recorded',
#             'status': 'done',
#             'created_at': '2024-05-15T04:33:20.491Z',
#             'completed_at': '2024-05-15T04:33:47.522Z',
#             'file': {'id': '11e766ea-6ba6-4f96-bd2b-82754e6858cc',
#                      'filename': 'test_audio.mp3',
#                      'source': None,
#                      'audio_duration': 169.896,
#                      'number_of_channels': 2},
#             'request_params': {'audio_url': 'https://api.gladia.io/file/11e766ea-6ba6-4f96-bd2b-82754e6858cc'},
#             'result': {'metadata': {'audio_duration': 169.884979,
#                                     'number_of_distinct_channels': 1,
#                                     'billing_time': 169.884979,
#                                     'transcription_time': 27.031}}},
#            {'id': '94a7bb7c-c579-48f9-b09d-de038e2fec9f',
#             'request_id': 'G-94a7bb7c',
#             'kind': 'pre-recorded',
#             'status': 'done',
#             'created_at': '2024-05-15T04:04:31.579Z',
#             'completed_at': '2024-05-15T04:05:07.957Z',
#             'file': {'id': '11e766ea-6ba6-4f96-bd2b-82754e6858cc',
#                      'filename': 'test_audio.mp3',
#                      'source': None,
#                      'audio_duration': 169.896,
#                      'number_of_channels': 2},
#             'request_params': {'audio_url': 'https://api.gladia.io/file/11e766ea-6ba6-4f96-bd2b-82754e6858cc',
#                                'diarization': True,
#                                'diarization_config': {'max_speakers': 5,
#                                                       'min_speakers': 1,
#                                                       'number_of_speakers': 3},
#                                'subtitles': True,
#                                'subtitles_config': {'formats': ['srt']},
#                                'translation': True,
#                                'translation_config': {'model': 'base',
#                                                       'target_languages': ['en']}},
#             'result': {'metadata': {'audio_duration': 169.884979,
#                                     'number_of_distinct_channels': 1,
#                                     'billing_time': 169.884979,
#                                     'transcription_time': 36.378}}},
#            {'id': '3b6caf33-4bcc-4b3c-916f-b48dfbb80717',
#             'request_id': 'G-3b6caf33',
#             'kind': 'pre-recorded',
#             'status': 'done',
#             'created_at': '2024-05-05T06:35:18.271Z',
#             'completed_at': '2024-05-05T06:37:07.554Z',
#             'file': {'id': 'fb0fd100-42be-4879-b059-ea6272c15137',
#                      'filename': 'Hitesh.mp3',
#                      'source': None,
#                      'audio_duration': 1289.18,
#                      'number_of_channels': 2},
#             'request_params': {'audio_url': 'https://api.gladia.io/file/fb0fd100-42be-4879-b059-ea6272c15137',
#                                'diarization': True},
#             'result': {'metadata': {'audio_duration': 1289.18,
#                                     'number_of_distinct_channels': 2,
#                                     'billing_time': 2578.36,
#                                     'transcription_time': 109.283}}},
#            {'id': '7aacefcb-c4d9-469f-900b-f7fb129b1677',
#             'request_id': 'G-7aacefcb',
#             'kind': 'pre-recorded',
#             'status': 'done',
#             'created_at': '2024-05-03T07:43:29.954Z',
#             'completed_at': '2024-05-03T07:44:35.960Z',
#             'file': {'id': '8c45b9af-638e-463b-9dce-9f649ecd796f',
#                      'filename': 'Opencv-Sourav.wav',
#                      'source': None,
#                      'audio_duration': 203.6,
#                      'number_of_channels': 2},
#             'request_params': {'audio_url': 'https://api.gladia.io/file/8c45b9af-638e-463b-9dce-9f649ecd796f',
#                                'diarization': True},
#             'result': {'metadata': {'audio_duration': 203.6,
#                                     'number_of_distinct_channels': 2,
#                                     'billing_time': 407.2,
#                                     'transcription_time': 66.006}}},
#            {'id': '921a7928-bca5-4484-bb77-e35c4f4cef61',
#             'request_id': 'G-921a7928',
#             'kind': 'pre-recorded',
#             'status': 'done',
#             'created_at': '2024-05-03T07:31:58.375Z',
#             'completed_at': '2024-05-03T07:35:31.431Z',
#             'file': {'id': '64e279d1-6a7b-4b53-b5be-b81dcc3dd15b',
#                      'filename': 'Hitesh.mp3',
#                      'source': None,
#                      'audio_duration': 1289.18,
#                      'number_of_channels': 2},
#             'request_params': {'audio_url': 'https://api.gladia.io/file/64e279d1-6a7b-4b53-b5be-b81dcc3dd15b',
#                                'diarization': True},
#             'result': {'metadata': {'audio_duration': 1289.18,
#                                     'number_of_distinct_channels': 2,
#                                     'billing_time': 2578.36,
#                                     'transcription_time': 213.056}}}],
#  'first': 'https://api.gladia.io/v2/transcription?offset=0&limit=20',
#  'current': 'https://api.gladia.io/v2/transcription?offset=0&limit=20',
#  'next': None}

# %% [markdown]
# ## Show Transcription

# %%
TRANSCRIPTION_ID = data['items'][0]['id']

URL = f"https://api.gladia.io/v2/transcription/{TRANSCRIPTION_ID}"

response_results = requests.get(url=URL, headers=HEADERS)

# %%
results_data = response_results.json()

# %%
results_data.get("result",{})
# Out:
# {'metadata': {'audio_duration': 169.884979,
#   'number_of_distinct_channels': 1,
#   'billing_time': 169.884979,
#   'transcription_time': 30.175},
#  'transcription': {'utterances': [{'words': [{'word': "I'm",
#       'start': 1.16573,
#       'end': 1.28633,
#       'confidence': 0.33},
#      {'word': ' going', 'start': 1.30643, 'end': 1.46724, 'confidence': 0.43},
#      {'word': ' to', 'start': 1.46724, 'end': 1.58784, 'confidence': 0.25},
#      {'word': ' introduce',
#       'start': 1.62804,
#       'end': 2.05015,
#       'confidence': 0.71},
#      {'word': ' you', 'start': 2.05015, 'end': 2.13055, 'confidence': 0.02},
#      {'word': ' to', 'start': 2.13055, 'end': 2.25116, 'confidence': 0.51},
#      {'word': ' a', 'start': 2.49236, 'end': 2.61296, 'confidence': 0.99},
#      {'word': ' rather', 'start': 2.63307, 'end': 2.89437, 'confidence': 0.46},
#      {'word': ' remarkable',
#       'start': 2.93457,
#       'end': 3.45719,
#       'confidence': 0.76},
#      {'word': ' man.', 'start': 3.55769, 'end': 3.75869, 'confidence': 0.96}],
#     'text': "I'm going to introduce you to a rather remarkable man.",
#     'language': 'en',
#     'start': 1.16573,
#     'end': 3.75869,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': " He's",
#       'start': 4.562709999999999,
#       'end': 4.7034199999999995,
#       'confidence': 0.27},
#      {'word': ' Mr',
#       'start': 4.74362,
#       'end': 4.984819999999999,
#       'confidence': 0.94},
#      {'word': ' Michael',
#       'start': 5.025029999999999,
#       'end': 5.26623,
#       'confidence': 0.56},
#      {'word': ' Fitzpatrick',
#       'start': 5.306430000000001,
#       'end': 5.90945,
#       'confidence': 0.6},
#      {'word': ' from',
#       'start': 5.9697499999999994,
#       'end': 6.1305499999999995,
#       'confidence': 0.43},
#      {'word': ' Killenie,',
#       'start': 6.27126,
#       'end': 6.63307,
#       'confidence': 0.48}],
#     'text': "He's Mr Michael Fitzpatrick from Killenie,",
#     'language': 'en',
#     'start': 4.562709999999999,
#     'end': 6.63307,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Maynooth.',
#       'start': 7.11548,
#       'end': 7.47729,
#       'confidence': 0.5}],
#     'text': 'Maynooth.',
#     'language': 'en',
#     'start': 7.11548,
#     'end': 7.47729,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Now,',
#       'start': 8.60233,
#       'end': 8.78305,
#       'confidence': 0.77}],
#     'text': 'Now,',
#     'language': 'en',
#     'start': 8.60233,
#     'end': 8.78305,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' he',
#       'start': 9.967789999999999,
#       'end': 10.08827,
#       'confidence': 0.93},
#      {'word': ' started',
#       'start': 10.16859,
#       'end': 10.48988,
#       'confidence': 0.91},
#      {'word': ' to', 'start': 10.53004, 'end': 10.65052, 'confidence': 0.99},
#      {'word': ' draw',
#       'start': 10.95173,
#       'end': 11.132449999999999,
#       'confidence': 0.96},
#      {'word': ' the',
#       'start': 11.152529999999999,
#       'end': 11.27301,
#       'confidence': 0.92},
#      {'word': ' old', 'start': 11.37341, 'end': 11.53406, 'confidence': 0.5},
#      {'word': ' age', 'start': 11.5943, 'end': 11.7951, 'confidence': 0.61},
#      {'word': ' pension',
#       'start': 11.83526,
#       'end': 12.15655,
#       'confidence': 0.96},
#      {'word': ' in', 'start': 12.15655, 'end': 12.19671, 'confidence': 0},
#      {'word': ' 1927', 'start': 12.19671, 'end': 13.02, 'confidence': 0.05},
#      {'word': ' and', 'start': 13.88298, 'end': 14.08367, 'confidence': 0.99},
#      {'word': ' seven',
#       'start': 14.545259999999999,
#       'end': 14.78609,
#       'confidence': 0.93},
#      {'word': ' years',
#       'start': 14.826229999999999,
#       'end': 15.02692,
#       'confidence': 0.96},
#      {'word': ' ago', 'start': 15.04699, 'end': 15.18747, 'confidence': 1},
#      {'word': ' he',
#       'start': 15.388169999999999,
#       'end': 15.508579999999998,
#       'confidence': 0.97},
#      {'word': ' got', 'start': 15.56879, 'end': 15.70927, 'confidence': 0.86},
#      {'word': ' the', 'start': 15.74941, 'end': 15.86983, 'confidence': 0.43},
#      {'word': " President's",
#       'start': 16.03038,
#       'end': 16.45183,
#       'confidence': 0.87},
#      {'word': ' bounty',
#       'start': 16.49197,
#       'end': 16.79301,
#       'confidence': 0.42},
#      {'word': ' on', 'start': 17.57571, 'end': 17.69612, 'confidence': 0.55},
#      {'word': ' his', 'start': 17.75633, 'end': 17.89682, 'confidence': 0.98},
#      {'word': ' hundredth',
#       'start': 17.93696,
#       'end': 18.21792,
#       'confidence': 0.43},
#      {'word': ' birthday.',
#       'start': 18.23799,
#       'end': 18.599239999999998,
#       'confidence': 0.47}],
#     'text': "he started to draw the old age pension in 1927 and seven years ago he got the President's bounty on his hundredth birthday.",
#     'language': 'en',
#     'start': 9.967789999999999,
#     'end': 18.599239999999998,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Now',
#       'start': 19.65056,
#       'end': 20.03145,
#       'confidence': 0.4},
#      {'word': " he's", 'start': 20.03145, 'end': 20.19182, 'confidence': 0.51},
#      {'word': ' from',
#       'start': 20.23192,
#       'end': 20.372239999999998,
#       'confidence': 0.99},
#      {'word': ' County',
#       'start': 20.412339999999997,
#       'end': 20.672939999999997,
#       'confidence': 0.82},
#      {'word': ' Clare.',
#       'start': 20.773169999999997,
#       'end': 21.11397,
#       'confidence': 0.52}],
#     'text': "Now he's from County Clare.",
#     'language': 'en',
#     'start': 19.65056,
#     'end': 21.11397,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' He',
#       'start': 22.036109999999997,
#       'end': 22.15639,
#       'confidence': 0.75},
#      {'word': ' came',
#       'start': 22.196479999999998,
#       'end': 22.396949999999997,
#       'confidence': 0.56},
#      {'word': ' up',
#       'start': 22.396949999999997,
#       'end': 22.517229999999998,
#       'confidence': 0.9},
#      {'word': ' from',
#       'start': 22.657559999999997,
#       'end': 22.91816,
#       'confidence': 0.62},
#      {'word': ' Clare',
#       'start': 23.238909999999997,
#       'end': 23.37924,
#       'confidence': 0.32},
#      {'word': ' in', 'start': 23.37924, 'end': 23.43938, 'confidence': 0.04},
#      {'word': ' 1940',
#       'start': 23.459419999999998,
#       'end': 24.90278,
#       'confidence': 0.03},
#      {'word': ' to',
#       'start': 25.06315,
#       'end': 25.183429999999998,
#       'confidence': 0.71},
#      {'word': ' a',
#       'start': 25.30371,
#       'end': 25.423989999999996,
#       'confidence': 0.97},
#      {'word': ' land',
#       'start': 25.444039999999998,
#       'end': 25.62446,
#       'confidence': 0.74},
#      {'word': ' commission',
#       'start': 25.66455,
#       'end': 25.9853,
#       'confidence': 0.9},
#      {'word': ' farm',
#       'start': 26.04544,
#       'end': 26.326089999999997,
#       'confidence': 0.98},
#      {'word': ' in',
#       'start': 27.007669999999997,
#       'end': 27.12795,
#       'confidence': 0.02},
#      {'word': ' Maynooth',
#       'start': 27.309189999999997,
#       'end': 28.09496,
#       'confidence': 0.46},
#      {'word': ' where',
#       'start': 28.115109999999998,
#       'end': 28.296439999999997,
#       'confidence': 0.24},
#      {'word': ' he',
#       'start': 28.296439999999997,
#       'end': 28.41733,
#       'confidence': 0.53},
#      {'word': ' lives',
#       'start': 28.477779999999996,
#       'end': 28.69941,
#       'confidence': 0.52},
#      {'word': ' now.',
#       'start': 28.779999999999998,
#       'end': 28.921039999999998,
#       'confidence': 0.62}],
#     'text': 'He came up from Clare in 1940 to a land commission farm in Maynooth where he lives now.',
#     'language': 'en',
#     'start': 22.036109999999997,
#     'end': 28.921039999999998,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' You',
#       'start': 29.868,
#       'end': 29.98845,
#       'confidence': 0.74},
#      {'word': ' have',
#       'start': 30.008519999999997,
#       'end': 30.20926,
#       'confidence': 0.87},
#      {'word': ' seen',
#       'start': 30.430079999999997,
#       'end': 30.670969999999997,
#       'confidence': 1},
#      {'word': ' a', 'start': 30.91187, 'end': 31.03231, 'confidence': 0.98},
#      {'word': ' lot',
#       'start': 31.05239,
#       'end': 31.192909999999998,
#       'confidence': 0.99},
#      {'word': ' of',
#       'start': 31.192909999999998,
#       'end': 31.31335,
#       'confidence': 0.97},
#      {'word': ' changes',
#       'start': 31.353499999999997,
#       'end': 31.81521,
#       'confidence': 0.98},
#      {'word': ' Mr', 'start': 31.91558, 'end': 32.09625, 'confidence': 0.7},
#      {'word': ' Fitzpatrick',
#       'start': 32.136399999999995,
#       'end': 32.65833,
#       'confidence': 0.5},
#      {'word': ' in',
#       'start': 32.75871,
#       'end': 32.879149999999996,
#       'confidence': 0.97},
#      {'word': ' farming.',
#       'start': 32.97952,
#       'end': 33.401089999999996,
#       'confidence': 0.98}],
#     'text': 'You have seen a lot of changes Mr Fitzpatrick in farming.',
#     'language': 'en',
#     'start': 29.868,
#     'end': 33.401089999999996,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' What',
#       'start': 34.16391,
#       'end': 34.304429999999996,
#       'confidence': 0.73},
#      {'word': ' would',
#       'start': 34.304429999999996,
#       'end': 34.42488,
#       'confidence': 0.27},
#      {'word': ' you', 'start': 34.42488, 'end': 34.54532, 'confidence': 0.42},
#      {'word': ' say',
#       'start': 34.58547,
#       'end': 34.725989999999996,
#       'confidence': 0.86},
#      {'word': ' was',
#       'start': 34.76613999999999,
#       'end': 34.88659,
#       'confidence': 0.67},
#      {'word': ' the',
#       'start': 34.86651,
#       'end': 34.986959999999996,
#       'confidence': 0.5},
#      {'word': ' biggest',
#       'start': 35.00703,
#       'end': 35.24793,
#       'confidence': 0.82},
#      {'word': ' change?',
#       'start': 35.28841,
#       'end': 35.73739,
#       'confidence': 0.22}],
#     'text': 'What would you say was the biggest change?',
#     'language': 'en',
#     'start': 34.16391,
#     'end': 35.73739,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Well',
#       'start': 36.268,
#       'end': 36.39045,
#       'confidence': 0.34},
#      {'word': ' machinery.',
#       'start': 36.43127,
#       'end': 36.98228999999999,
#       'confidence': 0.21}],
#     'text': 'Well machinery.',
#     'language': 'en',
#     'start': 36.268,
#     'end': 36.98228999999999,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' And',
#       'start': 37.93065,
#       'end': 38.05113,
#       'confidence': 0.98},
#      {'word': ' what',
#       'start': 38.111369999999994,
#       'end': 38.25194,
#       'confidence': 0.9},
#      {'word': ' sort', 'start': 38.31218, 'end': 38.51298, 'confidence': 0.99},
#      {'word': ' of',
#       'start': 38.51298,
#       'end': 38.61337999999999,
#       'confidence': 0.98},
#      {'word': ' a', 'start': 38.5933, 'end': 38.67362, 'confidence': 0.98},
#      {'word': ' machine',
#       'start': 38.69369999999999,
#       'end': 39.11539,
#       'confidence': 0.85},
#      {'word': ' would',
#       'start': 40.340289999999996,
#       'end': 40.46077,
#       'confidence': 0.27},
#      {'word': ' you', 'start': 40.46077, 'end': 40.56117, 'confidence': 0.04},
#      {'word': ' think', 'start': 40.56117, 'end': 40.7419, 'confidence': 0.85},
#      {'word': ' made',
#       'start': 40.882459999999995,
#       'end': 41.043099999999995,
#       'confidence': 0.91},
#      {'word': ' the',
#       'start': 41.043099999999995,
#       'end': 41.143499999999996,
#       'confidence': 0.93},
#      {'word': ' biggest',
#       'start': 41.143499999999996,
#       'end': 41.40455,
#       'confidence': 0.99},
#      {'word': ' impression?',
#       'start': 41.44471,
#       'end': 41.866389999999996,
#       'confidence': 0.97}],
#     'text': 'And what sort of a machine would you think made the biggest impression?',
#     'language': 'en',
#     'start': 37.93065,
#     'end': 41.866389999999996,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Well,',
#       'start': 42.268,
#       'end': 42.369249999999994,
#       'confidence': 0.01}],
#     'text': 'Well,',
#     'language': 'en',
#     'start': 42.268,
#     'end': 42.369249999999994,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' I',
#       'start': 42.369249999999994,
#       'end': 42.3895,
#       'confidence': 0.01},
#      {'word': ' think', 'start': 42.3895, 'end': 42.49075, 'confidence': 0.01},
#      {'word': ' it', 'start': 42.49075, 'end': 42.53125, 'confidence': 0.02},
#      {'word': ' was', 'start': 42.53125, 'end': 42.592, 'confidence': 0.01},
#      {'word': ' the', 'start': 42.592, 'end': 42.65275, 'confidence': 0.01},
#      {'word': ' most', 'start': 42.65275, 'end': 42.73375, 'confidence': 0.01},
#      {'word': ' powerful',
#       'start': 42.73375,
#       'end': 42.89574999999999,
#       'confidence': 0.01}],
#     'text': 'I think it was the most powerful',
#     'language': 'en',
#     'start': 42.369249999999994,
#     'end': 42.89574999999999,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' Well,',
#       'start': 43.169560000000004,
#       'end': 43.290890000000005,
#       'confidence': 0.44}],
#     'text': 'Well,',
#     'language': 'en',
#     'start': 43.169560000000004,
#     'end': 43.290890000000005,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' the',
#       'start': 43.290890000000005,
#       'end': 43.412220000000005,
#       'confidence': 0.09},
#      {'word': ' reaper',
#       'start': 43.452670000000005,
#       'end': 43.75600000000001,
#       'confidence': 0.6},
#      {'word': ' and',
#       'start': 43.796440000000004,
#       'end': 43.91778000000001,
#       'confidence': 0.42},
#      {'word': ' binder', 'start': 43.938, 'end': 44.26156, 'confidence': 0.71},
#      {'word': ' is', 'start': 44.26156, 'end': 44.34244, 'confidence': 0.02},
#      {'word': ' a',
#       'start': 44.32222000000001,
#       'end': 44.403110000000005,
#       'confidence': 0.21},
#      {'word': ' great',
#       'start': 44.42333000000001,
#       'end': 44.686220000000006,
#       'confidence': 0.47},
#      {'word': ' one,',
#       'start': 44.70644000000001,
#       'end': 44.827780000000004,
#       'confidence': 0.33}],
#     'text': 'the reaper and binder is a great one,',
#     'language': 'en',
#     'start': 43.290890000000005,
#     'end': 44.827780000000004,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' but,',
#       'start': 45.248000000000005,
#       'end': 45.36892,
#       'confidence': 0.41}],
#     'text': 'but,',
#     'language': 'en',
#     'start': 45.248000000000005,
#     'end': 45.36892,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' by',
#       'start': 45.42938000000001,
#       'end': 45.55031,
#       'confidence': 0.44},
#      {'word': ' God,',
#       'start': 45.61077,
#       'end': 45.772000000000006,
#       'confidence': 0.09}],
#     'text': 'by God,',
#     'language': 'en',
#     'start': 45.42938000000001,
#     'end': 45.772000000000006,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' the',
#       'start': 46.154920000000004,
#       'end': 46.275850000000005,
#       'confidence': 0.17},
#      {'word': ' one',
#       'start': 46.356460000000006,
#       'end': 46.49754000000001,
#       'confidence': 0.25},
#      {'word': ' for',
#       'start': 46.51769000000001,
#       'end': 46.658770000000004,
#       'confidence': 0.27},
#      {'word': ' cutting',
#       'start': 47.06185000000001,
#       'end': 47.36415000000001,
#       'confidence': 0.18},
#      {'word': ' up',
#       'start': 47.36415000000001,
#       'end': 47.48508,
#       'confidence': 0.12},
#      {'word': ' the',
#       'start': 47.48508,
#       'end': 47.60600000000001,
#       'confidence': 0.26},
#      {'word': ' ground',
#       'start': 47.62615000000001,
#       'end': 47.86800000000001,
#       'confidence': 0.3},
#      {'word': ' and',
#       'start': 47.92850000000001,
#       'end': 48.049490000000006,
#       'confidence': 0.15},
#      {'word': ' throwing',
#       'start': 48.33180000000001,
#       'end': 48.59395000000001,
#       'confidence': 0.26},
#      {'word': ' a',
#       'start': 48.59395000000001,
#       'end': 48.654450000000004,
#       'confidence': 0.31},
#      {'word': ' crop',
#       'start': 48.67461000000001,
#       'end': 48.89643000000001,
#       'confidence': 0.49},
#      {'word': ' is',
#       'start': 49.319900000000004,
#       'end': 49.44089,
#       'confidence': 0.37},
#      {'word': ' a',
#       'start': 49.44089,
#       'end': 49.541720000000005,
#       'confidence': 0.55},
#      {'word': ' powerful',
#       'start': 49.56188,
#       'end': 49.94502000000001,
#       'confidence': 0.18},
#      {'word': ' one',
#       'start': 49.98536000000001,
#       'end': 50.12651,
#       'confidence': 0.21},
#      {'word': ' too.',
#       'start': 50.16684000000001,
#       'end': 50.30800000000001,
#       'confidence': 0.13}],
#     'text': 'the one for cutting up the ground and throwing a crop is a powerful one too.',
#     'language': 'en',
#     'start': 46.154920000000004,
#     'end': 50.30800000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' Well,',
#       'start': 51.28952000000001,
#       'end': 51.43019000000001,
#       'confidence': 0.17}],
#     'text': 'Well,',
#     'language': 'en',
#     'start': 51.28952000000001,
#     'end': 51.43019000000001,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' you',
#       'start': 51.87229000000001,
#       'end': 51.99286000000001,
#       'confidence': 0.55},
#      {'word': ' were',
#       'start': 51.99286000000001,
#       'end': 52.11343000000001,
#       'confidence': 0.57},
#      {'word': ' saying',
#       'start': 52.133520000000004,
#       'end': 52.394760000000005,
#       'confidence': 0.7},
#      {'word': ' at',
#       'start': 52.997620000000005,
#       'end': 53.118190000000006,
#       'confidence': 0.37},
#      {'word': ' the', 'start': 53.0981, 'end': 53.21867, 'confidence': 0.24},
#      {'word': ' time',
#       'start': 53.238760000000006,
#       'end': 53.47990000000001,
#       'confidence': 0.94},
#      {'word': ' you',
#       'start': 53.47990000000001,
#       'end': 53.600480000000005,
#       'confidence': 0.73},
#      {'word': ' saw',
#       'start': 53.66076000000001,
#       'end': 53.86171,
#       'confidence': 0.63},
#      {'word': ' the', 'start': 53.88181, 'end': 54.00238, 'confidence': 0.09},
#      {'word': ' mowing',
#       'start': 54.042570000000005,
#       'end': 54.283710000000006,
#       'confidence': 0.36},
#      {'word': ' machine',
#       'start': 54.303810000000006,
#       'end': 54.70571000000001,
#       'confidence': 0.49},
#      {'word': ' first,',
#       'start': 54.98705000000001,
#       'end': 55.188,
#       'confidence': 0.3}],
#     'text': 'you were saying at the time you saw the mowing machine first,',
#     'language': 'en',
#     'start': 51.87229000000001,
#     'end': 55.188,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' it',
#       'start': 55.89160000000001,
#       'end': 56.01294000000001,
#       'confidence': 0.94},
#      {'word': ' made',
#       'start': 56.073620000000005,
#       'end': 56.235420000000005,
#       'confidence': 0.93},
#      {'word': ' a',
#       'start': 56.235420000000005,
#       'end': 56.31631000000001,
#       'confidence': 0.97},
#      {'word': ' tremendous',
#       'start': 56.31631000000001,
#       'end': 56.72081000000001,
#       'confidence': 0.9},
#      {'word': ' impression',
#       'start': 56.76126000000001,
#       'end': 57.12530000000001,
#       'confidence': 0.96},
#      {'word': ' on',
#       'start': 57.14553000000001,
#       'end': 57.26688000000001,
#       'confidence': 0.99},
#      {'word': ' you.',
#       'start': 57.24665,
#       'end': 57.36800000000001,
#       'confidence': 0.9}],
#     'text': 'it made a tremendous impression on you.',
#     'language': 'en',
#     'start': 55.89160000000001,
#     'end': 57.36800000000001,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' It',
#       'start': 57.428000000000004,
#       'end': 57.54869000000001,
#       'confidence': 0.03},
#      {'word': ' did,',
#       'start': 57.568810000000006,
#       'end': 57.74985000000001,
#       'confidence': 0.28}],
#     'text': 'It did,',
#     'language': 'en',
#     'start': 57.428000000000004,
#     'end': 57.74985000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' because',
#       'start': 58.25274,
#       'end': 58.61482000000001,
#       'confidence': 0.27},
#      {'word': ' I',
#       'start': 58.61482000000001,
#       'end': 58.67517000000001,
#       'confidence': 0.01},
#      {'word': " didn't",
#       'start': 58.67517000000001,
#       'end': 59.07748000000001,
#       'confidence': 0.26},
#      {'word': ' know',
#       'start': 59.13783000000001,
#       'end': 59.359100000000005,
#       'confidence': 0.14},
#      {'word': ' how',
#       'start': 59.761410000000005,
#       'end': 59.88210000000001,
#       'confidence': 0.31},
#      {'word': ' it',
#       'start': 59.88210000000001,
#       'end': 59.94245000000001,
#       'confidence': 0},
#      {'word': ' could',
#       'start': 59.94245000000001,
#       'end': 60.24418000000001,
#       'confidence': 0.19},
#      {'word': ' be',
#       'start': 60.24418000000001,
#       'end': 60.34476000000001,
#       'confidence': 0.02},
#      {'word': ' done', 'start': 60.38499, 'end': 60.58615, 'confidence': 0.42},
#      {'word': ' at',
#       'start': 60.58615,
#       'end': 60.686730000000004,
#       'confidence': 0.04},
#      {'word': ' all.',
#       'start': 60.70684000000001,
#       'end': 60.88788000000001,
#       'confidence': 0.28}],
#     'text': "because I didn't know how it could be done at all.",
#     'language': 'en',
#     'start': 58.25274,
#     'end': 60.88788000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' What',
#       'start': 62.40934000000001,
#       'end': 62.57016000000001,
#       'confidence': 0.3},
#      {'word': ' was',
#       'start': 62.57016000000001,
#       'end': 62.690780000000004,
#       'confidence': 0.4},
#      {'word': ' the',
#       'start': 63.13305000000001,
#       'end': 63.25367000000001,
#       'confidence': 0.59},
#      {'word': ' reaction',
#       'start': 63.4748,
#       'end': 64.05779000000001,
#       'confidence': 0.98},
#      {'word': ' of',
#       'start': 64.25882000000001,
#       'end': 64.37944,
#       'confidence': 0.99},
#      {'word': ' the', 'start': 64.43975, 'end': 64.56037, 'confidence': 0.91},
#      {'word': ' people',
#       'start': 65.06295,
#       'end': 65.4047,
#       'confidence': 0.95},
#      {'word': ' at',
#       'start': 65.48511,
#       'end': 65.60573000000001,
#       'confidence': 0.83},
#      {'word': ' that',
#       'start': 65.60573000000001,
#       'end': 65.74645000000001,
#       'confidence': 0.81},
#      {'word': ' time',
#       'start': 65.80676000000001,
#       'end': 66.048,
#       'confidence': 0.87},
#      {'word': ' to',
#       'start': 66.06836000000001,
#       'end': 66.1905,
#       'confidence': 0.24},
#      {'word': ' the',
#       'start': 66.17014,
#       'end': 66.29229000000001,
#       'confidence': 0.03},
#      {'word': ' mowing',
#       'start': 66.29229000000001,
#       'end': 66.49586000000001,
#       'confidence': 0.18},
#      {'word': ' machine,',
#       'start': 66.49586000000001,
#       'end': 66.82157000000001,
#       'confidence': 0.28}],
#     'text': 'What was the reaction of the people at that time to the mowing machine,',
#     'language': 'en',
#     'start': 62.40934000000001,
#     'end': 66.82157000000001,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Mr.',
#       'start': 66.82157000000001,
#       'end': 66.903,
#       'confidence': 0.15}],
#     'text': 'Mr.',
#     'language': 'en',
#     'start': 66.82157000000001,
#     'end': 66.903,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Scott?',
#       'start': 66.903,
#       'end': 67.06586,
#       'confidence': 0.1}],
#     'text': 'Scott?',
#     'language': 'en',
#     'start': 66.903,
#     'end': 67.06586,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' I',
#       'start': 67.188,
#       'end': 67.20822000000001,
#       'confidence': 0.02},
#      {'word': ' had',
#       'start': 67.20822000000001,
#       'end': 67.26889,
#       'confidence': 0.03},
#      {'word': ' great',
#       'start': 67.26889,
#       'end': 67.47111000000001,
#       'confidence': 0.32},
#      {'word': ' money,',
#       'start': 67.57222,
#       'end': 67.83511000000001,
#       'confidence': 0.47}],
#     'text': 'I had great money,',
#     'language': 'en',
#     'start': 67.188,
#     'end': 67.83511000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' but',
#       'start': 67.85533000000001,
#       'end': 68.03733,
#       'confidence': 0.26},
#      {'word': ' I', 'start': 68.03733, 'end': 68.07778, 'confidence': 0.01},
#      {'word': " wasn't",
#       'start': 68.07778,
#       'end': 68.42156,
#       'confidence': 0.29},
#      {'word': ' minding',
#       'start': 68.52267,
#       'end': 68.88667000000001,
#       'confidence': 0.29},
#      {'word': ' it.',
#       'start': 68.88667000000001,
#       'end': 69.00800000000001,
#       'confidence': 0.05}],
#     'text': "but I wasn't minding it.",
#     'language': 'en',
#     'start': 67.85533000000001,
#     'end': 69.00800000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' I',
#       'start': 69.12800000000001,
#       'end': 69.14812,
#       'confidence': 0.01},
#      {'word': ' could',
#       'start': 69.14812,
#       'end': 69.30909000000001,
#       'confidence': 0.06},
#      {'word': ' afford',
#       'start': 69.32921,
#       'end': 69.73164,
#       'confidence': 0.46},
#      {'word': ' it,',
#       'start': 69.75176,
#       'end': 69.87248000000001,
#       'confidence': 0.26}],
#     'text': 'I could afford it,',
#     'language': 'en',
#     'start': 69.12800000000001,
#     'end': 69.87248000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' but',
#       'start': 69.89261,
#       'end': 70.01333000000001,
#       'confidence': 0.31},
#      {'word': ' the',
#       'start': 69.99321,
#       'end': 70.11394000000001,
#       'confidence': 0.24},
#      {'word': ' mowing',
#       'start': 70.29503000000001,
#       'end': 71.52242000000001,
#       'confidence': 0.34},
#      {'word': ' got',
#       'start': 71.98521000000001,
#       'end': 72.14618000000002,
#       'confidence': 0.57},
#      {'word': ' at',
#       'start': 72.18642,
#       'end': 72.30715000000001,
#       'confidence': 0.41},
#      {'word': ' it.',
#       'start': 72.32727,
#       'end': 72.44800000000001,
#       'confidence': 0.49}],
#     'text': 'but the mowing got at it.',
#     'language': 'en',
#     'start': 69.89261,
#     'end': 72.44800000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' And',
#       'start': 73.721,
#       'end': 73.84154000000001,
#       'confidence': 0.83},
#      {'word': ' some', 'start': 73.92189, 'end': 74.1027, 'confidence': 0.88},
#      {'word': ' of',
#       'start': 74.1027,
#       'end': 74.18305000000001,
#       'confidence': 0.04},
#      {'word': ' them',
#       'start': 74.18305000000001,
#       'end': 74.30359,
#       'confidence': 0.8},
#      {'word': ' I',
#       'start': 74.32368000000001,
#       'end': 74.44421,
#       'confidence': 1},
#      {'word': ' think',
#       'start': 74.46430000000001,
#       'end': 74.64511,
#       'confidence': 0.93},
#      {'word': ' you', 'start': 74.64511, 'end': 74.76564, 'confidence': 0.89},
#      {'word': ' told', 'start': 74.78573, 'end': 74.98662, 'confidence': 0.58},
#      {'word': ' me', 'start': 75.00671, 'end': 75.12725, 'confidence': 0.98},
#      {'word': " wouldn't",
#       'start': 75.83038,
#       'end': 76.07145,
#       'confidence': 0.76},
#      {'word': ' have', 'start': 76.11162, 'end': 76.25225, 'confidence': 0.83},
#      {'word': ' it', 'start': 76.25225, 'end': 76.3527, 'confidence': 0.22},
#      {'word': ' on', 'start': 76.33261, 'end': 76.45314, 'confidence': 0.36},
#      {'word': ' the',
#       'start': 76.43305000000001,
#       'end': 76.5335,
#       'confidence': 0.15},
#      {'word': ' land', 'start': 76.55359, 'end': 76.73439, 'confidence': 0.99},
#      {'word': ' at', 'start': 76.75448, 'end': 76.87502, 'confidence': 0.92},
#      {'word': ' all.',
#       'start': 76.93529000000001,
#       'end': 77.05582,
#       'confidence': 0.78}],
#     'text': "And some of them I think you told me wouldn't have it on the land at all.",
#     'language': 'en',
#     'start': 73.721,
#     'end': 77.05582,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Well,',
#       'start': 77.1964,
#       'end': 77.95945,
#       'confidence': 0.47}],
#     'text': 'Well,',
#     'language': 'en',
#     'start': 77.1964,
#     'end': 77.95945,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' I',
#       'start': 77.95945,
#       'end': 78.05986,
#       'confidence': 0.01},
#      {'word': ' had', 'start': 78.10002, 'end': 78.2205, 'confidence': 0.71},
#      {'word': ' a',
#       'start': 78.2205,
#       'end': 78.32090000000001,
#       'confidence': 0.25},
#      {'word': ' good',
#       'start': 78.36106000000001,
#       'end': 78.52170000000001,
#       'confidence': 0.47},
#      {'word': ' father,',
#       'start': 78.56186000000001,
#       'end': 79.04379,
#       'confidence': 0.36}],
#     'text': 'I had a good father,',
#     'language': 'en',
#     'start': 77.95945,
#     'end': 79.04379,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' I',
#       'start': 79.20443,
#       'end': 79.32492,
#       'confidence': 0.08},
#      {'word': ' said', 'start': 79.7466, 'end': 79.90724, 'confidence': 0.19},
#      {'word': ' about',
#       'start': 79.92733,
#       'end': 80.18837,
#       'confidence': 0.31},
#      {'word': ' our',
#       'start': 80.26869,
#       'end': 80.42933000000001,
#       'confidence': 0.29},
#      {'word': " town's",
#       'start': 80.44941,
#       'end': 80.69038,
#       'confidence': 0.32},
#      {'word': ' land,',
#       'start': 80.73054,
#       'end': 80.93134,
#       'confidence': 0.62}],
#     'text': "I said about our town's land,",
#     'language': 'en',
#     'start': 79.20443,
#     'end': 80.93134,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' he',
#       'start': 81.31287,
#       'end': 81.43335,
#       'confidence': 0.07},
#      {'word': " wouldn't",
#       'start': 81.47351,
#       'end': 81.67431,
#       'confidence': 0.11},
#      {'word': ' have', 'start': 81.69439, 'end': 81.81488, 'confidence': 0.23},
#      {'word': ' it',
#       'start': 81.81488,
#       'end': 81.87512000000001,
#       'confidence': 0},
#      {'word': ' on', 'start': 81.85504, 'end': 81.93536, 'confidence': 0.42},
#      {'word': ' the', 'start': 81.91528, 'end': 81.9956, 'confidence': 0.02},
#      {'word': ' land.', 'start': 81.9956, 'end': 82.096, 'confidence': 0.01}],
#     'text': "he wouldn't have it on the land.",
#     'language': 'en',
#     'start': 81.31287,
#     'end': 82.096,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' You',
#       'start': 84.25290000000001,
#       'end': 84.37338000000001,
#       'confidence': 0.32},
#      {'word': ' see,', 'start': 84.43362, 'end': 84.5541, 'confidence': 0.12}],
#     'text': 'You see,',
#     'language': 'en',
#     'start': 84.25290000000001,
#     'end': 84.5541,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' ten',
#       'start': 84.63443000000001,
#       'end': 84.87539000000001,
#       'confidence': 0.41},
#      {'word': ' men', 'start': 84.89547, 'end': 85.05611, 'confidence': 0.46},
#      {'word': ' cut', 'start': 85.39748, 'end': 85.55812, 'confidence': 0.01},
#      {'word': ' it,',
#       'start': 85.57820000000001,
#       'end': 85.69868000000001,
#       'confidence': 0.58}],
#     'text': 'ten men cut it,',
#     'language': 'en',
#     'start': 84.63443000000001,
#     'end': 85.69868000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' three',
#       'start': 86.40149000000001,
#       'end': 86.54206,
#       'confidence': 0.26},
#      {'word': ' and', 'start': 86.62238, 'end': 86.76294, 'confidence': 0.61},
#      {'word': ' six',
#       'start': 86.8031,
#       'end': 86.98382000000001,
#       'confidence': 0.4},
#      {'word': ' months',
#       'start': 87.04406,
#       'end': 87.28503,
#       'confidence': 0.26},
#      {'word': ' a', 'start': 87.28503, 'end': 87.34527, 'confidence': 0.23},
#      {'word': ' day.',
#       'start': 87.36535,
#       'end': 87.56615000000001,
#       'confidence': 0.71}],
#     'text': 'three and six months a day.',
#     'language': 'en',
#     'start': 86.40149000000001,
#     'end': 87.56615000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' Do',
#       'start': 88.36937,
#       'end': 88.48985,
#       'confidence': 0.45},
#      {'word': ' you',
#       'start': 88.46977000000001,
#       'end': 88.57017,
#       'confidence': 0.03},
#      {'word': ' remember',
#       'start': 88.59025000000001,
#       'end': 89.03202,
#       'confidence': 0.91},
#      {'word': ' cutting',
#       'start': 91.42157,
#       'end': 91.66254,
#       'confidence': 0.65},
#      {'word': ' the', 'start': 91.66254, 'end': 91.76294, 'confidence': 0.13},
#      {'word': ' harvest',
#       'start': 91.78302000000001,
#       'end': 92.14447000000001,
#       'confidence': 0.6},
#      {'word': ' with',
#       'start': 92.14447000000001,
#       'end': 92.28503,
#       'confidence': 0.37},
#      {'word': ' the', 'start': 92.28503, 'end': 92.36535, 'confidence': 0.01},
#      {'word': ' reaping',
#       'start': 92.36535,
#       'end': 92.62639,
#       'confidence': 0.56},
#      {'word': ' hook?',
#       'start': 92.64647000000001,
#       'end': 92.80712,
#       'confidence': 0.41}],
#     'text': 'Do you remember cutting the harvest with the reaping hook?',
#     'language': 'en',
#     'start': 88.36937,
#     'end': 92.80712,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Oh,',
#       'start': 93.81588,
#       'end': 93.95729,
#       'confidence': 0.2}],
#     'text': 'Oh,',
#     'language': 'en',
#     'start': 93.81588,
#     'end': 93.95729,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' all',
#       'start': 94.01790000000001,
#       'end': 94.17952000000001,
#       'confidence': 0.69},
#      {'word': ' of',
#       'start': 94.19972000000001,
#       'end': 94.32093,
#       'confidence': 0},
#      {'word': ' it.', 'start': 94.30073, 'end': 94.42194, 'confidence': 0.35}],
#     'text': 'all of it.',
#     'language': 'en',
#     'start': 94.01790000000001,
#     'end': 94.42194,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' Of',
#       'start': 95.40953,
#       'end': 95.53001,
#       'confidence': 0.36},
#      {'word': ' course,',
#       'start': 95.59025000000001,
#       'end': 95.95169000000001,
#       'confidence': 0.02}],
#     'text': 'Of course,',
#     'language': 'en',
#     'start': 95.40953,
#     'end': 95.95169000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' for',
#       'start': 96.75491000000001,
#       'end': 96.95571000000001,
#       'confidence': 0.44},
#      {'word': ' years',
#       'start': 97.05611,
#       'end': 97.41756000000001,
#       'confidence': 0.39},
#      {'word': ' and',
#       'start': 97.45772000000001,
#       'end': 97.63844,
#       'confidence': 0.35},
#      {'word': ' years',
#       'start': 97.63844,
#       'end': 97.99989000000001,
#       'confidence': 0.46},
#      {'word': ' and',
#       'start': 98.04005000000001,
#       'end': 98.18061,
#       'confidence': 0.48},
#      {'word': ' years,',
#       'start': 98.18061,
#       'end': 98.40149000000001,
#       'confidence': 0.21}],
#     'text': 'for years and years and years,',
#     'language': 'en',
#     'start': 96.75491000000001,
#     'end': 98.40149000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' nothing',
#       'start': 98.40149000000001,
#       'end': 98.64246,
#       'confidence': 0.06},
#      {'word': ' else',
#       'start': 98.68262,
#       'end': 98.86334000000001,
#       'confidence': 0.48},
#      {'word': ' about',
#       'start': 98.88342,
#       'end': 99.06414000000001,
#       'confidence': 0.15},
#      {'word': ' cutting.',
#       'start': 99.14447000000001,
#       'end': 99.46575000000001,
#       'confidence': 0.02}],
#     'text': 'nothing else about cutting.',
#     'language': 'en',
#     'start': 98.40149000000001,
#     'end': 99.46575000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' And',
#       'start': 100.43001000000001,
#       'end': 100.55061,
#       'confidence': 0},
#      {'word': ' how',
#       'start': 100.55061,
#       'end': 100.67122,
#       'confidence': 0.99},
#      {'word': ' do', 'start': 100.69132, 'end': 100.81192, 'confidence': 0.82},
#      {'word': ' you',
#       'start': 100.81192,
#       'end': 100.93252000000001,
#       'confidence': 0.43},
#      {'word': ' think',
#       'start': 100.95262000000001,
#       'end': 101.15363,
#       'confidence': 0.99},
#      {'word': ' that',
#       'start': 101.19383,
#       'end': 101.33453,
#       'confidence': 0.92},
#      {'word': ' the',
#       'start': 101.33453,
#       'end': 101.45514,
#       'confidence': 0.77},
#      {'word': ' reaping',
#       'start': 101.47524000000001,
#       'end': 101.75664,
#       'confidence': 0.62},
#      {'word': ' hook',
#       'start': 101.77674,
#       'end': 101.91745,
#       'confidence': 0.66},
#      {'word': ' compares',
#       'start': 101.95765,
#       'end': 102.39986,
#       'confidence': 0.92},
#      {'word': ' with',
#       'start': 102.39986,
#       'end': 102.52046000000001,
#       'confidence': 0.25},
#      {'word': ' the',
#       'start': 102.52046000000001,
#       'end': 102.62096000000001,
#       'confidence': 0.13},
#      {'word': ' combine',
#       'start': 102.62096000000001,
#       'end': 103.04308,
#       'confidence': 0.79},
#      {'word': ' at', 'start': 103.04308, 'end': 103.10338, 'confidence': 0},
#      {'word': ' the',
#       'start': 103.08328,
#       'end': 103.18378000000001,
#       'confidence': 0.48},
#      {'word': ' present',
#       'start': 103.18378000000001,
#       'end': 103.44509000000001,
#       'confidence': 0.85},
#      {'word': ' time?',
#       'start': 103.46519,
#       'end': 103.72649000000001,
#       'confidence': 0.92}],
#     'text': 'And how do you think that the reaping hook compares with the combine at the present time?',
#     'language': 'en',
#     'start': 100.43001000000001,
#     'end': 103.72649000000001,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Oh,',
#       'start': 104.04813000000001,
#       'end': 104.16894,
#       'confidence': 0.01}],
#     'text': 'Oh,',
#     'language': 'en',
#     'start': 104.04813000000001,
#     'end': 104.16894,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' well,',
#       'start': 104.28974000000001,
#       'end': 104.45082000000001,
#       'confidence': 0.41}],
#     'text': 'well,',
#     'language': 'en',
#     'start': 104.28974000000001,
#     'end': 104.45082000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': " there's",
#       'start': 104.45082000000001,
#       'end': 104.69243,
#       'confidence': 0.25},
#      {'word': ' an', 'start': 104.69243, 'end': 104.81323, 'confidence': 0.49},
#      {'word': ' awful',
#       'start': 104.87364000000001,
#       'end': 105.19579,
#       'confidence': 0.07},
#      {'word': ' difference.',
#       'start': 105.23605,
#       'end': 105.77968000000001,
#       'confidence': 0.23}],
#     'text': "there's an awful difference.",
#     'language': 'en',
#     'start': 104.45082000000001,
#     'end': 105.77968000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' An',
#       'start': 107.31067,
#       'end': 107.43181000000001,
#       'confidence': 0.69},
#      {'word': ' awful',
#       'start': 107.49238,
#       'end': 107.89619,
#       'confidence': 0.22},
#      {'word': ' difference',
#       'start': 107.93657,
#       'end': 108.38076000000001,
#       'confidence': 0.33},
#      {'word': ' I',
#       'start': 108.40095000000001,
#       'end': 108.48171,
#       'confidence': 0.86},
#      {'word': ' see', 'start': 108.5019, 'end': 108.70381, 'confidence': 0.02},
#      {'word': ' anywhere.',
#       'start': 108.70381,
#       'end': 109.08743000000001,
#       'confidence': 0.24}],
#     'text': 'An awful difference I see anywhere.',
#     'language': 'en',
#     'start': 107.31067,
#     'end': 109.08743000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' Because',
#       'start': 110.47902,
#       'end': 110.92123000000001,
#       'confidence': 0.18},
#      {'word': ' if',
#       'start': 110.94133000000001,
#       'end': 111.06193,
#       'confidence': 0.24},
#      {'word': ' you',
#       'start': 111.22273,
#       'end': 111.36344000000001,
#       'confidence': 0.23},
#      {'word': ' come',
#       'start': 111.42374000000001,
#       'end': 111.64484,
#       'confidence': 0.09},
#      {'word': ' round',
#       'start': 111.78555,
#       'end': 112.10716000000001,
#       'confidence': 0.25},
#      {'word': ' and',
#       'start': 112.14736,
#       'end': 112.32826,
#       'confidence': 0.34},
#      {'word': ' slap',
#       'start': 112.54937000000001,
#       'end': 112.83077,
#       'confidence': 0.5},
#      {'word': ' your',
#       'start': 112.83077,
#       'end': 112.97148,
#       'confidence': 0.01},
#      {'word': ' head',
#       'start': 112.97148,
#       'end': 113.09208000000001,
#       'confidence': 0.17},
#      {'word': ' there,',
#       'start': 113.11218000000001,
#       'end': 113.33329,
#       'confidence': 0.32}],
#     'text': 'Because if you come round and slap your head there,',
#     'language': 'en',
#     'start': 110.47902,
#     'end': 113.33329,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' if',
#       'start': 113.9364,
#       'end': 114.05721,
#       'confidence': 0.06},
#      {'word': ' you',
#       'start': 114.07734,
#       'end': 114.19815,
#       'confidence': 0.04},
#      {'word': ' put', 'start': 114.25855, 'end': 114.5203, 'confidence': 0.27},
#      {'word': ' a',
#       'start': 114.5203,
#       'end': 114.56056000000001,
#       'confidence': 0.06},
#      {'word': ' rapier',
#       'start': 114.56056000000001,
#       'end': 114.84244000000001,
#       'confidence': 0.34},
#      {'word': ' on',
#       'start': 114.86258000000001,
#       'end': 114.98338000000001,
#       'confidence': 0.46},
#      {'word': ' the',
#       'start': 115.00352000000001,
#       'end': 115.12432000000001,
#       'confidence': 0.02},
#      {'word': ' vine,',
#       'start': 115.12432000000001,
#       'end': 115.22499,
#       'confidence': 0.1}],
#     'text': 'if you put a rapier on the vine,',
#     'language': 'en',
#     'start': 113.9364,
#     'end': 115.22499,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' there',
#       'start': 115.22499,
#       'end': 115.34580000000001,
#       'confidence': 0.07},
#      {'word': " wouldn't",
#       'start': 115.34580000000001,
#       'end': 115.58741,
#       'confidence': 0.15},
#      {'word': ' be',
#       'start': 115.58741,
#       'end': 115.70821000000001,
#       'confidence': 0.25},
#      {'word': ' no', 'start': 115.74848, 'end': 115.86929, 'confidence': 0.62},
#      {'word': ' mice.',
#       'start': 115.96996,
#       'end': 116.45318,
#       'confidence': 0.29}],
#     'text': "there wouldn't be no mice.",
#     'language': 'en',
#     'start': 115.22499,
#     'end': 116.45318,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' Now,',
#       'start': 116.876,
#       'end': 116.9966,
#       'confidence': 0.02}],
#     'text': 'Now,',
#     'language': 'en',
#     'start': 116.876,
#     'end': 116.9966,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' you',
#       'start': 117.13731,
#       'end': 117.25791000000001,
#       'confidence': 0.86},
#      {'word': ' also',
#       'start': 117.43881,
#       'end': 117.74032000000001,
#       'confidence': 0.9},
#      {'word': ' remember,',
#       'start': 118.14233,
#       'end': 118.58454,
#       'confidence': 0.98}],
#     'text': 'you also remember,',
#     'language': 'en',
#     'start': 117.13731,
#     'end': 118.58454,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' I',
#       'start': 118.62474,
#       'end': 118.72525,
#       'confidence': 0.86},
#      {'word': ' think,',
#       'start': 118.74535,
#       'end': 118.94635000000001,
#       'confidence': 0.82}],
#     'text': 'I think,',
#     'language': 'en',
#     'start': 118.62474,
#     'end': 118.94635000000001,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' a',
#       'start': 119.06695,
#       'end': 119.18756,
#       'confidence': 0.92},
#      {'word': ' rather',
#       'start': 119.22776,
#       'end': 119.48907,
#       'confidence': 0.87},
#      {'word': ' historic',
#       'start': 119.58957000000001,
#       'end': 120.07198000000001,
#       'confidence': 0.99},
#      {'word': ' thing',
#       'start': 120.15238000000001,
#       'end': 120.39359,
#       'confidence': 0.71},
#      {'word': ' in',
#       'start': 121.15741,
#       'end': 121.27801000000001,
#       'confidence': 0},
#      {'word': ' the',
#       'start': 121.27801000000001,
#       'end': 121.37851,
#       'confidence': 0.98},
#      {'word': ' land',
#       'start': 121.39861,
#       'end': 121.68002,
#       'confidence': 0.98},
#      {'word': ' history',
#       'start': 121.74032,
#       'end': 122.00163,
#       'confidence': 0.94},
#      {'word': ' of', 'start': 122.02173, 'end': 122.12223, 'confidence': 0.99},
#      {'word': ' this',
#       'start': 122.14233,
#       'end': 122.26293000000001,
#       'confidence': 0.99},
#      {'word': ' country,',
#       'start': 122.32324,
#       'end': 122.62474,
#       'confidence': 0.98}],
#     'text': 'a rather historic thing in the land history of this country,',
#     'language': 'en',
#     'start': 119.06695,
#     'end': 122.62474,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' the',
#       'start': 122.74535,
#       'end': 122.86595,
#       'confidence': 0.92}],
#     'text': 'the',
#     'language': 'en',
#     'start': 122.74535,
#     'end': 122.86595,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' Boddhike',
#       'start': 123.75037,
#       'end': 124.17248000000001,
#       'confidence': 0.36},
#      {'word': ' evictions.',
#       'start': 124.21268,
#       'end': 124.65489000000001,
#       'confidence': 0.84}],
#     'text': 'Boddhike evictions.',
#     'language': 'en',
#     'start': 123.75037,
#     'end': 124.65489000000001,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' I',
#       'start': 124.95763000000001,
#       'end': 125.08008000000001,
#       'confidence': 0.24},
#      {'word': ' do.',
#       'start': 125.10049000000001,
#       'end': 125.34539000000001,
#       'confidence': 0.15}],
#     'text': 'I do.',
#     'language': 'en',
#     'start': 124.95763000000001,
#     'end': 125.34539000000001,
#     'speaker': 1,
#     'channel': 0},
#    {'words': [{'word': ' Could',
#       'start': 126.48003,
#       'end': 126.60083,
#       'confidence': 0.29},
#      {'word': ' you',
#       'start': 126.60083,
#       'end': 126.70150000000001,
#       'confidence': 0.63},
#      {'word': ' describe',
#       'start': 126.72164000000001,
#       'end': 127.18472,
#       'confidence': 0.75},
#      {'word': ' for',
#       'start': 127.20486,
#       'end': 127.32566,
#       'confidence': 0.95},
#      {'word': ' us', 'start': 127.38607, 'end': 127.50687, 'confidence': 0.73},
#      {'word': ' what',
#       'start': 127.90956,
#       'end': 128.0505,
#       'confidence': 0.94},
#      {'word': ' happened',
#       'start': 128.11090000000002,
#       'end': 128.45318,
#       'confidence': 0.93},
#      {'word': ' at',
#       'start': 128.45318,
#       'end': 128.53372000000002,
#       'confidence': 0},
#      {'word': ' those',
#       'start': 128.53372000000002,
#       'end': 128.67466000000002,
#       'confidence': 0.01},
#      {'word': ' evictions?',
#       'start': 128.69479,
#       'end': 128.876,
#       'confidence': 0.02}],
#     'text': 'Could you describe for us what happened at those evictions?',
#     'language': 'en',
#     'start': 126.48003,
#     'end': 128.876,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' You',
#       'start': 128.99845,
#       'end': 129.34539,
#       'confidence': 0.25},
#      {'word': ' were',
#       'start': 129.3862,
#       'end': 129.54947,
#       'confidence': 0.47},
#      {'word': ' at', 'start': 129.54947, 'end': 129.67192, 'confidence': 0.48},
#      {'word': ' them.',
#       'start': 129.67192,
#       'end': 129.79437000000001,
#       'confidence': 0.49}],
#     'text': 'You were at them.',
#     'language': 'en',
#     'start': 128.99845,
#     'end': 129.79437000000001,
#     'speaker': 0,
#     'channel': 0},
#    {'words': [{'word': ' I',
#       'start': 130.03654,
#       'end': 130.15694000000002,
#       'confidence': 0.44},
# ...
#       'start': 140.49754000000001,
#       'end': 143.3119,
#       'confidence': 0.30888888888888894,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' Well, ',
#         'start': 143.73215000000002,
#         'end': 143.87323,
#         'confidence': 0.33}],
#       'text': ' Well, ',
#       'language': 'en',
#       'start': 143.73215000000002,
#       'end': 143.87323,
#       'confidence': 0.665,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' there ',
#         'start': 143.87323,
#         'end': 143.99415000000002,
#         'confidence': 0.12},
#        {'word': ' was ',
#         'start': 143.99415000000002,
#         'end': 144.09492,
#         'confidence': 0.26},
#        {'word': ' one ',
#         'start': 144.07477,
#         'end': 144.15538,
#         'confidence': 0.02},
#        {'word': ' of ',
#         'start': 144.15538,
#         'end': 144.27631,
#         'confidence': 0.02},
#        {'word': ' them ',
#         'start': 144.31662,
#         'end': 144.43754,
#         'confidence': 0.19},
#        {'word': ' thrown ',
#         'start': 144.53831,
#         'end': 144.82046,
#         'confidence': 0.39},
#        {'word': ' out ',
#         'start': 144.86077,
#         'end': 145.022,
#         'confidence': 0.12},
#        {'word': ' one ',
#         'start': 145.30415,
#         'end': 145.64677,
#         'confidence': 0.45},
#        {'word': ' day, ',
#         'start': 145.70723,
#         'end': 145.88862,
#         'confidence': 0.16}],
#       'text': ' there was one of them thrown out one day, ',
#       'language': 'en',
#       'start': 143.87323,
#       'end': 145.88862,
#       'confidence': 0.2730000000000001,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' I ',
#         'start': 145.88862,
#         'end': 145.92892,
#         'confidence': 0.41},
#        {'word': ' was ',
#         'start': 145.94908,
#         'end': 146.09015,
#         'confidence': 0.29},
#        {'word': ' in ',
#         'start': 146.09015,
#         'end': 146.21108,
#         'confidence': 0.53},
#        {'word': ' it, ',
#         'start': 146.19092,
#         'end': 146.31185,
#         'confidence': 0.44}],
#       'text': ' I was in it, ',
#       'language': 'en',
#       'start': 145.88862,
#       'end': 146.31185,
#       'confidence': 0.534,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' and ',
#         'start': 146.87252,
#         'end': 146.99355,
#         'confidence': 0.76},
#        {'word': ' the ',
#         'start': 147.13476,
#         'end': 147.25579000000002,
#         'confidence': 0.4},
#        {'word': ' baby ',
#         'start': 147.37683,
#         'end': 147.59872000000001,
#         'confidence': 0.54},
#        {'word': ' was ',
#         'start': 147.59872000000001,
#         'end': 147.71976,
#         'confidence': 0.24},
#        {'word': ' only ',
#         'start': 147.78028,
#         'end': 148.02234,
#         'confidence': 0.37},
#        {'word': ' about ',
#         'start': 148.06269,
#         'end': 148.32493,
#         'confidence': 0.37},
#        {'word': ' three ',
#         'start': 148.3451,
#         'end': 148.52666,
#         'confidence': 0.65},
#        {'word': ' days ',
#         'start': 148.567,
#         'end': 148.82924,
#         'confidence': 0.48},
#        {'word': ' old.',
#         'start': 148.88976,
#         'end': 149.11166,
#         'confidence': 0.46}],
#       'text': ' and the baby was only about three days old.',
#       'language': 'en',
#       'start': 146.87252,
#       'end': 149.11166,
#       'confidence': 0.527,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' And ',
#         'start': 149.75224,
#         'end': 149.87294,
#         'confidence': 0.76},
#        {'word': ' they ',
#         'start': 149.87294,
#         'end': 149.97353,
#         'confidence': 0.05},
#        {'word': ' were ',
#         'start': 149.97353,
#         'end': 150.09424,
#         'confidence': 0.16},
#        {'word': ' sitting, ',
#         'start': 150.13447000000002,
#         'end': 150.63741000000002,
#         'confidence': 0.4}],
#       'text': ' And they were sitting, ',
#       'language': 'en',
#       'start': 149.75224,
#       'end': 150.63741000000002,
#       'confidence': 0.47400000000000003,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' they ',
#         'start': 150.75812000000002,
#         'end': 150.87882000000002,
#         'confidence': 0.08},
#        {'word': ' were ',
#         'start': 150.89894,
#         'end': 151.05988000000002,
#         'confidence': 0.16},
#        {'word': ' thrown ',
#         'start': 151.08,
#         'end': 151.28118,
#         'confidence': 0.09},
#        {'word': ' on ',
#         'start': 151.28118,
#         'end': 151.40188,
#         'confidence': 0.48},
#        {'word': ' the ',
#         'start': 151.40188,
#         'end': 151.52259,
#         'confidence': 0.16},
#        {'word': ' bank ',
#         'start': 151.54271,
#         'end': 151.72376,
#         'confidence': 0.58},
#        {'word': ' of ',
#         'start': 151.72376,
#         'end': 151.82435,
#         'confidence': 0.04},
#        {'word': ' the ',
#         'start': 151.86459000000002,
#         'end': 152.00541,
#         'confidence': 0.03},
#        {'word': ' river.',
#         'start': 152.02553,
#         'end': 153.09176000000002,
#         'confidence': 0.15}],
#       'text': ' they were thrown on the bank of the river.',
#       'language': 'en',
#       'start': 150.75812000000002,
#       'end': 153.09176000000002,
#       'confidence': 0.277,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' Oh, ',
#         'start': 154.79459,
#         'end': 154.91681,
#         'confidence': 0.55}],
#       'text': ' Oh, ',
#       'language': 'en',
#       'start': 154.79459,
#       'end': 154.91681,
#       'confidence': 0.775,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' it ',
#         'start': 154.9983,
#         'end': 155.34459,
#         'confidence': 0.26},
#        {'word': ' was ',
#         'start': 155.36496,
#         'end': 155.48719,
#         'confidence': 0.21},
#        {'word': ' cruel.',
#         'start': 155.52793,
#         'end': 155.73163,
#         'confidence': 0.22}],
#       'text': ' it was cruel.',
#       'language': 'en',
#       'start': 154.9983,
#       'end': 155.73163,
#       'confidence': 0.4225,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' And ',
#         'start': 156.79297,
#         'end': 156.91338000000002,
#         'confidence': 0.72},
#        {'word': ' how ',
#         'start': 156.97359,
#         'end': 157.13415,
#         'confidence': 0.49},
#        {'word': ' about ',
#         'start': 157.15421,
#         'end': 157.41511,
#         'confidence': 0.49},
#        {'word': ' the ',
#         'start': 157.43518,
#         'end': 157.5556,
#         'confidence': 0.3},
#        {'word': ' type ',
#         'start': 160.06425000000002,
#         'end': 160.28501,
#         'confidence': 0.53},
#        {'word': ' of ',
#         'start': 160.28501,
#         'end': 160.38536,
#         'confidence': 0.03},
#        {'word': ' food ',
#         'start': 160.40543,
#         'end': 160.68639000000002,
#         'confidence': 0.58},
#        {'word': ' you ',
#         'start': 160.68639000000002,
#         'end': 160.76667,
#         'confidence': 0.01},
#        {'word': ' had ',
#         'start': 160.76667,
#         'end': 160.88709,
#         'confidence': 0.52},
#        {'word': ' to ',
#         'start': 160.88709,
#         'end': 161.0075,
#         'confidence': 0.6},
#        {'word': ' eat ',
#         'start': 161.08778,
#         'end': 161.20819,
#         'confidence': 0.58},
#        {'word': ' at ',
#         'start': 161.20819,
#         'end': 161.30854,
#         'confidence': 0.41},
#        {'word': ' that ',
#         'start': 161.30854,
#         'end': 161.44902000000002,
#         'confidence': 0.41},
#        {'word': ' time, ',
#         'start': 161.48916,
#         'end': 161.75006000000002,
#         'confidence': 0.69}],
#       'text': ' And how about the type of food you had to eat at that time, ',
#       'language': 'en',
#       'start': 156.79297,
#       'end': 161.75006000000002,
#       'confidence': 0.49066666666666664,
#       'speaker': 0,
#       'channel': 0},
#      {'words': [{'word': ' Mr ',
#         'start': 161.77013,
#         'end': 161.89055000000002,
#         'confidence': 0},
#        {'word': ' Fispartic?',
#         'start': 161.91062,
#         'end': 162.312,
#         'confidence': 0.53}],
#       'text': ' Mr Fispartic?',
#       'language': 'en',
#       'start': 161.77013,
#       'end': 162.312,
#       'confidence': 0.51,
#       'speaker': 0,
#       'channel': 0},
#      {'words': [{'word': ' What ',
#         'start': 162.3723,
#         'end': 162.51439,
#         'confidence': 0.33},
#        {'word': ' sort ',
#         'start': 162.53469,
#         'end': 162.71737000000002,
#         'confidence': 0.17},
#        {'word': ' of, ',
#         'start': 162.71737000000002,
#         'end': 162.83916,
#         'confidence': 0.01}],
#       'text': ' What sort of, ',
#       'language': 'en',
#       'start': 162.3723,
#       'end': 162.83916,
#       'confidence': 0.3775,
#       'speaker': 0,
#       'channel': 0},
#      {'words': [{'word': ' what ',
#         'start': 163.08275,
#         'end': 163.20454,
#         'confidence': 0.23},
#        {'word': ' did ',
#         'start': 163.20454,
#         'end': 163.30603000000002,
#         'confidence': 0.15},
#        {'word': ' you ',
#         'start': 163.30603000000002,
#         'end': 163.38722,
#         'confidence': 0},
#        {'word': ' live ',
#         'start': 163.40752,
#         'end': 163.59021,
#         'confidence': 0.51},
#        {'word': ' on?',
#         'start': 163.59021,
#         'end': 163.71200000000002,
#         'confidence': 0.49}],
#       'text': ' what did you live on?',
#       'language': 'en',
#       'start': 163.08275,
#       'end': 163.71200000000002,
#       'confidence': 0.39666666666666667,
#       'speaker': 0,
#       'channel': 0},
#      {'words': [{'word': ' Well, ',
#         'start': 163.85257000000001,
#         'end': 164.29436,
#         'confidence': 0.21}],
#       'text': ' Well, ',
#       'language': 'en',
#       'start': 163.85257000000001,
#       'end': 164.29436,
#       'confidence': 0.605,
#       'speaker': 1,
#       'channel': 0},
#      {'words': [{'word': ' we ',
#         'start': 164.73615,
#         'end': 164.85663,
#         'confidence': 0.1},
#        {'word': ' had ',
#         'start': 164.8968,
#         'end': 165.01728,
#         'confidence': 0.4},
#        {'word': ' to ',
#         'start': 165.03737,
#         'end': 165.15785,
#         'confidence': 0.24},
#        {'word': ' live ',
#         'start': 165.19802,
#         'end': 165.51932,
#         'confidence': 0.38},
#        {'word': ' there ',
#         'start': 165.78037,
#         'end': 166.02135,
#         'confidence': 0.29},
#        {'word': ' a ',
#         'start': 166.02135,
#         'end': 166.08159,
#         'confidence': 0.05},
#        {'word': ' long ',
#         'start': 166.08159,
#         'end': 166.26233000000002,
#         'confidence': 0.41},
#        {'word': ' time ',
#         'start': 166.32257,
#         'end': 166.56354000000002,
#         'confidence': 0.36},
#        {'word': ' on ',
#         'start': 167.02541000000002,
#         'end': 167.1459,
#         'confidence': 0.37},
#        {'word': ' an ',
#         'start': 167.18607,
#         'end': 167.30655000000002,
#         'confidence': 0.41},
#        {'word': ' Indian ',
#         'start': 167.34672,
#         'end': 167.60777000000002,
#         'confidence': 0.38},
#        {'word': ' man ',
#         'start': 167.66802,
#         'end': 167.92907,
#         'confidence': 0.4},
#        {'word': ' and ',
#         'start': 168.17005,
#         'end': 168.31062,
#         'confidence': 0.28},
#        {'word': ' plough.',
#         'start': 168.43111000000002,
#         'end': 168.65200000000002,
#         'confidence': 0.06}],
#       'text': ' we had to live there a long time on an Indian man and plough.',
#       'language': 'en',
#       'start': 164.73615,
#       'end': 168.65200000000002,
#       'confidence': 0.34199999999999997,
#       'speaker': 1,
#       'channel': 0}],
#     'error': None,
#     'subtitles': [{'format': 'srt',
#       'subtitles': "1\n00:00:01.166 --> 00:00:03.759\nI'm going to introduce you to a rather remarkable man.\n\n2\n00:00:04.563 --> 00:00:06.633\n He's Mr Michael Fitzpatrick from Killenie, \n\n3\n00:00:07.115 --> 00:00:07.477\n Maynooth.\n\n4\n00:00:08.602 --> 00:00:08.783\n Now, \n\n5\n00:00:09.968 --> 00:00:18.599\n he started to draw the old age pension in 1927 and seven years ago he got the President's bounty on his hundredth birthday.\n\n6\n00:00:19.651 --> 00:00:21.114\n Now he's from County Clare.\n\n7\n00:00:22.036 --> 00:00:28.921\n He came up from Clare in 1940 to a land commission farm in Maynooth where he lives now.\n\n8\n00:00:29.868 --> 00:00:33.401\n You have seen a lot of changes Mr Fitzpatrick in farming.\n\n9\n00:00:34.164 --> 00:00:35.737\n What would you say was the biggest change?\n\n10\n00:00:36.268 --> 00:00:36.982\n Well machinery.\n\n11\n00:00:37.931 --> 00:00:41.866\n And what sort of a machine would you think made the biggest impression?\n\n12\n00:00:42.268 --> 00:00:42.369\n Well, \n\n13\n00:00:42.369 --> 00:00:42.896\n I think it was the most powerful \n\n14\n00:00:43.170 --> 00:00:43.291\n Well, \n\n15\n00:00:43.291 --> 00:00:44.828\n the reaper and binder is a great one, \n\n16\n00:00:45.248 --> 00:00:45.369\n but, \n\n17\n00:00:45.429 --> 00:00:45.772\n by God, \n\n18\n00:00:46.155 --> 00:00:50.308\n the one for cutting up the ground and throwing a crop is a powerful one too.\n\n19\n00:00:51.290 --> 00:00:51.430\n Well, \n\n20\n00:00:51.872 --> 00:00:55.188\n you were saying at the time you saw the mowing machine first, \n\n21\n00:00:55.892 --> 00:00:57.368\n it made a tremendous impression on you.\n\n22\n00:00:57.428 --> 00:00:57.750\n It did, \n\n23\n00:00:58.253 --> 00:01:00.888\n because I didn't know how it could be done at all.\n\n24\n00:01:02.409 --> 00:01:06.822\n What was the reaction of the people at that time to the mowing machine, \n\n25\n00:01:06.822 --> 00:01:06.903\n Mr.\n\n26\n00:01:06.903 --> 00:01:07.066\n Scott?\n\n27\n00:01:07.188 --> 00:01:07.835\n I had great money, \n\n28\n00:01:07.855 --> 00:01:09.008\n but I wasn't minding it.\n\n29\n00:01:09.128 --> 00:01:09.872\n I could afford it, \n\n30\n00:01:09.893 --> 00:01:12.448\n but the mowing got at it.\n\n31\n00:01:13.721 --> 00:01:17.056\n And some of them I think you told me wouldn't have it on the land at all.\n\n32\n00:01:17.196 --> 00:01:17.959\n Well, \n\n33\n00:01:17.959 --> 00:01:19.044\n I had a good father, \n\n34\n00:01:19.204 --> 00:01:20.931\n I said about our town's land, \n\n35\n00:01:21.313 --> 00:01:22.096\n he wouldn't have it on the land.\n\n36\n00:01:24.253 --> 00:01:24.554\n You see, \n\n37\n00:01:24.634 --> 00:01:25.699\n ten men cut it, \n\n38\n00:01:26.401 --> 00:01:27.566\n three and six months a day.\n\n39\n00:01:28.369 --> 00:01:32.807\n Do you remember cutting the harvest with the reaping hook?\n\n40\n00:01:33.816 --> 00:01:33.957\n Oh, \n\n41\n00:01:34.018 --> 00:01:34.422\n all of it.\n\n42\n00:01:35.410 --> 00:01:35.952\n Of course, \n\n43\n00:01:36.755 --> 00:01:38.401\n for years and years and years, \n\n44\n00:01:38.401 --> 00:01:39.466\n nothing else about cutting.\n\n45\n00:01:40.430 --> 00:01:43.726\n And how do you think that the reaping hook compares with the combine at the present time?\n\n46\n00:01:44.048 --> 00:01:44.169\n Oh, \n\n47\n00:01:44.290 --> 00:01:44.451\n well, \n\n48\n00:01:44.451 --> 00:01:45.780\n there's an awful difference.\n\n49\n00:01:47.311 --> 00:01:49.087\n An awful difference I see anywhere.\n\n50\n00:01:50.479 --> 00:01:53.333\n Because if you come round and slap your head there, \n\n51\n00:01:53.936 --> 00:01:55.225\n if you put a rapier on the vine, \n\n52\n00:01:55.225 --> 00:01:56.453\n there wouldn't be no mice.\n\n53\n00:01:56.876 --> 00:01:56.997\n Now, \n\n54\n00:01:57.137 --> 00:01:58.585\n you also remember, \n\n55\n00:01:58.625 --> 00:01:58.946\n I think, \n\n56\n00:01:59.067 --> 00:02:02.625\n a rather historic thing in the land history of this cou ...
#   'exec_time': 0.20238161087036133,
#   'error': None}}

# %%
transcript = results_data.get("result",{}).get("transcription", {}).get("subtitles",[])[0].get("subtitles","")

# %%
print(transcript)
# Out:
# 1
# 00:00:01.166 --> 00:00:03.759
# I'm going to introduce you to a rather remarkable man.
#
# 2
# 00:00:04.563 --> 00:00:06.633
# He's Mr Michael Fitzpatrick from Killenie,
#
# 3
# 00:00:07.115 --> 00:00:07.477
# Maynooth.
#
# 4
# 00:00:08.602 --> 00:00:08.783
# Now,
#
# 5
# 00:00:09.968 --> 00:00:18.599
# he started to draw the old age pension in 1927 and seven years ago he got the President's bounty on his hundredth birthday.
#
# 6
# 00:00:19.651 --> 00:00:21.114
# Now he's from County Clare.
#
# 7
# 00:00:22.036 --> 00:00:28.921
# He came up from Clare in 1940 to a land commission farm in Maynooth where he lives now.
#
# 8
# 00:00:29.868 --> 00:00:33.401
# You have seen a lot of changes Mr Fitzpatrick in farming.
#
# 9
# 00:00:34.164 --> 00:00:35.737
# What would you say was the biggest change?
#
# 10
# 00:00:36.268 --> 00:00:36.982
# Well machinery.
#
# 11
# 00:00:37.931 --> 00:00:41.866
# And what sort of a machine would you think made the biggest impression?
#
# 12
# 00:00:42.268 --> 00:00:42.369
# Well,
#
# 13
# 00:00:42.369 --> 00:00:42.896
# I think it was the most powerful
#
# 14
# 00:00:43.170 --> 00:00:43.291
# Well,
#
# 15
# 00:00:43.291 --> 00:00:44.828
# the reaper and binder is a great one,
#
# 16
# 00:00:45.248 --> 00:00:45.369
# but,
#
# 17
# 00:00:45.429 --> 00:00:45.772
# by God,
#
# 18
# 00:00:46.155 --> 00:00:50.308
# the one for cutting up the ground and throwing a crop is a powerful one too.
#
# 19
# 00:00:51.290 --> 00:00:51.430
# Well,
#
# 20
# 00:00:51.872 --> 00:00:55.188
# you were saying at the time you saw the mowing machine first,
#
# 21
# 00:00:55.892 --> 00:00:57.368
# it made a tremendous impression on you.
#
# 22
# 00:00:57.428 --> 00:00:57.750
# It did,
#
# 23
# 00:00:58.253 --> 00:01:00.888
# because I didn't know how it could be done at all.
#
# 24
# 00:01:02.409 --> 00:01:06.822
# What was the reaction of the people at that time to the mowing machine,
#
# 25
# 00:01:06.822 --> 00:01:06.903
# Mr.
#
# 26
# 00:01:06.903 --> 00:01:07.066
# Scott?
#
# 27
# 00:01:07.188 --> 00:01:07.835
# I had great money,
#
# 28
# 00:01:07.855 --> 00:01:09.008
# but I wasn't minding it.
#
# 29
# 00:01:09.128 --> 00:01:09.872
# I could afford it,
#
# 30
# 00:01:09.893 --> 00:01:12.448
# but the mowing got at it.
#
# 31
# 00:01:13.721 --> 00:01:17.056
# And some of them I think you told me wouldn't have it on the land at all.
#
# 32
# 00:01:17.196 --> 00:01:17.959
# Well,
#
# 33
# 00:01:17.959 --> 00:01:19.044
# I had a good father,
#
# 34
# 00:01:19.204 --> 00:01:20.931
# I said about our town's land,
#
# 35
# 00:01:21.313 --> 00:01:22.096
# he wouldn't have it on the land.
#
# 36
# 00:01:24.253 --> 00:01:24.554
# You see,
#
# 37
# 00:01:24.634 --> 00:01:25.699
# ten men cut it,
#
# 38
# 00:01:26.401 --> 00:01:27.566
# three and six months a day.
#
# 39
# 00:01:28.369 --> 00:01:32.807
# Do you remember cutting the harvest with the reaping hook?
#
# 40
# 00:01:33.816 --> 00:01:33.957
# Oh,
#
# 41
# 00:01:34.018 --> 00:01:34.422
# all of it.
#
# 42
# 00:01:35.410 --> 00:01:35.952
# Of course,
#
# 43
# 00:01:36.755 --> 00:01:38.401
# for years and years and years,
#
# 44
# 00:01:38.401 --> 00:01:39.466
# nothing else about cutting.
#
# 45
# 00:01:40.430 --> 00:01:43.726
# And how do you think that the reaping hook compares with the combine at the present time?
#
# 46
# 00:01:44.048 --> 00:01:44.169
# Oh,
#
# 47
# 00:01:44.290 --> 00:01:44.451
# well,
#
# 48
# 00:01:44.451 --> 00:01:45.780
# there's an awful difference.
#
# 49
# 00:01:47.311 --> 00:01:49.087
# An awful difference I see anywhere.
#
# 50
# 00:01:50.479 --> 00:01:53.333
# Because if you come round and slap your head there,
#
# 51
# 00:01:53.936 --> 00:01:55.225
# if you put a rapier on the vine,
#
# 52
# 00:01:55.225 --> 00:01:56.453
# there wouldn't be no mice.
#
# 53
# 00:01:56.876 --> 00:01:56.997
# Now,
#
# 54
# 00:01:57.137 --> 00:01:58.585
# you also remember,
#
# 55
# 00:01:58.625 --> 00:01:58.946
# I think,
#
# 56
# 00:01:59.067 --> 00:02:02.625
# a rather historic thing in the land history of this country,
#
# 57
# 00:02:02.745 --> 00:02:02.866
# the
#
# 58
# 00:02:03.750 --> 00:02:04.655
# Boddhike evictions.
#
# 59
# 00:02:04.958 --> 00:02:05.345
# I do.
#
# 60
# 00:02:06.480 --> 00:02:08.876
# Could you describe for us what happened at those evictions?
#
# 61
# 00:02:08.998 --> 00:02:09.794
# You were at them.
#
# 62
# 00:02:10.037 --> 00:02:15.816
# I was at one of them about five hours before Monday.
#
# 63
# 00:02:16.264 --> 00:02:16.876
# And what happened?
#
# 64
# 00:02:17.158 --> 00:02:17.279
# Ah,
#
# 65
# 00:02:17.802 --> 00:02:19.332
# that was very cruel.
#
# 66
# 00:02:20.498 --> 00:02:23.312
# There were children and women on the roadside.
#
# 67
# 00:02:23.732 --> 00:02:23.873
# Well,
#
# 68
# 00:02:23.873 --> 00:02:25.889
# there was one of them thrown out one day,
#
# 69
# 00:02:25.889 --> 00:02:26.312
# I was in it,
#
# 70
# 00:02:26.873 --> 00:02:29.112
# and the baby was only about three days old.
#
# 71
# 00:02:29.752 --> 00:02:30.637
# And they were sitting,
#
# 72
# 00:02:30.758 --> 00:02:33.092
# they were thrown on the bank of the river.
#
# 73
# 00:02:34.795 --> 00:02:34.917
# Oh,
#
# 74
# 00:02:34.998 --> 00:02:35.732
# it was cruel.
#
# 75
# 00:02:36.793 --> 00:02:41.750
# And how about the type of food you had to eat at that time,
#
# 76
# 00:02:41.770 --> 00:02:42.312
# Mr Fispartic?
#
# 77
# 00:02:42.372 --> 00:02:42.839
# What sort of,
#
# 78
# 00:02:43.083 --> 00:02:43.712
# what did you live on?
#
# 79
# 00:02:43.853 --> 00:02:44.294
# Well,
#
# 80
# 00:02:44.736 --> 00:02:48.652
# we had to live there a long time on an Indian man and plough.

# %%
full_transcipt = results_data.get("result",{}).get("transcription",{}).get("full_transcript","")

print(full_transcipt)
# Out:
# I'm going to introduce you to a rather remarkable man. He's Mr Michael Fitzpatrick from Killenie, Maynooth. Now, he started to draw the old age pension in 1927 and seven years ago he got the President's bounty on his hundredth birthday. Now he's from County Clare. He came up from Clare in 1940 to a land commission farm in Maynooth where he lives now. You have seen a lot of changes Mr Fitzpatrick in farming. What would you say was the biggest change? Well machinery. And what sort of a machine would you think made the biggest impression? Well, I think it was the most powerful Well, the reaper and binder is a great one, but, by God, the one for cutting up the ground and throwing a crop is a powerful one too. Well, you were saying at the time you saw the mowing machine first, it made a tremendous impression on you. It did, because I didn't know how it could be done at all. What was the reaction of the people at that time to the mowing machine, Mr. Scott? I had great money, but I wasn't minding it. I could afford it, but the mowing got at it. And some of them I think you told me wouldn't have it on the land at all. Well, I had a good father, I said about our town's land, he wouldn't have it on the land. You see, ten men cut it, three and six months a day. Do you remember cutting the harvest with the reaping hook? Oh, all of it. Of course, for years and years and years, nothing else about cutting. And how do you think that the reaping hook compares with the combine at the present time? Oh, well, there's an awful difference. An awful difference I see anywhere. Because if you come round and slap your head there, if you put a rapier on the vine, there wouldn't be no mice. Now, you also remember, I think, a rather historic thing in the land history of this country, the Boddhike evictions. I do. Could you describe for us what happened at those evictions? You were at them. I was at one of them about five hours before Monday. And what happened? Ah, that was very cruel. There were children and women on the roadside. Well, there was one of them thrown out one day, I was in it, and the baby was only about three days old. And they were sitting, they were thrown on the bank of the river. Oh, it was cruel. And how about the type of food you had to eat at that time, Mr Fispartic? What sort of, what did you live on? Well, we had to live there a long time on an Indian man and plough.
