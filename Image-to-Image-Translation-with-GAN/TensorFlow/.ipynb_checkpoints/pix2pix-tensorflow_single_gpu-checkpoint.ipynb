# %%
import os
import numpy as np
import tensorflow as tf
import time
import glob
import cv2
from tensorflow.keras import layers
import matplotlib.pyplot as plt
# Out:
# 2021-07-19 14:38:02.760381: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
#os.environ['CUDA_VISIBLE_DEVICES'] = '1,2,5,6'


physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)


BUFFER_SIZE = 400
BATCH_SIZE = 32
IMG_WIDTH = 256
IMG_HEIGHT = 256
# Out:
# 2021-07-19 14:38:22.559555: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-19 14:38:22.581107: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-07-19 14:38:22.922334: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-19 14:38:22.923831: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# coreClock: 1.6705GHz coreCount: 10 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 178.99GiB/s
# 2021-07-19 14:38:22.923923: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-19 14:38:23.204653: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-07-19 14:38:23.204884: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-07-19 14:38:23.319484: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-07-19 14:38:23.388512: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-07-19 14:38:23.796269: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-07-19 14:38:24.003451: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-07-19 14:38:24.036578: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-07-19 14:38:24.036929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-19 14:38:24.038417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-19 14:38:24.061423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %%
def imshow(image, figsize=(6,6)):
    image = np.uint8(image)
    plt.figure(figsize=figsize)
    plt.axis('off')
    plt.imshow(image)
    

def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_image(image, channels=3)
    image.set_shape([None, None, 3])
    
    width = tf.shape(image)[1]
    width_half = width // 2
    
    input_image = image[:, :width_half, :]
    target_image = image[:, width_half:, :]
    
    input_image = tf.cast(input_image, dtype=tf.float32)
    target_image = tf.cast(target_image, dtype=tf.float32)
    return input_image, target_image

@tf.function
def random_jittering_mirroring(input_image, target_image, height=286, width=286):
    
    #resizing to 286x286
    input_image = tf.image.resize(input_image, [height, width],
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    target_image = tf.image.resize(target_image, [height, width],
                               method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    
    #cropping (random jittering) to 256x256
    stacked_image = tf.stack([input_image, target_image], axis=0)
    cropped_image = tf.image.random_crop(stacked_image, size=[2, IMG_HEIGHT, IMG_WIDTH, 3])
    
    input_image, target_image = cropped_image[0], cropped_image[1]
    
    if tf.random.uniform(()) > 0.5:
    # random mirroring
        input_image = tf.image.flip_left_right(input_image)
        target_image = tf.image.flip_left_right(target_image)
        
        
    return input_image, target_image

def normalize(input_image, target_image):
    input_image = (input_image / 127.5) - 1
    target_image = (target_image / 127.5) - 1
    return input_image, target_image



def preprocess_fn(image_path):
    input_image, target_image = read_image(image_path)
    input_image, target_image = random_jittering_mirroring(input_image, target_image)
    input_image, target_image = normalize(input_image, target_image)
    return input_image, target_image    



def preprocess_fn_test(image_path):
    input_image, target_image = read_image(image_path)
    #input_image, target_image = random_jittering_mirroring(input_image, target_image)
    input_image, target_image = normalize(input_image, target_image)
    return input_image, target_image

# %%
# In[10]:


image_paths = glob.glob('../../edges2shoes/train_data/train/*')


# In[11]:


val_path = glob.glob('../../edges2shoes/val_data/val/*')




# In[13]:
AUTOTUNE = tf.data.experimental.AUTOTUNE

batch_size = 32

train_dataset = tf.data.Dataset.from_tensor_slices(image_paths)
train_dataset = train_dataset.map(preprocess_fn,
                                  num_parallel_calls=tf.data.experimental.AUTOTUNE)
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.batch(batch_size)


test_dataset = tf.data.Dataset.from_tensor_slices(val_path)
test_dataset = test_dataset.map(preprocess_fn_test)
test_dataset = test_dataset.batch(batch_size)
# Out:
# 2021-07-19 14:38:24.483151: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-19 14:38:24.483551: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-19 14:38:24.484886: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 computeCapability: 6.1
# coreClock: 1.6705GHz coreCount: 10 deviceMemorySize: 5.94GiB deviceMemoryBandwidth: 178.99GiB/s
# 2021-07-19 14:38:24.484961: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-19 14:38:24.485024: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-07-19 14:38:24.485073: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-07-19 14:38:24.485121: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-07-19 14:38:24.485168: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-07-19 14:38:24.485216: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-07-19 14:38:24.485264: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-07-19 14:38:24.485313: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-07-19 14:38:24.485509: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-19 14:38:24.486878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-19 14:38:24.488119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-07-19 14:38:24.559230: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-19 14:38:36.408306: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-19 14:38:36.408375: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-07-19 14:38:36.408397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-07-19 14:38:36.428698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-19 14:38:36.430016: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-19 14:38:36.431261: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-07-19 14:38:36.432296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5545 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1)

# %%
#for (a,b) in train_dataset.take(1):
#    print(a.shape)
#    imshow(a[0])
#    imshow(b[0])


OUTPUT_CHANNELS = 3


def downsample(filters, size, apply_batchnorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)

    result = tf.keras.Sequential()
    result.add(
      layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

    if apply_batchnorm:
        result.add(layers.BatchNormalization())
    #result.add(tfa.layers.InstanceNormalization())


    result.add(tf.keras.layers.LeakyReLU())

    return result



def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)

    result = tf.keras.Sequential()
    result.add(
    tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                    padding='same',
                                    kernel_initializer=initializer,
                                    use_bias=False))

    result.add(tf.keras.layers.BatchNormalization())

    if apply_dropout:
        result.add(tf.keras.layers.Dropout(0.5))

    result.add(tf.keras.layers.ReLU())

    return result

# %%
def Generator():
    inputs = tf.keras.layers.Input(shape=[256,256,3])

    down_stack = [
        downsample(64, 4, apply_batchnorm=False), # (bs, 128, 128, 64)
        downsample(128, 4), # (bs, 64, 64, 128)
        downsample(256, 4), # (bs, 32, 32, 256)
        downsample(512, 4), # (bs, 16, 16, 512)
        downsample(512, 4), # (bs, 8, 8, 512)
        downsample(512, 4), # (bs, 4, 4, 512)
        downsample(512, 4), # (bs, 2, 2, 512)
        downsample(512, 4), # (bs, 1, 1, 512)
      ]
        
    up_stack = [
        upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4), # (bs, 16, 16, 1024)
        upsample(256, 4), # (bs, 32, 32, 512)
        upsample(128, 4), # (bs, 64, 64, 256)
        upsample(64, 4), # (bs, 128, 128, 128)
      ]

    initializer = tf.random_normal_initializer(0., 0.02)
    last = tf.keras.layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                         strides=2,
                                         padding='same',
                                         kernel_initializer=initializer,
                                         activation='tanh') # (bs, 256, 256, 3)

    x = inputs

    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = tf.keras.layers.Concatenate()([x, skip])

    x = last(x)

    return tf.keras.Model(inputs=inputs, outputs=x)

# %%
def Discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)

    inp = tf.keras.layers.Input(shape=[256, 256, 3], name='input_image')
    tar = tf.keras.layers.Input(shape=[256, 256, 3], name='target_image')

    x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels*2)

    down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

    zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                kernel_initializer=initializer,
                                use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

    batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

    leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

    zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

    last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                kernel_initializer=initializer, activation='sigmoid')(zero_pad2) # (bs, 30, 30, 1)

    return tf.keras.Model(inputs=[inp, tar], outputs=last)

# %%
generator = Generator()
discriminator = Discriminator()
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5, beta_2=0.999)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5, beta_2=0.999)

# %%
loss = tf.keras.losses.BinaryCrossentropy()



def generator_loss(disc_generated_output, gen_output, target):
    Lambda =  100
    gan_loss = loss(tf.ones_like(disc_generated_output), disc_generated_output)

    # mean absolute error
    l1_loss = tf.reduce_mean(tf.abs(target - gen_output))
   

    total_gen_loss = gan_loss + (Lambda * l1_loss)

    return total_gen_loss, gan_loss, l1_loss




def discriminator_loss(disc_real_output, disc_generated_output):
    real_loss = loss(tf.ones_like(disc_real_output), disc_real_output)
  
    generated_loss = loss(tf.zeros_like(disc_generated_output), disc_generated_output)

    total_disc_loss = real_loss + generated_loss

    return total_disc_loss

# %%
@tf.function
def train_step(input_image, target, epoch):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        gen_output = generator(input_image, training=True)

        disc_real_output = discriminator([input_image, target], training=True)
        disc_generated_output = discriminator([input_image, gen_output], training=True)

        gen_total_loss, gen_gan_loss, gen_l1_loss = generator_loss(disc_generated_output, gen_output, target)
        disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

    generator_gradients = gen_tape.gradient(gen_total_loss,
                                          generator.trainable_variables)
    discriminator_gradients = disc_tape.gradient(disc_loss,
                                               discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(generator_gradients,
                                          generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(discriminator_gradients,
                                              discriminator.trainable_variables))



    return gen_gan_loss, gen_l1_loss, disc_loss

# %%
EPOCHS = 1

# %%
def generate_images(model, test_input, tar,epoch):
    prediction = model(test_input, training=True)
    display_list = [test_input[0], tar[0], prediction[0]]
    title = ['Input Image', 'Ground Truth', 'Predicted Image']
    image = np.concatenate((test_input[0], tar[0], prediction[0]), axis=1)
    image = (image * 0.5) + 0.5
    cv2.imwrite('results_images_single/'+str(epoch) +'.png', image*255.)

# %%
def fit(train_ds, epochs, test_ds):
    for epoch in range(epochs):
        start = time.time()
        
        for example_input, example_target in test_ds.take(1):
            generate_images(generator, example_input, example_target,epoch)

        # Train
        D_loss_list, G_loss_list, L1_loss_list = [], [], []

        for n, (input_image, target) in train_ds.enumerate():
            gan_l, l1_l, disc_l = train_step(input_image, target, epoch)
            G_loss_list.append(gan_l)
            D_loss_list.append(disc_l)
            L1_loss_list.append(l1_l)


    print('Epoch: [%d/%d]: D_loss: %.3f, G_loss: %.3f, L1_loss: %.3f'  % (
        (epoch), epochs, tf.math.reduce_mean(D_loss_list),\
         tf.math.reduce_mean(G_loss_list),  tf.math.reduce_mean(L1_loss_list)))


    generator.save_weights('model_single/gen_'+ str(epoch) + '.h5')
    print ('Time taken for epoch {} is {} sec\n'.format(epoch + 1,
                                                    time.time()-start))

# %%
fit(train_dataset, EPOCHS, test_dataset)
# Out:
# 2021-07-19 14:38:40.944282: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-07-19 14:38:40.967409: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# 2021-07-19 14:38:42.198897: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-07-19 14:39:05.978843: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-07-19 14:39:11.289651: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-07-19 14:39:12.668151: W tensorflow/core/common_runtime/bfc_allocator.cc:314] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2021-07-19 14:39:22.429104: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 977.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-19 14:39:22.429215: W tensorflow/core/common_runtime/bfc_allocator.cc:248] Allocator (GPU_0_bfc) ran out of memory trying to allocate 968.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-19 14:39:31.893307: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 512.00MiB (rounded to 536870912)requested by op model/concatenate_6/concat
# Current allocation summary follows.
# 2021-07-19 14:39:31.893415: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2021-07-19 14:39:31.893453: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 44, Chunks in use: 44. 11.0KiB allocated for chunks. 11.0KiB in use in bin. 2.7KiB client-requested in use in bin.
# 2021-07-19 14:39:31.893480: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 31, Chunks in use: 30. 15.5KiB allocated for chunks. 15.0KiB in use in bin. 15.0KiB client-requested in use in bin.
# 2021-07-19 14:39:31.893506: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 31, Chunks in use: 31. 31.8KiB allocated for chunks. 31.8KiB in use in bin. 31.0KiB client-requested in use in bin.
# 2021-07-19 14:39:31.893531: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 100, Chunks in use: 100. 207.5KiB allocated for chunks. 207.5KiB in use in bin. 200.0KiB client-requested in use in bin.
# 2021-07-19 14:39:31.893555: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 1, Chunks in use: 0. 4.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-07-19 14:39:31.893581: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 4, Chunks in use: 3. 49.0KiB allocated for chunks. 36.0KiB in use in bin. 36.0KiB client-requested in use in bin.
# 2021-07-19 14:39:31.893607: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 6, Chunks in use: 6. 149.2KiB allocated for chunks. 149.2KiB in use in bin. 144.0KiB client-requested in use in bin.
# 2021-07-19 14:39:31.893632: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 3, Chunks in use: 3. 96.0KiB allocated for chunks. 96.0KiB in use in bin. 96.0KiB client-requested in use in bin.
# 2021-07-19 14:39:31.893654: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 1, Chunks in use: 0. 116.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-07-19 14:39:31.893678: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 7, Chunks in use: 7. 1.25MiB allocated for chunks. 1.25MiB in use in bin. 1.25MiB client-requested in use in bin.
# 2021-07-19 14:39:31.893699: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-07-19 14:39:31.893723: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 12, Chunks in use: 12. 6.46MiB allocated for chunks. 6.46MiB in use in bin. 6.00MiB client-requested in use in bin.
# 2021-07-19 14:39:31.893746: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 5, Chunks in use: 4. 5.00MiB allocated for chunks. 4.00MiB in use in bin. 4.00MiB client-requested in use in bin.
# 2021-07-19 14:39:31.893772: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 14, Chunks in use: 12. 30.00MiB allocated for chunks. 24.00MiB in use in bin. 24.00MiB client-requested in use in bin.
# 2021-07-19 14:39:31.893798: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 4, Chunks in use: 4. 16.00MiB allocated for chunks. 16.00MiB in use in bin. 16.00MiB client-requested in use in bin.
# 2021-07-19 14:39:31.893824: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 12, Chunks in use: 12. 103.49MiB allocated for chunks. 103.49MiB in use in bin. 96.00MiB client-requested in use in bin.
# 2021-07-19 14:39:31.893850: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 19, Chunks in use: 19. 312.00MiB allocated for chunks. 312.00MiB in use in bin. 304.00MiB client-requested in use in bin.
# 2021-07-19 14:39:31.893877: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 19, Chunks in use: 18. 688.50MiB allocated for chunks. 656.00MiB in use in bin. 640.00MiB client-requested in use in bin.
# 2021-07-19 14:39:31.893911: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 15, Chunks in use: 13. 1.21GiB allocated for chunks. 1.05GiB in use in bin. 968.50MiB client-requested in use in bin.
# 2021-07-19 14:39:31.893937: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 10, Chunks in use: 10. 1.31GiB allocated for chunks. 1.31GiB in use in bin. 1.24GiB client-requested in use in bin.
# 2021-07-19 14:39:31.893963: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 7, Chunks in use: 7. 1.77GiB allocated for chunks. 1.77GiB in use in bin. 1.75GiB client-requested in use in bin.
# 2021-07-19 14:39:31.893987: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 512.00MiB was 256.00MiB, Chunk State:
# 2021-07-19 14:39:31.894004: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 446940928
# 2021-07-19 14:39:31.894031: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcb78000000 of size 125960192 next 101
# 2021-07-19 14:39:31.894051: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcb7f820000 of size 125960192 next 342
# 2021-07-19 14:39:31.894069: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcb87040000 of size 195020544 next 18446744073709551615
# 2021-07-19 14:39:31.894086: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 4294967296
# 2021-07-19 14:39:31.894103: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcbdc000000 of size 100663296 next 244
# 2021-07-19 14:39:31.894120: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcbe2000000 of size 100663296 next 245
# 2021-07-19 14:39:31.894136: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcbe8000000 of size 16777216 next 300
# 2021-07-19 14:39:31.894153: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fcbe9000000 of size 34078720 next 247
# 2021-07-19 14:39:31.894169: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcbeb080000 of size 268435456 next 248
# 2021-07-19 14:39:31.894185: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcbfb080000 of size 268435456 next 249
# 2021-07-19 14:39:31.894202: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc0b080000 of size 285212672 next 239
# 2021-07-19 14:39:31.894218: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc1c080000 of size 268435456 next 251
# 2021-07-19 14:39:31.894235: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc2c080000 of size 134217728 next 252
# 2021-07-19 14:39:31.894252: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc34080000 of size 134217728 next 253
# 2021-07-19 14:39:31.894268: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc3c080000 of size 134217728 next 258
# 2021-07-19 14:39:31.894285: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc44080000 of size 67108864 next 261
# 2021-07-19 14:39:31.894302: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc48080000 of size 33554432 next 262
# 2021-07-19 14:39:31.894319: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4a080000 of size 33554432 next 263
# 2021-07-19 14:39:31.894335: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4c080000 of size 33554432 next 268
# 2021-07-19 14:39:31.894352: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4e080000 of size 8388608 next 118
# 2021-07-19 14:39:31.894368: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4e880000 of size 8388608 next 269
# 2021-07-19 14:39:31.894400: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4f080000 of size 8388608 next 272
# 2021-07-19 14:39:31.894417: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4f880000 of size 2097152 next 28
# 2021-07-19 14:39:31.894437: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4fa80000 of size 2097152 next 273
# 2021-07-19 14:39:31.894454: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4fc80000 of size 2097152 next 277
# 2021-07-19 14:39:31.894470: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4fe80000 of size 524288 next 34
# 2021-07-19 14:39:31.894487: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4ff00000 of size 524288 next 278
# 2021-07-19 14:39:31.894503: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc4ff80000 of size 524288 next 282
# 2021-07-19 14:39:31.894520: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50000000 of size 131072 next 38
# 2021-07-19 14:39:31.894536: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50020000 of size 131072 next 283
# 2021-07-19 14:39:31.894552: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50040000 of size 131072 next 287
# 2021-07-19 14:39:31.894568: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50060000 of size 524288 next 120
# 2021-07-19 14:39:31.894585: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc500e0000 of size 2048 next 291
# 2021-07-19 14:39:31.894602: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc500e0800 of size 1048576 next 301
# 2021-07-19 14:39:31.894618: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fcc501e0800 of size 1048576 next 292
# 2021-07-19 14:39:31.894634: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc502e0800 of size 2097152 next 246
# 2021-07-19 14:39:31.894651: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc504e0800 of size 524288 next 297
# 2021-07-19 14:39:31.894667: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50560800 of size 2048 next 305
# 2021-07-19 14:39:31.894683: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50561000 of size 2048 next 306
# 2021-07-19 14:39:31.894699: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50561800 of size 2048 next 308
# 2021-07-19 14:39:31.894715: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50562000 of size 2048 next 309
# 2021-07-19 14:39:31.894731: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50562800 of size 2048 next 312
# 2021-07-19 14:39:31.894747: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50563000 of size 2048 next 313
# 2021-07-19 14:39:31.894763: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fcc50563800 of size 118784 next 299
# 2021-07-19 14:39:31.894780: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc50580800 of size 11925504 next 288
# 2021-07-19 14:39:31.894796: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc510e0000 of size 524288 next 289
# 2021-07-19 14:39:31.894813: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc51160000 of size 4194304 next 293
# 2021-07-19 14:39:31.894830: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc51560000 of size 12707072 next 121
# 2021-07-19 14:39:31.894847: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc5217e500 of size 50331648 next 296
# 2021-07-19 14:39:31.894863: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc5517e500 of size 8388608 next 307
# 2021-07-19 14:39:31.894879: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc5597e500 of size 33554432 next 310
# 2021-07-19 14:39:31.894895: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc5797e500 of size 33554432 next 311
# 2021-07-19 14:39:31.894945: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc5997e500 of size 67108864 next 314
# 2021-07-19 14:39:31.894962: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc5d97e500 of size 67108864 next 315
# 2021-07-19 14:39:31.894981: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc6197e500 of size 67108864 next 317
# 2021-07-19 14:39:31.894998: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc6597e500 of size 134217728 next 319
# 2021-07-19 14:39:31.895014: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc6d97e500 of size 134217728 next 22
# 2021-07-19 14:39:31.895030: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc7597e500 of size 134217728 next 321
# 2021-07-19 14:39:31.895046: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc7d97e500 of size 134217728 next 323
# 2021-07-19 14:39:31.895062: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc8597e500 of size 134217728 next 331
# 2021-07-19 14:39:31.895078: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc8d97e500 of size 67108864 next 95
# 2021-07-19 14:39:31.895094: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcc9197e500 of size 268435456 next 43
# 2021-07-19 14:39:31.895111: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcca197e500 of size 75759616 next 79
# 2021-07-19 14:39:31.895127: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fcca61be500 of size 96206848 next 325
# 2021-07-19 14:39:31.895144: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fccabd7e500 of size 134217728 next 320
# 2021-07-19 14:39:31.895160: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fccb3d7e500 of size 268435456 next 332
# 2021-07-19 14:39:31.895176: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fccc3d7e500 of size 268435456 next 333
# 2021-07-19 14:39:31.895192: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fccd3d7e500 of size 67108864 next 336
# 2021-07-19 14:39:31.895209: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fccd7d7e500 of size 69737216 next 18446744073709551615
# 2021-07-19 14:39:31.895225: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 536870912
# 2021-07-19 14:39:31.895241: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd30000000 of size 33554432 next 148
# 2021-07-19 14:39:31.895258: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd32000000 of size 16777216 next 151
# 2021-07-19 14:39:31.895274: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd33000000 of size 16777216 next 166
# 2021-07-19 14:39:31.895290: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd34000000 of size 16777216 next 169
# 2021-07-19 14:39:31.895306: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd35000000 of size 16777216 next 172
# 2021-07-19 14:39:31.895322: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd36000000 of size 16777216 next 175
# 2021-07-19 14:39:31.895338: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd37000000 of size 16777216 next 178
# 2021-07-19 14:39:31.895354: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd38000000 of size 33554432 next 181
# 2021-07-19 14:39:31.895370: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd3a000000 of size 33554432 next 184
# 2021-07-19 14:39:31.895386: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd3c000000 of size 33554432 next 187
# 2021-07-19 14:39:31.895401: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd3e000000 of size 16777216 next 190
# 2021-07-19 14:39:31.895417: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd3f000000 of size 4194304 next 193
# 2021-07-19 14:39:31.895434: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd3f400000 of size 2097152 next 206
# 2021-07-19 14:39:31.895449: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd3f600000 of size 8388608 next 209
# 2021-07-19 14:39:31.895465: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd3fe00000 of size 2097152 next 217
# 2021-07-19 14:39:31.895482: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd40000000 of size 8388608 next 220
# 2021-07-19 14:39:31.895498: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd40800000 of size 230400 next 233
# 2021-07-19 14:39:31.895515: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd40838400 of size 230400 next 234
# 2021-07-19 14:39:31.895530: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd40870800 of size 230400 next 235
# 2021-07-19 14:39:31.895546: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd408a8c00 of size 230400 next 236
# 2021-07-19 14:39:31.895562: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd408e1000 of size 100663296 next 240
# 2021-07-19 14:39:31.895578: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd468e1000 of size 50331648 next 241
# 2021-07-19 14:39:31.895594: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fcd498e1000 of size 2621440 next 294
# 2021-07-19 14:39:31.895610: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd49b61000 of size 2097152 next 302
# 2021-07-19 14:39:31.895625: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd49d61000 of size 2097152 next 303
# 2021-07-19 14:39:31.895641: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fcd49f61000 of size 3670016 next 243
# 2021-07-19 14:39:31.895659: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd4a2e1000 of size 97644544 next 18446744073709551615
# 2021-07-19 14:39:31.895674: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 268435456
# 2021-07-19 14:39:31.895692: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd68000000 of size 33554432 next 62
# 2021-07-19 14:39:31.895708: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd6a000000 of size 33554432 next 67
# 2021-07-19 14:39:31.895724: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd6c000000 of size 16777216 next 130
# 2021-07-19 14:39:31.895740: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd6d000000 of size 16777216 next 133
# 2021-07-19 14:39:31.895755: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd6e000000 of size 16777216 next 112
# 2021-07-19 14:39:31.895771: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd6f000000 of size 50331648 next 15
# 2021-07-19 14:39:31.895787: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd72000000 of size 16777216 next 138
# 2021-07-19 14:39:31.895803: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd73000000 of size 16777216 next 140
# 2021-07-19 14:39:31.895819: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd74000000 of size 33554432 next 143
# 2021-07-19 14:39:31.895834: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd76000000 of size 33554432 next 18446744073709551615
# 2021-07-19 14:39:31.895850: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 134217728
# 2021-07-19 14:39:31.895866: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd78000000 of size 16777216 next 50
# 2021-07-19 14:39:31.895882: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd79000000 of size 16777216 next 71
# 2021-07-19 14:39:31.895898: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd7a000000 of size 50331648 next 56
# 2021-07-19 14:39:31.895914: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd7d000000 of size 50331648 next 18446744073709551615
# 2021-07-19 14:39:31.895930: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 67108864
# 2021-07-19 14:39:31.895946: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd80000000 of size 16777216 next 31
# 2021-07-19 14:39:31.895962: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd81000000 of size 16777216 next 35
# 2021-07-19 14:39:31.895980: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd82000000 of size 16777216 next 40
# 2021-07-19 14:39:31.895997: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd83000000 of size 4194304 next 76
# 2021-07-19 14:39:31.896013: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd83400000 of size 4194304 next 153
# 2021-07-19 14:39:31.896029: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd83800000 of size 8388608 next 18446744073709551615
# 2021-07-19 14:39:31.896045: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 33554432
# 2021-07-19 14:39:31.896061: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd84000000 of size 8388608 next 27
# 2021-07-19 14:39:31.896078: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd84800000 of size 25165824 next 18446744073709551615
# 2021-07-19 14:39:31.896094: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 16777216
# 2021-07-19 14:39:31.896110: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd86000000 of size 8388608 next 103
# 2021-07-19 14:39:31.896127: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcd86800000 of size 8388608 next 18446744073709551615
# 2021-07-19 14:39:31.896142: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 1048576
# 2021-07-19 14:39:31.896159: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600000 of size 1280 next 1
# 2021-07-19 14:39:31.896176: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600500 of size 256 next 2
# 2021-07-19 14:39:31.896192: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600600 of size 256 next 11
# 2021-07-19 14:39:31.896209: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600700 of size 512 next 12
# 2021-07-19 14:39:31.896225: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600900 of size 256 next 13
# 2021-07-19 14:39:31.896240: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600a00 of size 512 next 14
# 2021-07-19 14:39:31.896256: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600c00 of size 256 next 242
# 2021-07-19 14:39:31.896272: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600d00 of size 256 next 295
# 2021-07-19 14:39:31.896288: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600e00 of size 256 next 298
# 2021-07-19 14:39:31.896303: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4600f00 of size 256 next 16
# 2021-07-19 14:39:31.896320: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4601000 of size 1024 next 18
# 2021-07-19 14:39:31.896336: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4601400 of size 1024 next 21
# 2021-07-19 14:39:31.896352: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4601800 of size 2048 next 23
# 2021-07-19 14:39:31.896368: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4602000 of size 2048 next 25
# 2021-07-19 14:39:31.896385: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4602800 of size 3584 next 3
# 2021-07-19 14:39:31.896401: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4603600 of size 256 next 4
# 2021-07-19 14:39:31.896417: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4603700 of size 2048 next 274
# 2021-07-19 14:39:31.896433: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4603f00 of size 2048 next 29
# 2021-07-19 14:39:31.896448: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4604700 of size 2048 next 32
# 2021-07-19 14:39:31.896464: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4604f00 of size 2048 next 33
# 2021-07-19 14:39:31.896483: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4605700 of size 2048 next 279
# 2021-07-19 14:39:31.896499: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4605f00 of size 2048 next 5
# 2021-07-19 14:39:31.896515: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4606700 of size 256 next 6
# 2021-07-19 14:39:31.896532: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4606800 of size 12288 next 7
# 2021-07-19 14:39:31.896549: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4609800 of size 1009664 next 18446744073709551615
# 2021-07-19 14:39:31.896565: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 2097152
# 2021-07-19 14:39:31.896581: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4800000 of size 2048 next 36
# 2021-07-19 14:39:31.896598: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4800800 of size 2048 next 37
# 2021-07-19 14:39:31.896613: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4801000 of size 2048 next 284
# 2021-07-19 14:39:31.896629: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4801800 of size 2048 next 39
# 2021-07-19 14:39:31.896645: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4802000 of size 2048 next 41
# 2021-07-19 14:39:31.896661: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4802800 of size 2048 next 42
# 2021-07-19 14:39:31.896677: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4803000 of size 2048 next 290
# 2021-07-19 14:39:31.896693: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4803800 of size 2048 next 44
# 2021-07-19 14:39:31.896709: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4804000 of size 2048 next 45
# 2021-07-19 14:39:31.896725: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4804800 of size 2048 next 46
# 2021-07-19 14:39:31.896741: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4805000 of size 2048 next 304
# 2021-07-19 14:39:31.896756: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4805800 of size 2048 next 48
# 2021-07-19 14:39:31.896772: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4806000 of size 2048 next 51
# 2021-07-19 14:39:31.896788: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4806800 of size 2048 next 52
# 2021-07-19 14:39:31.896804: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4807000 of size 256 next 53
# 2021-07-19 14:39:31.896820: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4807100 of size 256 next 122
# 2021-07-19 14:39:31.896836: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4807200 of size 3584 next 54
# 2021-07-19 14:39:31.896852: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4808000 of size 2048 next 55
# 2021-07-19 14:39:31.896868: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4808800 of size 2048 next 57
# 2021-07-19 14:39:31.896884: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4809000 of size 2048 next 58
# 2021-07-19 14:39:31.896900: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4809800 of size 1024 next 316
# 2021-07-19 14:39:31.896916: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4809c00 of size 1024 next 59
# 2021-07-19 14:39:31.896932: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480a000 of size 2048 next 60
# 2021-07-19 14:39:31.896948: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480a800 of size 2048 next 63
# 2021-07-19 14:39:31.896964: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480b000 of size 1024 next 318
# 2021-07-19 14:39:31.896980: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480b400 of size 1024 next 64
# 2021-07-19 14:39:31.896997: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480b800 of size 512 next 324
# 2021-07-19 14:39:31.897013: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480ba00 of size 512 next 326
# 2021-07-19 14:39:31.897029: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480bc00 of size 512 next 327
# 2021-07-19 14:39:31.897045: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480be00 of size 512 next 65
# 2021-07-19 14:39:31.897061: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480c000 of size 2048 next 66
# 2021-07-19 14:39:31.897077: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480c800 of size 2048 next 68
# 2021-07-19 14:39:31.897092: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480d000 of size 512 next 125
# 2021-07-19 14:39:31.897108: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480d200 of size 1024 next 126
# 2021-07-19 14:39:31.897124: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480d600 of size 1024 next 127
# 2021-07-19 14:39:31.897141: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480da00 of size 1536 next 70
# 2021-07-19 14:39:31.897157: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480e000 of size 1024 next 72
# 2021-07-19 14:39:31.897173: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480e400 of size 1024 next 73
# 2021-07-19 14:39:31.897189: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480e800 of size 1024 next 116
# 2021-07-19 14:39:31.897205: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fcdd480ec00 of size 512 next 74
# 2021-07-19 14:39:31.897220: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480ee00 of size 256 next 113
# 2021-07-19 14:39:31.897236: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480ef00 of size 256 next 75
# 2021-07-19 14:39:31.897252: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480f000 of size 512 next 77
# 2021-07-19 14:39:31.897268: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480f200 of size 512 next 78
# 2021-07-19 14:39:31.897284: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480f400 of size 256 next 124
# 2021-07-19 14:39:31.897300: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480f500 of size 256 next 69
# 2021-07-19 14:39:31.897316: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480f600 of size 512 next 80
# 2021-07-19 14:39:31.897332: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480f800 of size 256 next 83
# 2021-07-19 14:39:31.897347: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480f900 of size 256 next 84
# 2021-07-19 14:39:31.897363: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480fa00 of size 256 next 85
# 2021-07-19 14:39:31.897379: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480fb00 of size 256 next 86
# 2021-07-19 14:39:31.897395: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480fc00 of size 256 next 87
# 2021-07-19 14:39:31.897411: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd480fd00 of size 2048 next 141
# 2021-07-19 14:39:31.897427: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4810500 of size 2048 next 142
# 2021-07-19 14:39:31.897443: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4810d00 of size 2048 next 144
# 2021-07-19 14:39:31.897459: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4811500 of size 2048 next 145
# 2021-07-19 14:39:31.897475: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4811d00 of size 2048 next 146
# 2021-07-19 14:39:31.897491: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4812500 of size 2048 next 147
# 2021-07-19 14:39:31.897509: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4812d00 of size 2048 next 149
# 2021-07-19 14:39:31.897525: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4813500 of size 2048 next 150
# 2021-07-19 14:39:31.897541: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4813d00 of size 1024 next 152
# 2021-07-19 14:39:31.897557: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4814100 of size 512 next 154
# 2021-07-19 14:39:31.897573: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4814300 of size 512 next 155
# 2021-07-19 14:39:31.897589: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4814500 of size 256 next 156
# 2021-07-19 14:39:31.897605: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4814600 of size 256 next 157
# 2021-07-19 14:39:31.897622: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4814700 of size 29952 next 88
# 2021-07-19 14:39:31.897639: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd481bc00 of size 24576 next 89
# 2021-07-19 14:39:31.897655: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4821c00 of size 512 next 93
# 2021-07-19 14:39:31.897671: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4821e00 of size 512 next 94
# 2021-07-19 14:39:31.897687: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4822000 of size 1024 next 96
# 2021-07-19 14:39:31.897703: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4822400 of size 1024 next 99
# 2021-07-19 14:39:31.897719: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4822800 of size 1024 next 100
# 2021-07-19 14:39:31.897735: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4822c00 of size 2048 next 102
# 2021-07-19 14:39:31.897751: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4823400 of size 2048 next 104
# 2021-07-19 14:39:31.897767: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4823c00 of size 2048 next 105
# 2021-07-19 14:39:31.897783: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fcdd4824400 of size 4096 next 107
# 2021-07-19 14:39:31.897799: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4825400 of size 256 next 110
# 2021-07-19 14:39:31.897815: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4825500 of size 1024 next 117
# 2021-07-19 14:39:31.897832: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4825900 of size 3072 next 119
# 2021-07-19 14:39:31.897848: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4826500 of size 2048 next 123
# 2021-07-19 14:39:31.897864: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4826d00 of size 3840 next 90
# 2021-07-19 14:39:31.897881: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4827c00 of size 24576 next 91
# 2021-07-19 14:39:31.897897: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd482dc00 of size 12288 next 47
# 2021-07-19 14:39:31.897913: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4830c00 of size 2048 next 128
# 2021-07-19 14:39:31.897929: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4831400 of size 2048 next 129
# 2021-07-19 14:39:31.897945: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4831c00 of size 2048 next 131
# 2021-07-19 14:39:31.897961: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4832400 of size 2048 next 132
# 2021-07-19 14:39:31.897977: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4832c00 of size 2048 next 134
# 2021-07-19 14:39:31.897993: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4833400 of size 2048 next 135
# 2021-07-19 14:39:31.898009: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4833c00 of size 2048 next 136
# 2021-07-19 14:39:31.898027: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4834400 of size 2048 next 137
# 2021-07-19 14:39:31.898043: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4834c00 of size 2048 next 139
# 2021-07-19 14:39:31.898059: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4835400 of size 2048 next 108
# 2021-07-19 14:39:31.898076: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4835c00 of size 32768 next 109
# 2021-07-19 14:39:31.898092: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd483dc00 of size 256 next 158
# 2021-07-19 14:39:31.898108: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd483dd00 of size 12288 next 159
# 2021-07-19 14:39:31.898125: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4840d00 of size 512 next 160
# 2021-07-19 14:39:31.898141: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4840f00 of size 512 next 161
# 2021-07-19 14:39:31.898157: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4841100 of size 1024 next 162
# 2021-07-19 14:39:31.898173: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4841500 of size 1024 next 163
# 2021-07-19 14:39:31.898189: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4841900 of size 2048 next 164
# 2021-07-19 14:39:31.898220: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4842100 of size 2048 next 165
# 2021-07-19 14:39:31.898224: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4842900 of size 2048 next 167
# 2021-07-19 14:39:31.898227: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4843100 of size 2048 next 168
# 2021-07-19 14:39:31.898246: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4843900 of size 2048 next 170
# 2021-07-19 14:39:31.898249: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4844100 of size 2048 next 171
# 2021-07-19 14:39:31.898252: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4844900 of size 2048 next 173
# 2021-07-19 14:39:31.898274: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4845100 of size 2048 next 174
# 2021-07-19 14:39:31.898278: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4845900 of size 2048 next 176
# 2021-07-19 14:39:31.898281: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4846100 of size 2048 next 177
# 2021-07-19 14:39:31.898284: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4846900 of size 2048 next 179
# 2021-07-19 14:39:31.898287: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4847100 of size 2048 next 180
# 2021-07-19 14:39:31.898290: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4847900 of size 2048 next 182
# 2021-07-19 14:39:31.898294: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4848100 of size 2048 next 183
# 2021-07-19 14:39:31.898297: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4848900 of size 2048 next 185
# 2021-07-19 14:39:31.898300: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4849100 of size 2048 next 186
# 2021-07-19 14:39:31.898303: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4849900 of size 2048 next 188
# 2021-07-19 14:39:31.898306: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd484a100 of size 2048 next 189
# 2021-07-19 14:39:31.898309: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd484a900 of size 1024 next 191
# 2021-07-19 14:39:31.898312: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd484ad00 of size 1024 next 192
# 2021-07-19 14:39:31.898316: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd484b100 of size 512 next 194
# 2021-07-19 14:39:31.898319: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd484b300 of size 512 next 195
# 2021-07-19 14:39:31.898322: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd484b500 of size 256 next 197
# 2021-07-19 14:39:31.898326: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd484b600 of size 256 next 198
# 2021-07-19 14:39:31.898329: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd484b700 of size 24576 next 199
# 2021-07-19 14:39:31.898332: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4851700 of size 256 next 200
# 2021-07-19 14:39:31.898335: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4851800 of size 256 next 201
# 2021-07-19 14:39:31.898338: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4851900 of size 24576 next 202
# 2021-07-19 14:39:31.898342: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4857900 of size 512 next 204
# 2021-07-19 14:39:31.898345: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4857b00 of size 512 next 205
# 2021-07-19 14:39:31.898348: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4857d00 of size 1024 next 207
# 2021-07-19 14:39:31.898351: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4858100 of size 1024 next 208
# 2021-07-19 14:39:31.898354: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4858500 of size 2048 next 210
# 2021-07-19 14:39:31.898358: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4858d00 of size 2048 next 211
# 2021-07-19 14:39:31.898361: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4859500 of size 32768 next 212
# 2021-07-19 14:39:31.898364: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4861500 of size 256 next 213
# 2021-07-19 14:39:31.898367: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4861600 of size 24576 next 214
# 2021-07-19 14:39:31.898370: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4867600 of size 512 next 215
# 2021-07-19 14:39:31.898373: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4867800 of size 512 next 216
# 2021-07-19 14:39:31.898377: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4867a00 of size 1024 next 218
# 2021-07-19 14:39:31.898380: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4867e00 of size 1024 next 219
# 2021-07-19 14:39:31.898383: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4868200 of size 2048 next 221
# 2021-07-19 14:39:31.898386: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4868a00 of size 2048 next 222
# 2021-07-19 14:39:31.898389: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4869200 of size 32768 next 223
# 2021-07-19 14:39:31.898393: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871200 of size 256 next 224
# 2021-07-19 14:39:31.898396: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871300 of size 256 next 225
# 2021-07-19 14:39:31.898399: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871400 of size 256 next 226
# 2021-07-19 14:39:31.898402: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871500 of size 256 next 227
# 2021-07-19 14:39:31.898405: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871600 of size 256 next 228
# 2021-07-19 14:39:31.898408: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871700 of size 256 next 229
# 2021-07-19 14:39:31.898412: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871800 of size 256 next 230
# 2021-07-19 14:39:31.898415: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871900 of size 256 next 231
# 2021-07-19 14:39:31.898418: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871a00 of size 256 next 232
# 2021-07-19 14:39:31.898421: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871b00 of size 256 next 237
# 2021-07-19 14:39:31.898424: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871c00 of size 256 next 238
# 2021-07-19 14:39:31.898428: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871d00 of size 512 next 322
# 2021-07-19 14:39:31.898431: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871f00 of size 512 next 328
# 2021-07-19 14:39:31.898434: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872100 of size 512 next 329
# 2021-07-19 14:39:31.898437: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872300 of size 512 next 330
# 2021-07-19 14:39:31.898440: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872500 of size 1024 next 337
# 2021-07-19 14:39:31.898444: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872900 of size 1024 next 338
# 2021-07-19 14:39:31.898447: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872d00 of size 256 next 335
# 2021-07-19 14:39:31.898450: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872e00 of size 256 next 339
# ...
# 2021-07-19 14:39:32.435403: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871a00 of size 256 next 232
# 2021-07-19 14:39:32.435423: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871b00 of size 256 next 237
# 2021-07-19 14:39:32.435426: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871c00 of size 256 next 238
# 2021-07-19 14:39:32.435451: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871d00 of size 512 next 322
# 2021-07-19 14:39:32.435454: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4871f00 of size 512 next 328
# 2021-07-19 14:39:32.435458: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872100 of size 512 next 329
# 2021-07-19 14:39:32.435461: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872300 of size 512 next 330
# 2021-07-19 14:39:32.435484: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872500 of size 1024 next 337
# 2021-07-19 14:39:32.435487: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872900 of size 1024 next 338
# 2021-07-19 14:39:32.435490: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872d00 of size 256 next 335
# 2021-07-19 14:39:32.435493: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872e00 of size 256 next 339
# 2021-07-19 14:39:32.435497: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4872f00 of size 256 next 340
# 2021-07-19 14:39:32.435500: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4873000 of size 256 next 341
# 2021-07-19 14:39:32.435503: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4873100 of size 2048 next 343
# 2021-07-19 14:39:32.435520: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4873900 of size 2048 next 344
# 2021-07-19 14:39:32.435523: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4874100 of size 2048 next 345
# 2021-07-19 14:39:32.435527: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7fcdd4874900 of size 13312 next 250
# 2021-07-19 14:39:32.435530: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4877d00 of size 512 next 254
# 2021-07-19 14:39:32.435533: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4877f00 of size 512 next 255
# 2021-07-19 14:39:32.435536: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4878100 of size 512 next 256
# 2021-07-19 14:39:32.435539: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4878300 of size 512 next 257
# 2021-07-19 14:39:32.435542: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4878500 of size 1024 next 114
# 2021-07-19 14:39:32.435546: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4878900 of size 1024 next 259
# 2021-07-19 14:39:32.435549: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4878d00 of size 1024 next 260
# 2021-07-19 14:39:32.435552: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4879100 of size 2048 next 264
# 2021-07-19 14:39:32.435555: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4879900 of size 2048 next 265
# 2021-07-19 14:39:32.435558: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487a100 of size 2048 next 266
# 2021-07-19 14:39:32.435562: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487a900 of size 2048 next 267
# 2021-07-19 14:39:32.435565: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487b100 of size 2048 next 270
# 2021-07-19 14:39:32.435568: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487b900 of size 2048 next 271
# 2021-07-19 14:39:32.435571: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487c100 of size 2048 next 275
# 2021-07-19 14:39:32.435574: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487c900 of size 2048 next 276
# 2021-07-19 14:39:32.435578: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487d100 of size 2048 next 280
# 2021-07-19 14:39:32.435581: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487d900 of size 2048 next 281
# 2021-07-19 14:39:32.435585: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487e100 of size 2048 next 285
# 2021-07-19 14:39:32.435588: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487e900 of size 2048 next 286
# 2021-07-19 14:39:32.435591: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd487f100 of size 3840 next 9
# 2021-07-19 14:39:32.435594: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4880000 of size 524288 next 10
# 2021-07-19 14:39:32.435598: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4900000 of size 524288 next 92
# 2021-07-19 14:39:32.435601: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4980000 of size 524288 next 18446744073709551615
# 2021-07-19 14:39:32.435604: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 4194304
# 2021-07-19 14:39:32.435608: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4a00000 of size 1048576 next 81
# 2021-07-19 14:39:32.435611: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4b00000 of size 1048576 next 82
# 2021-07-19 14:39:32.435614: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4c00000 of size 2097152 next 18446744073709551615
# 2021-07-19 14:39:32.435617: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 8388608
# 2021-07-19 14:39:32.435621: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd4e00000 of size 2097152 next 20
# 2021-07-19 14:39:32.435624: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd5000000 of size 2097152 next 97
# 2021-07-19 14:39:32.435627: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd5200000 of size 2097152 next 98
# 2021-07-19 14:39:32.435630: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd5400000 of size 1048576 next 196
# 2021-07-19 14:39:32.435649: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd5500000 of size 524288 next 203
# 2021-07-19 14:39:32.435653: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7fcdd5580000 of size 524288 next 18446744073709551615
# 2021-07-19 14:39:32.435674: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]      Summary of in-use Chunks by size:
# 2021-07-19 14:39:32.435680: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 44 Chunks of size 256 totalling 11.0KiB
# 2021-07-19 14:39:32.435684: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 30 Chunks of size 512 totalling 15.0KiB
# 2021-07-19 14:39:32.435688: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 29 Chunks of size 1024 totalling 29.0KiB
# 2021-07-19 14:39:32.435692: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1280 totalling 1.2KiB
# 2021-07-19 14:39:32.435696: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1536 totalling 1.5KiB
# 2021-07-19 14:39:32.435700: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 95 Chunks of size 2048 totalling 190.0KiB
# 2021-07-19 14:39:32.435723: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 3072 totalling 3.0KiB
# 2021-07-19 14:39:32.435727: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 3584 totalling 7.0KiB
# 2021-07-19 14:39:32.435731: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 3840 totalling 7.5KiB
# 2021-07-19 14:39:32.435748: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 12288 totalling 36.0KiB
# 2021-07-19 14:39:32.435752: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 5 Chunks of size 24576 totalling 120.0KiB
# 2021-07-19 14:39:32.435756: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 29952 totalling 29.2KiB
# 2021-07-19 14:39:32.435760: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 32768 totalling 96.0KiB
# 2021-07-19 14:39:32.435763: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 131072 totalling 384.0KiB
# 2021-07-19 14:39:32.435767: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 4 Chunks of size 230400 totalling 900.0KiB
# 2021-07-19 14:39:32.435771: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 11 Chunks of size 524288 totalling 5.50MiB
# 2021-07-19 14:39:32.435775: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1009664 totalling 986.0KiB
# 2021-07-19 14:39:32.435778: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 4 Chunks of size 1048576 totalling 4.00MiB
# 2021-07-19 14:39:32.435782: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 12 Chunks of size 2097152 totalling 24.00MiB
# 2021-07-19 14:39:32.435786: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 4 Chunks of size 4194304 totalling 16.00MiB
# 2021-07-19 14:39:32.435790: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 10 Chunks of size 8388608 totalling 80.00MiB
# 2021-07-19 14:39:32.435794: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 11925504 totalling 11.37MiB
# 2021-07-19 14:39:32.435798: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 12707072 totalling 12.12MiB
# 2021-07-19 14:39:32.435802: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 18 Chunks of size 16777216 totalling 288.00MiB
# 2021-07-19 14:39:32.435806: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 25165824 totalling 24.00MiB
# 2021-07-19 14:39:32.435810: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 13 Chunks of size 33554432 totalling 416.00MiB
# 2021-07-19 14:39:32.435813: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 5 Chunks of size 50331648 totalling 240.00MiB
# 2021-07-19 14:39:32.435817: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 6 Chunks of size 67108864 totalling 384.00MiB
# 2021-07-19 14:39:32.435837: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 75759616 totalling 72.25MiB
# 2021-07-19 14:39:32.435841: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 97644544 totalling 93.12MiB
# 2021-07-19 14:39:32.435845: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 100663296 totalling 288.00MiB
# 2021-07-19 14:39:32.435868: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 125960192 totalling 240.25MiB
# 2021-07-19 14:39:32.435871: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 9 Chunks of size 134217728 totalling 1.12GiB
# 2021-07-19 14:39:32.435875: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 195020544 totalling 185.99MiB
# 2021-07-19 14:39:32.435879: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 6 Chunks of size 268435456 totalling 1.50GiB
# 2021-07-19 14:39:32.435883: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 285212672 totalling 272.00MiB
# 2021-07-19 14:39:32.435886: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 5.22GiB
# 2021-07-19 14:39:32.435890: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 5814601472 memory_limit_: 5814601664 available bytes: 192 curr_region_allocation_bytes_: 17179869184
# 2021-07-19 14:39:32.435917: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                      5814601664
# InUse:                      5607101952
# MaxInUse:                   5607106048
# NumAllocs:                         737
# MaxAllocSize:               2726297600
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2021-07-19 14:39:32.435945: W tensorflow/core/common_runtime/bfc_allocator.cc:441] ****************************************************************************************************
# 2021-07-19 14:39:32.435961: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at pad_op.cc:114 : Resource exhausted: OOM when allocating tensor with shape[32768,33,33] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_146289/2212100343.py in <module>
# ----> 1 fit(train_dataset, EPOCHS, test_dataset)
#
# /tmp/ipykernel_146289/3100356666.py in fit(train_ds, epochs, test_ds)
#      10
#      11         for n, (input_image, target) in train_ds.enumerate():
# ---> 12             gan_l, l1_l, disc_l = train_step(input_image, target, epoch)
#      13             G_loss_list.append(gan_l)
#      14             D_loss_list.append(disc_l)
#
# ~/miniconda3/envs/gan_series/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/miniconda3/envs/gan_series/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     886         # Lifting succeeded, so variables are initialized and we can run the
#     887         # stateless function.
# --> 888         return self._stateless_fn(*args, **kwds)
#     889     else:
#     890       _, _, _, filtered_flat_args = \
#
# ~/miniconda3/envs/gan_series/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/miniconda3/envs/gan_series/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/miniconda3/envs/gan_series/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/miniconda3/envs/gan_series/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[64,128,128,128] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node model/concatenate_6/concat (defined at tmp/ipykernel_146289/3186482716.py:4) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_step_6648]
#
# Function call stack:
# train_step
