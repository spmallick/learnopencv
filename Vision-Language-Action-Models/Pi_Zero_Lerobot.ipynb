# %%
# !git clone https://github.com/huggingface/lerobot.git
# Out:
# Cloning into 'lerobot'...
# remote: Enumerating objects: 21130, done.
# remote: Counting objects: 100% (2260/2260), done.
# remote: Compressing objects: 100% (883/883), done.
# remote: Total 21130 (delta 1834), reused 1377 (delta 1377), pack-reused 18870 (from 3)
# Receiving objects: 100% (21130/21130), 136.03 MiB | 16.47 MiB/s, done.
# Resolving deltas: 100% (13307/13307), done.
# Filtering content: 100% (40/40), 65.23 MiB | 19.58 MiB/s, done.

# %%
# %cd lerobot
# Out:
# /content/lerobot/lerobot

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: av>=12.0.5 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (14.3.0)
# Requirement already satisfied: cmake>=3.29.0.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.31.6)
# Requirement already satisfied: datasets>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.5.0)
# Requirement already satisfied: deepdiff>=7.0.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (8.4.2)
# Requirement already satisfied: diffusers>=0.27.2 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.32.2)
# Requirement already satisfied: draccus>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.10.0)
# Requirement already satisfied: einops>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.8.1)
# Requirement already satisfied: flask>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.1.0)
# Requirement already satisfied: gdown>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (5.2.0)
# Requirement already satisfied: gymnasium==0.29.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.29.1)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.13.0)
# Requirement already satisfied: huggingface-hub>=0.27.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.30.1)
# Requirement already satisfied: imageio>=2.34.0 in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]>=2.34.0->lerobot==0.1.0) (2.37.0)
# Requirement already satisfied: jsonlines>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (4.0.0)
# Requirement already satisfied: numba>=0.59.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.60.0)
# Requirement already satisfied: omegaconf>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (2.3.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (4.11.0.86)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (24.2)
# Requirement already satisfied: pymunk>=6.6.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (6.11.1)
# Requirement already satisfied: pynput>=1.7.7 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (1.8.1)
# Requirement already satisfied: pyzmq>=26.2.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (26.4.0)
# Requirement already satisfied: rerun-sdk>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.22.1)
# Requirement already satisfied: termcolor>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.0.1)
# Requirement already satisfied: torch>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: torchcodec>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.2.1)
# Requirement already satisfied: torchvision>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: wandb>=0.16.3 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.19.9)
# Requirement already satisfied: zarr>=2.17.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.0.6)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (4.13.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.19.0->lerobot==0.1.0) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (3.11.15)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (6.0.2)
# Requirement already satisfied: orderly-set<6,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from deepdiff>=7.0.1->lerobot==0.1.0) (5.3.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (8.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (2024.11.6)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (0.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (11.1.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (1.3.4)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (0.9.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (1.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown>=5.1.0->lerobot==0.1.0) (4.13.3)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (3.0.50)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]>=2.34.0->lerobot==0.1.0) (0.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]>=2.34.0->lerobot==0.1.0) (5.9.5)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonlines>=4.0.0->lerobot==0.1.0) (25.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.59.0->lerobot==0.1.0) (0.43.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf>=2.3.0->lerobot==0.1.0) (4.9.3)
# Requirement already satisfied: cffi>=1.17.1 in /usr/local/lib/python3.11/dist-packages (from pymunk>=6.6.0->lerobot==0.1.0) (1.17.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pynput>=1.7.7->lerobot==0.1.0) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.11/dist-packages (from pynput>=1.7.7->lerobot==0.1.0) (1.9.1)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.11/dist-packages (from pynput>=1.7.7->lerobot==0.1.0) (0.33)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.2.1->lerobot==0.1.0) (1.3.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (5.29.4)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (2.11.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (2.25.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (75.2.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.11/dist-packages (from zarr>=2.17.0->lerobot==0.1.0) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.11/dist-packages (from numcodecs[crc32c]>=0.14->zarr>=2.17.0->lerobot==0.1.0) (0.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.17.1->pymunk>=6.6.0->lerobot==0.1.0) (2.22)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0) (4.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->flask>=3.0.3->lerobot==0.1.0) (3.0.2)
# Requirement already satisfied: crc32c>=2.7 in /usr/local/lib/python3.11/dist-packages (from numcodecs[crc32c]>=0.14->zarr>=2.17.0->lerobot==0.1.0) (2.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (2025.1.31)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect~=0.9.0->draccus>=0.10.0->lerobot==0.1.0) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown>=5.1.0->lerobot==0.1.0) (2.6)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers>=0.27.2->lerobot==0.1.0) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.0->lerobot==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.0->lerobot==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.0->lerobot==0.1.0) (2025.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown>=5.1.0->lerobot==0.1.0) (1.7.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0) (5.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.2.13)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.1.0-py3-none-any.whl size=15386 sha256=15dda02b6d2865e6d3ed06e59689a71564cae251559bc5b22bc2e424b4b02254
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fys594p9/wheels/15/0d/02/b9c6ff1c78574dee99101ad231194b3425eb4cd784ce8c8338
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.1.0
#     Uninstalling lerobot-0.1.0:
#       Successfully uninstalled lerobot-0.1.0
# Successfully installed lerobot-0.1.0

# %%
# !pip install -e ".[pi0]"
# !pip install -e ".[aloha, pusht]"
# Out:
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: av>=12.0.5 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (14.3.0)
# Requirement already satisfied: cmake>=3.29.0.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.31.6)
# Requirement already satisfied: datasets>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.5.0)
# Requirement already satisfied: deepdiff>=7.0.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (8.4.2)
# Requirement already satisfied: diffusers>=0.27.2 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.32.2)
# Requirement already satisfied: draccus>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.10.0)
# Requirement already satisfied: einops>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.8.1)
# Requirement already satisfied: flask>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.1.0)
# Requirement already satisfied: gdown>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (5.2.0)
# Requirement already satisfied: gymnasium==0.29.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.29.1)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.13.0)
# Requirement already satisfied: huggingface-hub>=0.27.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.30.1)
# Requirement already satisfied: imageio>=2.34.0 in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]>=2.34.0->lerobot==0.1.0) (2.37.0)
# Requirement already satisfied: jsonlines>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (4.0.0)
# Requirement already satisfied: numba>=0.59.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.60.0)
# Requirement already satisfied: omegaconf>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (2.3.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (4.11.0.86)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (24.2)
# Requirement already satisfied: pymunk>=6.6.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (6.11.1)
# Requirement already satisfied: pynput>=1.7.7 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (1.8.1)
# Requirement already satisfied: pyzmq>=26.2.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (26.4.0)
# Requirement already satisfied: rerun-sdk>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.22.1)
# Requirement already satisfied: termcolor>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.0.1)
# Requirement already satisfied: torch>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: torchcodec>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.2.1)
# Requirement already satisfied: torchvision>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: wandb>=0.16.3 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.19.9)
# Requirement already satisfied: zarr>=2.17.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.0.6)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (4.13.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (0.0.4)
# Requirement already satisfied: transformers>=4.48.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (4.50.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.19.0->lerobot==0.1.0) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (3.11.15)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (6.0.2)
# Requirement already satisfied: orderly-set<6,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from deepdiff>=7.0.1->lerobot==0.1.0) (5.3.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (8.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (2024.11.6)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (0.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (11.1.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (1.3.4)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (0.9.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (1.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown>=5.1.0->lerobot==0.1.0) (4.13.3)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (3.0.50)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]>=2.34.0->lerobot==0.1.0) (0.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]>=2.34.0->lerobot==0.1.0) (5.9.5)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonlines>=4.0.0->lerobot==0.1.0) (25.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.59.0->lerobot==0.1.0) (0.43.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf>=2.3.0->lerobot==0.1.0) (4.9.3)
# Requirement already satisfied: cffi>=1.17.1 in /usr/local/lib/python3.11/dist-packages (from pymunk>=6.6.0->lerobot==0.1.0) (1.17.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pynput>=1.7.7->lerobot==0.1.0) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.11/dist-packages (from pynput>=1.7.7->lerobot==0.1.0) (1.9.1)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.11/dist-packages (from pynput>=1.7.7->lerobot==0.1.0) (0.33)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.2.1->lerobot==0.1.0) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0->lerobot==0.1.0) (0.21.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (5.29.4)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (2.11.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (2.25.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (75.2.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.11/dist-packages (from zarr>=2.17.0->lerobot==0.1.0) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.11/dist-packages (from numcodecs[crc32c]>=0.14->zarr>=2.17.0->lerobot==0.1.0) (0.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.17.1->pymunk>=6.6.0->lerobot==0.1.0) (2.22)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0) (4.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->flask>=3.0.3->lerobot==0.1.0) (3.0.2)
# Requirement already satisfied: crc32c>=2.7 in /usr/local/lib/python3.11/dist-packages (from numcodecs[crc32c]>=0.14->zarr>=2.17.0->lerobot==0.1.0) (2.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (2025.1.31)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect~=0.9.0->draccus>=0.10.0->lerobot==0.1.0) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown>=5.1.0->lerobot==0.1.0) (2.6)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers>=0.27.2->lerobot==0.1.0) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.0->lerobot==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.0->lerobot==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.0->lerobot==0.1.0) (2025.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown>=5.1.0->lerobot==0.1.0) (1.7.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0) (5.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.2.13)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.1.0-py3-none-any.whl size=15386 sha256=15dda02b6d2865e6d3ed06e59689a71564cae251559bc5b22bc2e424b4b02254
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p971cf08/wheels/15/0d/02/b9c6ff1c78574dee99101ad231194b3425eb4cd784ce8c8338
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.1.0
#     Uninstalling lerobot-0.1.0:
#       Successfully uninstalled lerobot-0.1.0
# Successfully installed lerobot-0.1.0
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: av>=12.0.5 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (14.3.0)
# Requirement already satisfied: cmake>=3.29.0.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.31.6)
# Requirement already satisfied: datasets>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.5.0)
# Requirement already satisfied: deepdiff>=7.0.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (8.4.2)
# Requirement already satisfied: diffusers>=0.27.2 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.32.2)
# Requirement already satisfied: draccus>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.10.0)
# Requirement already satisfied: einops>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.8.1)
# Requirement already satisfied: flask>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.1.0)
# Requirement already satisfied: gdown>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (5.2.0)
# Requirement already satisfied: gymnasium==0.29.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.29.1)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.13.0)
# Requirement already satisfied: huggingface-hub>=0.27.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.30.1)
# Requirement already satisfied: imageio>=2.34.0 in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]>=2.34.0->lerobot==0.1.0) (2.37.0)
# Requirement already satisfied: jsonlines>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (4.0.0)
# Requirement already satisfied: numba>=0.59.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.60.0)
# Requirement already satisfied: omegaconf>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (2.3.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (4.11.0.86)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (24.2)
# Requirement already satisfied: pymunk>=6.6.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (6.11.1)
# Requirement already satisfied: pynput>=1.7.7 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (1.8.1)
# Requirement already satisfied: pyzmq>=26.2.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (26.4.0)
# Requirement already satisfied: rerun-sdk>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.22.1)
# Requirement already satisfied: termcolor>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.0.1)
# Requirement already satisfied: torch>=2.2.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: torchcodec>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.2.1)
# Requirement already satisfied: torchvision>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: wandb>=0.16.3 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.19.9)
# Requirement already satisfied: zarr>=2.17.0 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (3.0.6)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (4.13.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->lerobot==0.1.0) (0.0.4)
# Requirement already satisfied: gym-aloha>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.1.1)
# Requirement already satisfied: gym-pusht>=0.1.5 in /usr/local/lib/python3.11/dist-packages (from lerobot==0.1.0) (0.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.19.0->lerobot==0.1.0) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (3.11.15)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.0->lerobot==0.1.0) (6.0.2)
# Requirement already satisfied: orderly-set<6,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from deepdiff>=7.0.1->lerobot==0.1.0) (5.3.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (8.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (2024.11.6)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (0.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers>=0.27.2->lerobot==0.1.0) (11.1.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (1.3.4)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.11/dist-packages (from draccus>=0.10.0->lerobot==0.1.0) (0.9.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask>=3.0.3->lerobot==0.1.0) (1.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown>=5.1.0->lerobot==0.1.0) (4.13.3)
# Requirement already satisfied: dm-control>=1.0.14 in /usr/local/lib/python3.11/dist-packages (from gym-aloha>=0.1.1->lerobot==0.1.0) (1.0.14)
# Requirement already satisfied: mujoco<3.0.0,>=2.3.7 in /usr/local/lib/python3.11/dist-packages (from gym-aloha>=0.1.1->lerobot==0.1.0) (2.3.7)
# Requirement already satisfied: opencv-python>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from gym-pusht>=0.1.5->lerobot==0.1.0) (4.11.0.86)
# Requirement already satisfied: pygame>=2.5.2 in /usr/local/lib/python3.11/dist-packages (from gym-pusht>=0.1.5->lerobot==0.1.0) (2.6.1)
# Requirement already satisfied: scikit-image>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from gym-pusht>=0.1.5->lerobot==0.1.0) (0.25.2)
# Requirement already satisfied: shapely>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from gym-pusht>=0.1.5->lerobot==0.1.0) (2.1.0)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (3.0.50)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]>=2.34.0->lerobot==0.1.0) (0.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]>=2.34.0->lerobot==0.1.0) (5.9.5)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonlines>=4.0.0->lerobot==0.1.0) (25.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.59.0->lerobot==0.1.0) (0.43.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf>=2.3.0->lerobot==0.1.0) (4.9.3)
# Requirement already satisfied: cffi>=1.17.1 in /usr/local/lib/python3.11/dist-packages (from pymunk>=6.6.0->lerobot==0.1.0) (1.17.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pynput>=1.7.7->lerobot==0.1.0) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.11/dist-packages (from pynput>=1.7.7->lerobot==0.1.0) (1.9.1)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.11/dist-packages (from pynput>=1.7.7->lerobot==0.1.0) (0.33)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.2.1->lerobot==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.2.1->lerobot==0.1.0) (1.3.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (5.29.4)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (2.11.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (2.25.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.3->lerobot==0.1.0) (75.2.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.11/dist-packages (from zarr>=2.17.0->lerobot==0.1.0) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.11/dist-packages (from numcodecs[crc32c]>=0.14->zarr>=2.17.0->lerobot==0.1.0) (0.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.17.1->pymunk>=6.6.0->lerobot==0.1.0) (2.22)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (1.4.0)
# Requirement already satisfied: dm-env in /usr/local/lib/python3.11/dist-packages (from dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (1.6)
# Requirement already satisfied: dm-tree!=0.1.2 in /usr/local/lib/python3.11/dist-packages (from dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (0.1.9)
# Requirement already satisfied: glfw in /usr/local/lib/python3.11/dist-packages (from dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (2.8.0)
# Requirement already satisfied: labmaze in /usr/local/lib/python3.11/dist-packages (from dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (1.0.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (5.3.1)
# Requirement already satisfied: pyopengl>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (3.1.9)
# Requirement already satisfied: pyparsing>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (3.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (1.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.19.0->lerobot==0.1.0) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0) (4.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->flask>=3.0.3->lerobot==0.1.0) (3.0.2)
# Requirement already satisfied: crc32c>=2.7 in /usr/local/lib/python3.11/dist-packages (from numcodecs[crc32c]>=0.14->zarr>=2.17.0->lerobot==0.1.0) (2.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb>=0.16.3->lerobot==0.1.0) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.19.0->lerobot==0.1.0) (2025.1.31)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.22.0->gym-pusht>=0.1.5->lerobot==0.1.0) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.22.0->gym-pusht>=0.1.5->lerobot==0.1.0) (0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect~=0.9.0->draccus>=0.10.0->lerobot==0.1.0) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown>=5.1.0->lerobot==0.1.0) (2.6)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers>=0.27.2->lerobot==0.1.0) (3.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.0->lerobot==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.0->lerobot==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.0->lerobot==0.1.0) (2025.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown>=5.1.0->lerobot==0.1.0) (1.7.1)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from dm-tree!=0.1.2->dm-control>=1.0.14->gym-aloha>=0.1.1->lerobot==0.1.0) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.16.3->lerobot==0.1.0) (5.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]>=0.27.1; python_version < "4.0"->lerobot==0.1.0) (0.2.13)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.1.0-py3-none-any.whl size=15386 sha256=15dda02b6d2865e6d3ed06e59689a71564cae251559bc5b22bc2e424b4b02254
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8t_9h_xs/wheels/15/0d/02/b9c6ff1c78574dee99101ad231194b3425eb4cd784ce8c8338
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.1.0
#     Uninstalling lerobot-0.1.0:
#       Successfully uninstalled lerobot-0.1.0
# Successfully installed lerobot-0.1.0

# %%
# !huggingface-cli login --token  ""
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# The token `Large Language Models` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Large Language Models`

# %%
# from lerobot.common.policies.pi0.modeling_pi0 import PI0Policy
# policy = PI0Policy.from_pretrained("lerobot/pi0")

# %%
# !python lerobot/scripts/eval.py \
# --pretrained_policy.path=lerobot/pi0

# !python lerobot/scripts/eval.py \
    --policy.path=lerobot/pi0  \
    --env.type=aloha \
    --eval.batch_size=10 \
    --eval.n_episodes=10 \
    # --device=cuda
# Out:
# INFO 2025-04-10 10:00:15 pts/eval.py:462 {'env': {'episode_length': 400,
#          'features': {'action': {'shape': (14,),
#                                  'type': <FeatureType.ACTION: 'ACTION'>},
#                       'agent_pos': {'shape': (14,),
#                                     'type': <FeatureType.STATE: 'STATE'>},
#                       'pixels/top': {'shape': (480, 640, 3),
#                                      'type': <FeatureType.VISUAL: 'VISUAL'>}},
#          'features_map': {'action': 'action',
#                           'agent_pos': 'observation.state',
#                           'pixels/top': 'observation.images.top',
#                           'top': 'observation.image.top'},
#          'fps': 50,
#          'obs_type': 'pixels_agent_pos',
#          'render_mode': 'rgb_array',
#          'task': 'AlohaInsertion-v0'},
#  'eval': {'batch_size': 10, 'n_episodes': 10, 'use_async_envs': False},
#  'job_name': 'aloha_pi0',
#  'output_dir': PosixPath('outputs/eval/2025-04-10/10-00-15_aloha_pi0'),
#  'policy': {'adapt_to_pi_aloha': False,
#             'attention_implementation': 'eager',
#             'chunk_size': 50,
#             'device': 'cuda',
#             'empty_cameras': 0,
#             'freeze_vision_encoder': True,
#             'input_features': {},
#             'max_action_dim': 32,
#             'max_state_dim': 32,
#             'n_action_steps': 50,
#             'n_obs_steps': 1,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.IDENTITY: 'IDENTITY'>},
#             'num_steps': 10,
#             'optimizer_betas': (0.9, 0.95),
#             'optimizer_eps': 1e-08,
#             'optimizer_lr': 2.5e-05,
#             'optimizer_weight_decay': 1e-10,
#             'output_features': {},
#             'proj_width': 1024,
#             'resize_imgs_with_padding': (224, 224),
#             'scheduler_decay_lr': 2.5e-06,
#             'scheduler_decay_steps': 30000,
#             'scheduler_warmup_steps': 1000,
#             'tokenizer_max_length': 48,
#             'train_expert_only': False,
#             'train_state_proj': True,
#             'use_amp': False,
#             'use_cache': True,
#             'use_delta_joint_actions_aloha': False},
#  'seed': 1000}
# INFO 2025-04-10 10:00:15 pts/eval.py:471 Output dir: outputs/eval/2025-04-10/10-00-15_aloha_pi0
# INFO 2025-04-10 10:00:15 pts/eval.py:473 Making environment.
# INFO 2025-04-10 10:00:15 /__init__.py:88 MUJOCO_GL is not set, so an OpenGL backend will be chosen automatically.
# /usr/local/lib/python3.11/dist-packages/glfw/__init__.py:917: GLFWError: (65550) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)
# INFO 2025-04-10 10:00:16 /__init__.py:96 Successfully imported OpenGL backend: %s
# INFO 2025-04-10 10:00:16 /__init__.py:31 MuJoCo library version is: %s
# INFO 2025-04-10 10:00:18 pts/eval.py:476 Making policy.
# 2025-04-10 10:00:21.718201: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744279222.014842    4052 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744279222.100892    4052 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-10 10:00:22.759674: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ^C

# %%
# !python lerobot/scripts/train.py \
--policy.path=lerobot/pi0 \
--dataset.repo_id=danaaubakirova/koch_test
# Out:
# WARNING 2025-04-10 09:40:04 ils/utils.py:50 No accelerated backend detected. Using default cpu, this will be slow.
# WARNING 2025-04-10 09:40:04 /policies.py:67 Device 'cuda' is not available. Switching to 'cpu'.
# INFO 2025-04-10 09:40:04 ts/train.py:111 {'batch_size': 8,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'danaaubakirova/koch_test',
#              'revision': None,
#              'root': None,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'pi0',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.95],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 2.5e-05,
#                'type': 'adamw',
#                'weight_decay': 1e-10},
#  'output_dir': 'outputs/train/2025-04-10/09-40-04_pi0',
#  'policy': {'adapt_to_pi_aloha': False,
#             'attention_implementation': 'eager',
#             'chunk_size': 50,
#             'device': 'cpu',
#             'empty_cameras': 0,
#             'freeze_vision_encoder': True,
#             'input_features': {},
#             'max_action_dim': 32,
#             'max_state_dim': 32,
#             'n_action_steps': 50,
#             'n_obs_steps': 1,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.IDENTITY: 'IDENTITY'>},
#             'num_steps': 10,
#             'optimizer_betas': [0.9, 0.95],
#             'optimizer_eps': 1e-08,
#             'optimizer_lr': 2.5e-05,
#             'optimizer_weight_decay': 1e-10,
#             'output_features': {},
#             'proj_width': 1024,
#             'resize_imgs_with_padding': [224, 224],
#             'scheduler_decay_lr': 2.5e-06,
#             'scheduler_decay_steps': 30000,
#             'scheduler_warmup_steps': 1000,
#             'tokenizer_max_length': 48,
#             'train_expert_only': False,
#             'train_state_proj': True,
#             'type': 'pi0',
#             'use_amp': False,
#             'use_cache': True,
#             'use_delta_joint_actions_aloha': False},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': {'decay_lr': 2.5e-06,
#                'num_decay_steps': 30000,
#                'num_warmup_steps': 1000,
#                'peak_lr': 2.5e-05,
#                'type': 'cosine_decay_with_warmup'},
#  'seed': 1000,
#  'steps': 100000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2025-04-10 09:40:04 ts/train.py:117 Logs will be saved locally.
# WARNING 2025-04-10 09:40:04 ils/utils.py:68 Using CPU, this will be slow.
# INFO 2025-04-10 09:40:04 ts/train.py:127 Creating dataset
# WARNING 2025-04-10 09:40:04 ts/utils.py:303
# The dataset you requested (danaaubakirova/koch_test) is in 2.0 format.
# While current version of LeRobot is backward-compatible with it, the version of your dataset still uses global
# stats instead of per-episode stats. Update your dataset stats to the new format using this command:
# ```
# python lerobot/common/datasets/v21/convert_dataset_v20_to_v21.py --repo-id=danaaubakirova/koch_test
# ```
#
# If you encounter a problem, contact LeRobot maintainers on [Discord](https://discord.com/invite/s3KuuzsPFb)
# or open an [issue on GitHub](https://github.com/huggingface/lerobot/issues/new/choose).
#
# WARNING 2025-04-10 09:40:04 ts/utils.py:303
# The dataset you requested (danaaubakirova/koch_test) is in 2.0 format.
# While current version of LeRobot is backward-compatible with it, the version of your dataset still uses global
# stats instead of per-episode stats. Update your dataset stats to the new format using this command:
# ```
# python lerobot/common/datasets/v21/convert_dataset_v20_to_v21.py --repo-id=danaaubakirova/koch_test
# ```
#
# If you encounter a problem, contact LeRobot maintainers on [Discord](https://discord.com/invite/s3KuuzsPFb)
# or open an [issue on GitHub](https://github.com/huggingface/lerobot/issues/new/choose).
#
# Resolving data files: 100% 51/51 [00:00<00:00, 215200.71it/s]
# INFO 2025-04-10 09:40:05 ts/train.py:138 Creating policy
# 2025-04-10 09:40:09.817032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744278010.136395    6150 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744278010.220979    6150 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-10 09:40:10.890808: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ^C
