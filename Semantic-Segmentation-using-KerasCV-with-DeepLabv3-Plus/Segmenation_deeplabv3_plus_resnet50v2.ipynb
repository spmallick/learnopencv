# %% [markdown]
# <h1 style="font-size:30px;">DeepLabv3+ with ResNet50_v2 Backbone</h1>

# %%
# !pip install -q git+https://github.com/keras-team/keras-cv.git --upgrade

# %%
import os
import requests
from zipfile import ZipFile
import glob
from dataclasses import dataclass, field

import random
import numpy as np
import cv2

import tensorflow as tf
import keras_cv

import matplotlib.pyplot as plt
# Out:
# 2023-10-02 16:21:13.701903: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-02 16:21:13.701977: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-02 16:21:13.702008: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-02 16:21:13.709870: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using TensorFlow backend

# %% [markdown]
# ## Set Seeds for Reproducibility

# %%
def system_config(SEED_VALUE):
    # Set python `random` seed.
    # Set `numpy` seed
    # Set `tensorflow` seed.
    random.seed(SEED_VALUE)
    tf.keras.utils.set_random_seed(SEED_VALUE)
    os.environ["CUDA_VISIBLE_DEVICES"] = '0'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'     
    os.environ['TF_USE_CUDNN'] = "true"

system_config(SEED_VALUE=42)

# %% [markdown]
# ## Download and Extract Dataset

# %%
# Download and dataset.
def download_and_unzip(url, save_path):

    print("Downloading and extracting assets...", end="")
    file = requests.get(url)
    open(save_path, "wb").write(file.content)

    try:
        # Extract tarfile.
        if save_path.endswith(".zip"):
            with ZipFile(save_path) as zip:
                zip.extractall(os.path.split(save_path)[0])

        print("Done")
    except:
        print("Invalid file")

# %%
DATASET_URL = r"https://www.dropbox.com/scl/fi/9k8t9619b4x0hegued5c5/Water-Bodies-Dataset.zip?rlkey=tjgepcai6t74yynmx7tqsm7af&dl=1"
DATASET_DIR = "Water-Bodies-Dataset"
DATASET_ZIP_PATH = os.path.join(os.getcwd(), f"{DATASET_DIR}.zip")

# Download if dataset does not exists.
if not os.path.exists(DATASET_DIR):
    download_and_unzip(DATASET_URL, DATASET_ZIP_PATH)
    os.remove(DATASET_ZIP_PATH)

# %% [markdown]
# ## Configurations

# %% [markdown]
# ### Data Configuration

# %%
@dataclass(frozen=True)
class DatasetConfig:
    IMAGE_SIZE:        tuple = (256, 256)
    BATCH_SIZE:          int = 16
    NUM_CLASSES:         int = 2
    BRIGHTNESS_FACTOR: float = 0.2
    CONTRAST_FACTOR:   float = 0.2

# %% [markdown]
# ### Training Configuration

# %%
@dataclass(frozen=True)
class TrainingConfig:
    MODEL:           str = "resnet50_v2_imagenet"
    EPOCHS:          int = 35
    LEARNING_RATE: float = 1e-4
    CKPT_DIR:        str = os.path.join("checkpoints_"+"_".join(MODEL.split("_")[:2]), 
                                        "deeplabv3_plus_"+"_".join(MODEL.split("_")[:2])+".h5")
    LOGS_DIR:        str = "logs_"+"_".join(MODEL.split("_")[:2])

# %%
train_config = TrainingConfig()
data_config = DatasetConfig()

# %% [markdown]
# ## Dataset Preparation

# %%
data_images = glob.glob(os.path.join(DATASET_DIR, "Images", "*.jpg"))
data_masks = glob.glob(os.path.join(DATASET_DIR, "Masks", "*.jpg"))

# Shuffle the data paths before data preparation.
zipped_data = list(zip(data_images, data_masks))
random.shuffle(zipped_data)
data_images, data_masks = zip(*zipped_data)
data_images = list(data_images)
data_masks = list(data_masks)

# %%
org_data = tf.data.Dataset.from_tensor_slices((data_images, data_masks))
# Out:
# 2023-10-02 16:21:23.014455: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-02 16:21:23.042641: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-02 16:21:23.107412: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-02 16:21:23.116717: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-02 16:21:23.117026: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-02 16:21:23.117327: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-02 16:21:23.224318: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-02 16:21:23.224653: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-02 16:21:23.224947: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-02 16:21:23.225210: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22287 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:81:00.0, compute capability: 8.9

# %% [markdown]
# ### Train-Validation Split

# %% [markdown]
# We are maintaining a **95-5** split ratio for training and validation samples respectively.

# %%
SPLIT_RATIO = 0.05
# Determine the number of validation samples
NUM_VAL = int(len(data_images) * SPLIT_RATIO)

# Split the dataset into train and validation sets
train_data = org_data.skip(NUM_VAL)
valid_data = org_data.take(NUM_VAL)

# %%
print(f"Train samples: {train_data.cardinality().numpy()}")
print(f"Validation samples: {valid_data.cardinality().numpy()}")
# Out:
# Train samples: 2699
# Validation samples: 142

# %% [markdown]
# ### Load Data and Threshold Masks

# %%
def read_image_mask(image_path, mask=False, size = data_config.IMAGE_SIZE):
    image = tf.io.read_file(image_path)

    if mask:
        image = tf.io.decode_image(image, channels=1)
        image.set_shape([None, None, 1])
        image = tf.image.resize(images=image, size=size, method = "bicubic")

        image_mask = tf.zeros_like(image)
        cond = image >=200
        updates = tf.ones_like(image[cond])
        image_mask = tf.tensor_scatter_nd_update(image_mask, tf.where(cond), updates)
        image = tf.cast(image_mask, tf.uint8)

    else:
        image = tf.io.decode_image(image, channels=3)
        image.set_shape([None, None, 3])
        image = tf.image.resize(images=image, size=size, method = "bicubic")
        image = tf.cast(tf.clip_by_value(image, 0., 255.), tf.float32)

    return image

# %%
def load_data(image_list, mask_list):
    image = read_image_mask(image_list)
    mask  = read_image_mask(mask_list, mask=True)
    return {"images":image, "segmentation_masks":mask}

# %%
train_ds = train_data.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
valid_ds = valid_data.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)

# %% [markdown]
# ### Unpack Images and Segmentation Masks
#
# The `unpackage_inputs` is a utility function that is used to unpack the inputs from the
# dictionary format to a tuple of `(images, segmentation_masks)`. This will be used later
# on for visualizing the images and segmentation masks and also the model predictions.

# %%
def unpackage_inputs(inputs):
    images = inputs["images"]
    segmentation_masks = inputs["segmentation_masks"]
    return images, segmentation_masks

# %% [markdown]
# ## Ground Truth Visualizations

# %%
# Dictionary mapping class IDs to colors.
id2color = {
    0: (0,  0,    0),    # Background
    1: (102, 204, 255),  # Waterbody
 }

# %%
# Function to convert a single channel mask representation to an RGB mask.
def num_to_rgb(num_arr, color_map=id2color):
    
    # single_layer = np.squeeze(num_arr)
    output = np.zeros(num_arr.shape[:2]+(3,))
    
    for k in color_map.keys():
        output[num_arr==k] = color_map[k]
        
    return output.astype(np.uint8)

# %%
# Function to overlay a segmentation map on top of an RGB image.
def image_overlay(image, segmented_image):

    alpha = 1.0 # Transparency for the original image.
    beta  = 0.7 # Transparency for the segmentation map.
    gamma = 0.0 # Scalar added to each sum.

    image = image.astype(np.uint8)

    segmented_image = cv2.cvtColor(segmented_image, cv2.COLOR_RGB2BGR)

    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    image = cv2.addWeighted(image, alpha, segmented_image, beta, gamma, image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    return image

# %% [markdown]
# Let us display a few ground truth images along with the corresponding ground truth mask; and have it overlayed on the image input.

# %%
def display_image_and_mask(data_list, title_list, figsize, color_mask=False, color_map=id2color):
    
    # Create RGB segmentation map from grayscale segmentation map.
    rgb_gt_mask = num_to_rgb(data_list[1], color_map=color_map)
    mask_to_overlay = rgb_gt_mask

    if len(data_list)==3:
        rgb_pred_mask = num_to_rgb(data_list[-1], color_map=color_map)
        mask_to_overlay = rgb_pred_mask
        
    # Create the overlayed image.
    overlayed_image = image_overlay(data_list[0], mask_to_overlay)
    
    data_list.append(overlayed_image)

    fig, axes = plt.subplots(nrows=1, ncols=len(data_list), figsize=figsize)
    
    for idx, axis in enumerate(axes.flat):
        axis.set_title(title_list[idx])
        if title_list[idx] == "GT Mask":
            if color_mask:
                axis.imshow(rgb_gt_mask)
            else:
                axis.imshow(data_list[1], cmap="gray")

        elif title_list[idx] == "Pred Mask":
            if color_mask:
                axis.imshow(rgb_pred_mask)
            else:
                axis.imshow(data_list[-1], cmap="gray")
            
        else:
            axis.imshow(data_list[idx])
            
        axis.axis('off')
        
    plt.show()

# %%
plot_train_ds = train_ds.map(unpackage_inputs).batch(3)
image_batch, mask_batch = next(iter(plot_train_ds.take(1)))

titles = ["GT Image", "GT Mask", "Overlayed Mask"]

for image, gt_mask in zip(image_batch, mask_batch):

    gt_mask = tf.squeeze(gt_mask, axis=-1).numpy()
    display_image_and_mask([image.numpy().astype(np.uint8), gt_mask], 
                           title_list=titles,
                           figsize=(16,6),
                           color_mask=True)

# %% [markdown]
# ## Data Augmentation
#
# We will use the following transforms as augmentations:
# * RandomFlip (default mode is **"horizontal"**, with a probability of `0.5`)
# * Random Brightness
# * Random Contrast

# %%
augment_fn = tf.keras.Sequential(
    [
        keras_cv.layers.RandomFlip(),
        keras_cv.layers.RandomBrightness(factor=data_config.BRIGHTNESS_FACTOR,
                                         value_range=(0, 255)),
        keras_cv.layers.RandomContrast(factor=data_config.CONTRAST_FACTOR,
                                       value_range=(0, 255)),
    ]
)

# %%
train_dataset = (
                train_ds.shuffle(data_config.BATCH_SIZE)
                .map(augment_fn, num_parallel_calls=tf.data.AUTOTUNE)
                .batch(data_config.BATCH_SIZE)
                .map(unpackage_inputs)
                .prefetch(buffer_size=tf.data.AUTOTUNE)
)

valid_dataset = (
                valid_ds.batch(data_config.BATCH_SIZE)
                .map(unpackage_inputs)
                .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %% [markdown]
# Let's visualized a few images and their segmentation masks from the training data, with
# the `keras_cv.visualization.plot_segmentation_mask_gallery` API.

# %% [markdown]
# ### Visualize Augmented Data

# %%
image_batch, aug_mask_batch = next(iter(train_dataset.take(1)))

titles = ["GT Image", "GT Mask", "Overlayed Mask"]

for idx, (image, gt_mask) in enumerate(zip(image_batch, aug_mask_batch)):
    if idx > 1:
        break
    gt_mask = tf.squeeze(gt_mask, axis=-1).numpy()
    display_image_and_mask([image.numpy().astype(np.uint8), gt_mask], 
                           title_list=titles,
                           figsize=(16,6),
                           color_mask=False)

# %% [markdown]
# ## Model Architecture
#
# We will use `resnet50_v2_imagenet` feature extractor on top of the DeepLabv3 Head.

# %%
backbone = keras_cv.models.ResNet50V2Backbone.from_preset(preset = train_config.MODEL,
                                                          input_shape=data_config.IMAGE_SIZE+(3,),
                                                          load_weights = True)
model = keras_cv.models.segmentation.DeepLabV3Plus(
        num_classes=data_config.NUM_CLASSES, backbone=backbone,
    )
print(model.summary())
# Out:
# Model: "deep_lab_v3_plus"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  model (Functional)          {'P2': (None, 64, 64, 256)   2355660   ['input_1[0][0]']
#                              , 'P5': (None, 8, 8, 2048)   8
#                              }
#
#  spatial_pyramid_pooling (S  (None, 8, 8, 256)            1553817   ['model[0][1]']
#  patialPyramidPooling)                                    6
#
#  encoder_output_upsampling   (None, 64, 64, 256)          0         ['spatial_pyramid_pooling[0][0
#  (UpSampling2D)                                                     ]']
#
#  sequential_1 (Sequential)   (None, 64, 64, 48)           12480     ['model[0][0]']
#
#  concatenate (Concatenate)   (None, 64, 64, 304)          0         ['encoder_output_upsampling[0]
#                                                                     [0]',
#                                                                      'sequential_1[0][0]']
#
#  sequential_2 (Sequential)   (None, 256, 256, 2)          79360     ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 39194816 (149.52 MB)
# Trainable params: 39145696 (149.33 MB)
# Non-trainable params: 49120 (191.88 KB)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Evaluation Metrics

# %% [markdown]
# Intersection over Union (IoU) is a metric often used in segmentation problems to assess the model's accuracy. It provides a more intuitive basis for accuracy that is not biased by the (unbalanced) percentage of pixels from any particular class. Given two segmentation masks, `A` and `B`, the IoU is defined as follows:
#
# $$
# IoU = \frac{|A\cap B\hspace{1mm}|}{|A\cup B\hspace{1mm}|} \hspace{2mm}
# $$
#
# When there are multiple classes and inferences, we assess the model's performance by computing the mean IoU.
#
# The function below computes the mean IoU that only considers the classes that are present in the ground truth mask or the predicted segmentation map (sometimes referred to as classwise mean IoU). This computation is a better representation of the metric since it only considers the relevant classes. **This is the metric computation we use for mean IoU.**

# %%
def mean_iou(y_true, y_pred):

    # Get total number of classes from model output.
    num_classes = y_pred.shape[-1]

    y_true = tf.squeeze(y_true, axis=-1)

    y_true = tf.one_hot(tf.cast(y_true, tf.int32), num_classes, axis=-1)
    y_pred = tf.one_hot(tf.math.argmax(y_pred, axis=-1), num_classes, axis=-1)

    # Intersection: |G ∩ P|. Shape: (batch_size, num_classes)
    intersection = tf.math.reduce_sum(y_true * y_pred, axis=(1, 2))

    # Total Sum: |G| + |P|. Shape: (batch_size, num_classes)
    total = tf.math.reduce_sum(y_true, axis=(1, 2)) + tf.math.reduce_sum(y_pred, axis=(1, 2))

    union = total - intersection

    is_class_present =  tf.cast(tf.math.not_equal(total, 0), dtype=tf.float32)
    num_classes_present = tf.math.reduce_sum(is_class_present, axis=1)

    iou = tf.math.divide_no_nan(intersection, union)
    iou = tf.math.reduce_sum(iou, axis=1) / num_classes_present

    # Compute the mean across the batch axis. Shape: Scalar
    mean_iou = tf.math.reduce_mean(iou)

    return mean_iou

# %% [markdown]
# ### Tensorboard and ModelCheckpoint Callbacks

# %%
def get_callbacks(
    train_config,
    monitor="val_mean_iou",
    mode="max",
    save_weights_only=True,
    save_best_only=True,
):

    # Initialize tensorboard callback for logging.
    tensorboard_callback = tf.keras.callbacks.TensorBoard(
        log_dir=train_config.LOGS_DIR,
        histogram_freq=20,
        write_graph=False,
        update_freq="epoch",
    )


    # Update file path if saving best model weights.
    if save_weights_only:
        checkpoint_filepath = train_config.CKPT_DIR

    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=save_weights_only,
        monitor=monitor,
        mode=mode,
        save_best_only=save_best_only,
        verbose=1,
    )

    return [tensorboard_callback, model_checkpoint_callback]

# %% [markdown]
# ## Train the model
#
# Now let's create the model, compile and train by calling `model.fit()` using the configurations defined in the `Trainingconfig` class.

# %%
# Build model.

# Get callbacks.
callbacks = get_callbacks(train_config)
# Define Loss.
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
# Compile model.
model.compile(
    optimizer=tf.keras.optimizers.Adam(train_config.LEARNING_RATE),
    loss=loss_fn,
    metrics=["accuracy", mean_iou],
)

# %%
# Train the model, doing validation at the end of each epoch.
history = model.fit(
    train_dataset,
    epochs=train_config.EPOCHS,
    validation_data=valid_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/35
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2023-10-02 16:22:07.859642: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2023-10-02 16:22:08.746294: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f1af60996d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-02 16:22:08.746337: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2023-10-02 16:22:08.751248: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-02 16:22:08.870426: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 169/169 [==============================] - ETA: 0s - loss: 0.3710 - accuracy: 0.8408 - mean_iou: 0.6432
# Epoch 1: val_mean_iou improved from -inf to 0.67080, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 57s 145ms/step - loss: 0.3710 - accuracy: 0.8408 - mean_iou: 0.6432 - val_loss: 0.3339 - val_accuracy: 0.8754 - val_mean_iou: 0.6708
# Epoch 2/35
# 169/169 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.8890 - mean_iou: 0.7214
# Epoch 2: val_mean_iou improved from 0.67080 to 0.70740, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 110ms/step - loss: 0.2733 - accuracy: 0.8890 - mean_iou: 0.7214 - val_loss: 0.3073 - val_accuracy: 0.8725 - val_mean_iou: 0.7074
# Epoch 3/35
# 169/169 [==============================] - ETA: 0s - loss: 0.2416 - accuracy: 0.9023 - mean_iou: 0.7485
# Epoch 3: val_mean_iou did not improve from 0.70740
# 169/169 [==============================] - 18s 109ms/step - loss: 0.2416 - accuracy: 0.9023 - mean_iou: 0.7485 - val_loss: 0.3427 - val_accuracy: 0.8530 - val_mean_iou: 0.6934
# Epoch 4/35
# 169/169 [==============================] - ETA: 0s - loss: 0.2212 - accuracy: 0.9104 - mean_iou: 0.7652
# Epoch 4: val_mean_iou improved from 0.70740 to 0.74368, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 111ms/step - loss: 0.2212 - accuracy: 0.9104 - mean_iou: 0.7652 - val_loss: 0.2662 - val_accuracy: 0.8925 - val_mean_iou: 0.7437
# Epoch 5/35
# 169/169 [==============================] - ETA: 0s - loss: 0.2024 - accuracy: 0.9182 - mean_iou: 0.7815
# Epoch 5: val_mean_iou did not improve from 0.74368
# 169/169 [==============================] - 18s 108ms/step - loss: 0.2024 - accuracy: 0.9182 - mean_iou: 0.7815 - val_loss: 0.5997 - val_accuracy: 0.7083 - val_mean_iou: 0.5442
# Epoch 6/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1920 - accuracy: 0.9225 - mean_iou: 0.7910
# Epoch 6: val_mean_iou improved from 0.74368 to 0.76031, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 111ms/step - loss: 0.1920 - accuracy: 0.9225 - mean_iou: 0.7910 - val_loss: 0.2479 - val_accuracy: 0.8985 - val_mean_iou: 0.7603
# Epoch 7/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1762 - accuracy: 0.9293 - mean_iou: 0.8047
# Epoch 7: val_mean_iou improved from 0.76031 to 0.78593, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 110ms/step - loss: 0.1762 - accuracy: 0.9293 - mean_iou: 0.8047 - val_loss: 0.2116 - val_accuracy: 0.9148 - val_mean_iou: 0.7859
# Epoch 8/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9314 - mean_iou: 0.8098
# Epoch 8: val_mean_iou improved from 0.78593 to 0.80203, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 110ms/step - loss: 0.1718 - accuracy: 0.9314 - mean_iou: 0.8098 - val_loss: 0.1936 - val_accuracy: 0.9271 - val_mean_iou: 0.8020
# Epoch 9/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9345 - mean_iou: 0.8155
# Epoch 9: val_mean_iou did not improve from 0.80203
# 169/169 [==============================] - 18s 108ms/step - loss: 0.1626 - accuracy: 0.9345 - mean_iou: 0.8155 - val_loss: 0.1986 - val_accuracy: 0.9204 - val_mean_iou: 0.7913
# Epoch 10/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1575 - accuracy: 0.9365 - mean_iou: 0.8208
# Epoch 10: val_mean_iou improved from 0.80203 to 0.80299, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 111ms/step - loss: 0.1575 - accuracy: 0.9365 - mean_iou: 0.8208 - val_loss: 0.1792 - val_accuracy: 0.9298 - val_mean_iou: 0.8030
# Epoch 11/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1572 - accuracy: 0.9369 - mean_iou: 0.8250
# Epoch 11: val_mean_iou did not improve from 0.80299
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1572 - accuracy: 0.9369 - mean_iou: 0.8250 - val_loss: 0.2275 - val_accuracy: 0.9073 - val_mean_iou: 0.7705
# Epoch 12/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1489 - accuracy: 0.9407 - mean_iou: 0.8312
# Epoch 12: val_mean_iou did not improve from 0.80299
# 169/169 [==============================] - 19s 109ms/step - loss: 0.1489 - accuracy: 0.9407 - mean_iou: 0.8312 - val_loss: 0.1924 - val_accuracy: 0.9267 - val_mean_iou: 0.7975
# Epoch 13/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9422 - mean_iou: 0.8368
# Epoch 13: val_mean_iou did not improve from 0.80299
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1444 - accuracy: 0.9422 - mean_iou: 0.8368 - val_loss: 0.1942 - val_accuracy: 0.9237 - val_mean_iou: 0.7955
# Epoch 14/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9434 - mean_iou: 0.8391
# Epoch 14: val_mean_iou did not improve from 0.80299
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1407 - accuracy: 0.9434 - mean_iou: 0.8391 - val_loss: 0.1883 - val_accuracy: 0.9270 - val_mean_iou: 0.7901
# Epoch 15/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9459 - mean_iou: 0.8439
# Epoch 15: val_mean_iou improved from 0.80299 to 0.81234, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 111ms/step - loss: 0.1351 - accuracy: 0.9459 - mean_iou: 0.8439 - val_loss: 0.1755 - val_accuracy: 0.9314 - val_mean_iou: 0.8123
# Epoch 16/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9477 - mean_iou: 0.8488
# Epoch 16: val_mean_iou did not improve from 0.81234
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1305 - accuracy: 0.9477 - mean_iou: 0.8488 - val_loss: 0.1842 - val_accuracy: 0.9325 - val_mean_iou: 0.8097
# Epoch 17/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9491 - mean_iou: 0.8523
# Epoch 17: val_mean_iou improved from 0.81234 to 0.81761, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 111ms/step - loss: 0.1274 - accuracy: 0.9491 - mean_iou: 0.8523 - val_loss: 0.1706 - val_accuracy: 0.9340 - val_mean_iou: 0.8176
# Epoch 18/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9499 - mean_iou: 0.8536
# Epoch 18: val_mean_iou did not improve from 0.81761
# 169/169 [==============================] - 18s 108ms/step - loss: 0.1261 - accuracy: 0.9499 - mean_iou: 0.8536 - val_loss: 0.1871 - val_accuracy: 0.9257 - val_mean_iou: 0.7973
# Epoch 19/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9510 - mean_iou: 0.8566
# Epoch 19: val_mean_iou did not improve from 0.81761
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1234 - accuracy: 0.9510 - mean_iou: 0.8566 - val_loss: 0.1899 - val_accuracy: 0.9295 - val_mean_iou: 0.8062
# Epoch 20/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9514 - mean_iou: 0.8591
# Epoch 20: val_mean_iou did not improve from 0.81761
# 169/169 [==============================] - 19s 109ms/step - loss: 0.1212 - accuracy: 0.9514 - mean_iou: 0.8591 - val_loss: 0.1931 - val_accuracy: 0.9334 - val_mean_iou: 0.8076
# Epoch 21/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9524 - mean_iou: 0.8612
# Epoch 21: val_mean_iou did not improve from 0.81761
# 169/169 [==============================] - 22s 131ms/step - loss: 0.1192 - accuracy: 0.9524 - mean_iou: 0.8612 - val_loss: 0.2067 - val_accuracy: 0.9225 - val_mean_iou: 0.7962
# Epoch 22/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9533 - mean_iou: 0.8635
# Epoch 22: val_mean_iou improved from 0.81761 to 0.82220, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 111ms/step - loss: 0.1165 - accuracy: 0.9533 - mean_iou: 0.8635 - val_loss: 0.1665 - val_accuracy: 0.9358 - val_mean_iou: 0.8222
# Epoch 23/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9539 - mean_iou: 0.8637
# Epoch 23: val_mean_iou did not improve from 0.82220
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1149 - accuracy: 0.9539 - mean_iou: 0.8637 - val_loss: 0.1635 - val_accuracy: 0.9385 - val_mean_iou: 0.8215
# Epoch 24/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9538 - mean_iou: 0.8644
# Epoch 24: val_mean_iou did not improve from 0.82220
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1152 - accuracy: 0.9538 - mean_iou: 0.8644 - val_loss: 0.1925 - val_accuracy: 0.9272 - val_mean_iou: 0.7870
# Epoch 25/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9543 - mean_iou: 0.8667
# Epoch 25: val_mean_iou did not improve from 0.82220
# 169/169 [==============================] - 19s 109ms/step - loss: 0.1140 - accuracy: 0.9543 - mean_iou: 0.8667 - val_loss: 0.1791 - val_accuracy: 0.9313 - val_mean_iou: 0.8096
# Epoch 26/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9555 - mean_iou: 0.8692
# Epoch 26: val_mean_iou improved from 0.82220 to 0.82617, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 111ms/step - loss: 0.1107 - accuracy: 0.9555 - mean_iou: 0.8692 - val_loss: 0.1627 - val_accuracy: 0.9395 - val_mean_iou: 0.8262
# Epoch 27/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9552 - mean_iou: 0.8677
# Epoch 27: val_mean_iou did not improve from 0.82617
# 169/169 [==============================] - 18s 108ms/step - loss: 0.1121 - accuracy: 0.9552 - mean_iou: 0.8677 - val_loss: 0.2005 - val_accuracy: 0.9224 - val_mean_iou: 0.8003
# Epoch 28/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9566 - mean_iou: 0.8721
# Epoch 28: val_mean_iou did not improve from 0.82617
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1086 - accuracy: 0.9566 - mean_iou: 0.8721 - val_loss: 0.1557 - val_accuracy: 0.9411 - val_mean_iou: 0.8237
# Epoch 29/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9581 - mean_iou: 0.8754
# Epoch 29: val_mean_iou improved from 0.82617 to 0.82989, saving model to checkpoints/deeplabv3_plus_resnet50_v2.h5
# 169/169 [==============================] - 19s 110ms/step - loss: 0.1046 - accuracy: 0.9581 - mean_iou: 0.8754 - val_loss: 0.1634 - val_accuracy: 0.9422 - val_mean_iou: 0.8299
# Epoch 30/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1056 - accuracy: 0.9576 - mean_iou: 0.8730
# Epoch 30: val_mean_iou did not improve from 0.82989
# 169/169 [==============================] - 18s 108ms/step - loss: 0.1056 - accuracy: 0.9576 - mean_iou: 0.8730 - val_loss: 0.1616 - val_accuracy: 0.9403 - val_mean_iou: 0.8257
# Epoch 31/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9572 - mean_iou: 0.8726
# Epoch 31: val_mean_iou did not improve from 0.82989
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1076 - accuracy: 0.9572 - mean_iou: 0.8726 - val_loss: 0.4067 - val_accuracy: 0.8251 - val_mean_iou: 0.6485
# Epoch 32/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9584 - mean_iou: 0.8763
# Epoch 32: val_mean_iou did not improve from 0.82989
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1038 - accuracy: 0.9584 - mean_iou: 0.8763 - val_loss: 0.1820 - val_accuracy: 0.9333 - val_mean_iou: 0.8181
# Epoch 33/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9586 - mean_iou: 0.8787
# Epoch 33: val_mean_iou did not improve from 0.82989
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1031 - accuracy: 0.9586 - mean_iou: 0.8787 - val_loss: 0.2087 - val_accuracy: 0.9235 - val_mean_iou: 0.8117
# Epoch 34/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9586 - mean_iou: 0.8777
# Epoch 34: val_mean_iou did not improve from 0.82989
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1032 - accuracy: 0.9586 - mean_iou: 0.8777 - val_loss: 0.2007 - val_accuracy: 0.9276 - val_mean_iou: 0.8017
# Epoch 35/35
# 169/169 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9594 - mean_iou: 0.8794
# Epoch 35: val_mean_iou did not improve from 0.82989
# 169/169 [==============================] - 18s 109ms/step - loss: 0.1017 - accuracy: 0.9594 - mean_iou: 0.8794 - val_loss: 0.1720 - val_accuracy: 0.9362 - val_mean_iou: 0.8218

# %% [markdown]
# #### Load Fine-tuned Model Weights

# %%
model.load_weights(train_config.CKPT_DIR)

# %% [markdown]
# #### Perform Evaluation

# %%
evaluate = model.evaluate(valid_dataset)
# Out:
# 9/9 [==============================] - 0s 33ms/step - loss: 0.1634 - accuracy: 0.9422 - mean_iou: 0.8299

# %% [markdown]
# ## Prediction with Fine-tuned Model
#
# Now that the model training of DeepLabv3 has been completed, let's test it by making predictions on a few sample images.

# %%
def inference(model, dataset, samples_to_plot):

    num_batches_to_process = 2
    count = 0
    stop_plot = False

    titles = ["Image", "GT Mask", "Pred Mask", "Overlayed Prediction"]

    for idx, data in enumerate(dataset):

        if stop_plot:
            break

        batch_img, batch_mask = data[0], data[1]
        batch_pred = (model.predict(batch_img)).astype('float32')
        batch_pred = batch_pred.argmax(axis=-1)
        
        batch_img  = batch_img.numpy().astype('uint8')
        batch_mask = batch_mask.numpy().squeeze(axis=-1)

        for image, mask, pred in zip(batch_img, batch_mask, batch_pred):
            count+=1
            display_image_and_mask([image, mask, pred],
                                  title_list=titles,
                                   figsize=(20,8),
                                   color_mask=True)
            if count >= samples_to_plot:
                stop_plot=True
                break

# %%
inference(model, valid_dataset, samples_to_plot=10)
# Out:
# 1/1 [==============================] - 1s 1s/step
